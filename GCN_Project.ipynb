# %%
#Cora MLN
def MLN__Cora_explanation():
                class MLN_EXP:
                    @classmethod
                    def cora_mln(cls):
                                    pid=[]
                                    cl=[]
                                    words={}
                                    label={}
                                    ln1=[]
                                    ln2=[]
                                    f1=open("content.txt")
                                    for j in f1:
                                        wrds=[]
                                        p=j.strip("\n").split()
                                        for j in range(1,len(p)-1):
                                            if int(p[j])==1:
                                                ss="w_"+str(j)
                                                wrds.append(ss)
                                        words[p[0]]=wrds
                                        label[p[0]]=p[-1]
                                       # print(len(wrds))
                                    f1.close()
                                    f1=open("link.txt")
                                    for z in f1:
                                        p=z.strip("\n").split()
                                        ln1.append(p[0])
                                        ln2.append(p[1])
                                    f1.close()
                                    linked={}
                                    for t in words:
                                        zzv=[]
                                        for hh in range(0,len(ln1)):
                                            if int(t)==int(ln1[hh]):
                                                if ln2[hh] not in zzv:
                                                            zzv.append(ln2[hh])
                                        if len(zzv)>0:
                                              linked[t]=zzv
                                    for x in linked:
                                        pass#print(x,linked[x]) Neural_Networks Neural_Networks
                                    WORDS={}
                                    samelink={}
                                    c1=0
                                    c2=0
                                    c3=0
                                    c4=0
                                    c5=0
                                    c6=0
                                    c7=0
                                    #c2=0
                                    lb=80
                                    for x in words:
                                        if x in linked:
                                                    if label[x]=='Neural_Networks':
                                                         if c1<lb:
                                                            if len(linked[x])>=5:
                                                                WORDS[x]=words[x]
                                                                samelink[x]=linked[x]
                                                                c1=c1+1
                                                    elif label[x]=='Probabilistic_Methods':
                                                          if c2<lb:
                                                                if len(linked[x])>=5:
                                                                    WORDS[x]=words[x]
                                                                    samelink[x]=linked[x]
                                                                    c2=c2+1
                                                    elif label[x]=='Genetic_Algorithms':
                                                          if c3<lb:
                                                                if len(linked[x])>=5:
                                                                    WORDS[x]=words[x]
                                                                    samelink[x]=linked[x]
                                                                    c3=c3+1
                                                    elif label[x]=='Theory':
                                                          if c4<lb:
                                                                if len(linked[x])>=5:
                                                                    WORDS[x]=words[x]
                                                                    samelink[x]=linked[x]
                                                                    c4=c4+1
                                                    elif label[x]=='Case_Based':
                                                          if c5<80:
                                                                if len(linked[x])>=5:
                                                                    WORDS[x]=words[x]
                                                                    samelink[x]=linked[x]
                                                                    c5=c5+1
                                                    elif label[x]=='Reinforcement_Learning':
                                                          if c6<80:
                                                                if len(linked[x])>=5:
                                                                    WORDS[x]=words[x]
                                                                    samelink[x]=linked[x]
                                                                    c6=c6+1
                                                    elif label[x]=='Rule_Learning':
                                                          if c7<80:
                                                                if len(linked[x])>=5:
                                                                    WORDS[x]=words[x]
                                                                    samelink[x]=linked[x]
                                                                    c7=c7+1
                                    # Data Type

                                    d_tt={}
                                    #margs2={}
                                    d_tt[0]="Neural_Networks"
                                    d_tt[1]="Probabilistic_Methods"
                                    d_tt[2]="Genetic_Algorithms"
                                    d_tt[3]="Theory"
                                    d_tt[4]="Case_Based"
                                    d_tt[5]="Reinforcement_Learning"
                                    d_tt[6]="Rule_Learning"
                                    #d_tt[7]="Probabilistic_Methods"
                                    #train and target data
                                    w11=[]
                                    trg=[]
                                    w12=[]
                                    trg1=[]
                                    for tt in WORDS:
                                        s=' '
                                        #if qrat[tt]!=1:
                                        for kk in WORDS[tt]:
                                            #if qrat[tt]!=1:
                                                w11.append(kk)
                                                s=str(kk)+s+"\t"
                                                #print(kk)
                                                trg.append(label[tt])
                                            #w12.append(s)
                                            #trg1.append(qrat[tt])
                                    #SVM Learner
                                    from sklearn.feature_extraction.text import TfidfVectorizer
                                    from sklearn import svm
                                    #from sklearn import cross_validation
                                    from sklearn.model_selection import cross_validate
                                    from sklearn.preprocessing import MinMaxScaler
                                    from sklearn.metrics import (precision_score,recall_score,f1_score)
                                    from sklearn.feature_extraction.text import TfidfVectorizer
                                    from collections import defaultdict
                                    from sklearn import svm
                                    #from sklearn import cross_validation
                                    from sklearn.model_selection import cross_validate
                                    from sklearn.preprocessing import MinMaxScaler
                                    from sklearn.metrics import (precision_score,recall_score,f1_score)
                                    from sklearn.multiclass import OneVsRestClassifier
                                    from sklearn.svm import SVC
                                    from sklearn.svm import LinearSVC
                                    from sklearn.multiclass import OneVsOneClassifier
                                    from sklearn.multiclass import OutputCodeClassifier

                                    #OutputCodeClassifier(LinearSVC(random_state=0),code_size=2, random_state=0)

                                    #Learn SVM Model
                                    #ifile = open("processed_revs_1.txt",encoding="ISO-8859-1")
                                    Y = trg
                                    words =w11
                                    unique_words = []

                                    ss=set(words)
                                    for w1 in ss:
                                            if w1 not in unique_words:
                                                unique_words.append(w1)

                                    #######
                                    #tf_transformer = TfidfVectorizer()
                                    #f = tf_transformer.fit_transform(words)
                                    #features = [((i, j), f[i,j]) for i, j in zip(*f.nonzero())]
                                    #unique_word_ids = []
                                    #for w in unique_words:
                                       # i = tf_transformer.vocabulary_.get(w)
                                        #unique_word_ids.append(i)

                                    #clf =OneVsRestClassifier(SVC(kernel='linear'))#svm.LinearSVC(C=1)
                                    #clf.fit(f,Y)
                                    #p = clf.predict(f)
                                    #print(f1_score(Y,p,average='weighted'))




                                    #########
                                    tf_transformer = TfidfVectorizer()
                                    f = tf_transformer.fit_transform(words)
                                    features = [((i, j), f[i,j]) for i, j in zip(*f.nonzero())]
                                    unique_word_ids = []
                                    for w in unique_words:
                                        i = tf_transformer.vocabulary_.get(w)
                                        unique_word_ids.append(i)

                                    clf =svm.LinearSVC(C=100)#svm.SVC(C=1.0, kernel='linear', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=- 1, decision_function_shape='ovr', random_state=None)

                                    #OneVsRestClassifier(LinearSVC(random_state=0)) #svm.LinearSVC(C=1)
                                    clf.fit(f,Y)
                                    #clf.fit(f,Y)
                                    p = clf.predict(f)
                                    #print(f1_score(Y,p,average='micro'))
                                    from sklearn.metrics import accuracy_score
                                    #print(accuracy_score(Y,p))

                                    #Store learned weights

                                    #Tunable parameter, normalization range of weights
                                    rangelower=0
                                    rangehigher=1

                                    C = clf.coef_
                                    scaler = MinMaxScaler(feature_range=(rangelower,rangehigher))
                                    vals = []
                                    for i, j in zip(*C.nonzero()):
                                        vals.append([C[i,j]])
                                    scaler.fit(vals)
                                    V1 = scaler.transform(vals)
                                    rows,cols = C.nonzero()
                                    r_wts =  defaultdict(list)
                                    ix= 0
                                    for w in unique_words:
                                        r_wts[w] = [0,0,0,0,0,0,0]  
                                    for i, j in zip(*C.nonzero()):
                                        #print(i,j)
                                        for k in tf_transformer.vocabulary_.keys():
                                            if tf_transformer.vocabulary_[k]==j:
                                                if k not in r_wts:
                                                    break
                                                else:
                                                    #if float(V1[ix][0])>0:
                                                    r_wts[k][i] = V1[ix][0]
                                                    break
                                        ix = ix + 1


                                    #print(r_wts)
                                    #Sample 2 origin

                                    import random
                                    from collections import defaultdict

                                    #Sampler
                                    margs =defaultdict(list)
                                    Relational_formula_filter={}
                                    iter1=defaultdict(list)
                                    users_s= defaultdict(list)
                                    expns = defaultdict(dict)
                                    Relational_formula_filter={}
                                    same_user={}
                                    Sample={}
                                    Sample_r={}

                                    for h in samelink:
                                        for i,r in enumerate(samelink[h]):
                                            if r in WORDS:
                                                    Sample[r] = random.randint(0,6)
                                                    #Sample_r[r] = random.randint(0,1)
                                                    margs[r] = [0]*7
                                                    #margs_r[r] = 0
                                                    iter1[r] =0

                                    #Tunable parameter (default value of prob)
                                    C1 = 0.98
                                    VR=0.98
                                    iters =1000000

                                    for t in range(0,iters,1):
                                        h1 = random.choice(list(samelink.keys()))
                                        if len(samelink[h1])==0:
                                            continue
                                        ix1 = random.randint(0,len(samelink[h1])-1)
                                        r33 = samelink[h1][ix1]
                                        if r33 in WORDS:
                                            if random.random()<0.5:
                                                #sample Topic
                                                W0=0
                                                W1=0
                                                W2=0
                                                W3=0
                                                W4=0
                                                W5=0
                                                W6=0


                                                try:
                                                            for w in WORDS[r33]:
                                                                if len(r_wts[w])!=7:
                                                                    continue

                                                                W0=W0+r_wts[w][0]
                                                                W1=W1+r_wts[w][1]
                                                                W2=W2+r_wts[w][2]
                                                                W3=W3+r_wts[w][3]
                                                                W4=W4+r_wts[w][4]
                                                                W5=W5+r_wts[w][5]
                                                                W6=W6+r_wts[w][6]
                                                               # W2=W2+(r_wts[w][2])


                                                                if r33 not in expns or w not in expns[r]:
                                                                                         expns[r33][w] = r_wts[w][0]
                                                                                         expns[r33][w] = r_wts[w][1]
                                                                                         expns[r33][w] = r_wts[w][2]
                                                                                         expns[r33][w] = r_wts[w][3]
                                                                                         expns[r33][w] = r_wts[w][4]
                                                                                         expns[r33][w] = r_wts[w][5]
                                                                                         expns[r33][w] = r_wts[w][6]
                                                                                    #expns[r][w] = (r_wts[w][2])


                                                                else:
                                                                                     expns[r33][w] =expns[r33][w]+ r_wts[w][0]
                                                                                     expns[r33][w] = expns[r33][w]+r_wts[w][1]
                                                                                     expns[r33][w] = expns[r33][w]+r_wts[w][2]
                                                                                     expns[r33][w] =expns[r33][w]+ r_wts[w][3]
                                                                                     expns[r33][w] =expns[r33][w]+ r_wts[w][4]
                                                                                     expns[r33][w] =expns[r33][w]+ r_wts[w][5]
                                                                                     expns[r33][w] =expns[r33][w]+ r_wts[w][6]
                                                except:
                                                    continue



                                                if (W0+W1+W2+W3+W4+W5+W6)!= 0:
                                                    W0 = W0/(W0+W1+W2+W3+W4+W5+W6)
                                                    W1 = W1/(W0+W1+W2+W3+W4+W5+W6)
                                                    W2 = W2/(W0+W1+W2+W3+W4+W5+W6)
                                                    W3 = W3/(W0+W1+W2+W3+W4+W5+W6)
                                                    W4 = W4/(W0+W1+W2+W3+W4+W5+W6)
                                                    W5 = W5/(W0+W1+W2+W3+W4+W5+W6)
                                                    W6 = W6/(W0+W1+W2+W3+W4+W5+W6)

                                                   # W2=W2/(W0+W1+W2)


                                                    sval = random.random()
                                                    iter1[r33]=iter1[r33]+1
                                                    #print(sval,W14,W15,W16,W17,W18,W19)
                                                    if sval<W0:
                                                        #print(sval)
                                                        Sample[r33]=0
                                                        #Sample_r[r33]=0
                                                        margs[r33][0]=margs[r33][0]+1
                                                    elif sval<(W0+W1):
                                                        #print(sval)
                                                        Sample[r33]=1
                                                        #Sample_r[r33]=1
                                                        margs[r33][1]=margs[r33][1]+1
                                                    elif sval<(W0+W1+W2):
                                                        #print(sval)
                                                        Sample[r33]=2
                                                        #Sample_r[r33]=1
                                                        margs[r33][2]=margs[r33][1]+1
                                                    elif sval<(W0+W1+W2+W3):
                                                        #print(sval)
                                                        Sample[r33]=3
                                                        #Sample_r[r33]=1
                                                        margs[r33][3]=margs[r33][1]+1
                                                    elif sval<(W0+W1+W2+W3+W4):
                                                        #print(sval)
                                                        Sample[r33]=4
                                                        #Sample_r[r33]=1
                                                        margs[r33][4]=margs[r33][1]+1
                                                    elif sval<(W0+W1+W2+W3+W4+W5):
                                                        #print(sval)
                                                        Sample[r33]=5
                                                        #Sample_r[r33]=1
                                                        margs[r33][5]=margs[r33][1]+1
                                                    elif sval<(W0+W1+W2+W3+W4+W5+W6):
                                                        #print(sval)
                                                        Sample[r33]=6
                                                        #Sample_r[r33]=1
                                                        margs[r33][6]=margs[r33][1]+1



                                                    for r1 in samelink[h]:
                                                        if r1==r33:
                                                            continue
                                                        if r33 in WORDS and r1 in WORDS:
                                                                if Sample[r33]!=Sample[r1]:
                                                                    if Sample[r1]==0:
                                                                        #W0=W0+r_wts1[w][0]
                                                                        #margs[r][0]=margs[r][0]+1
                                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                                            expns[r33][hhlll] =C1
                                                                            if r33 not in Relational_formula_filter:
                                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                                        else:
                                                                            expns[r33][hhlll] = expns[r33][hhlll] + C1
                                                                    elif Sample[r1]==1:
                                                                        #W1=W1+r_wts1[w][1]
                                                                       # margs[r][1]=margs[r][1]+1
                                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                                            expns[r33][hhlll] =C1
                                                                            if r33 not in Relational_formula_filter:
                                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                                        else:
                                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                                    elif Sample[r1]==2:
                                                                        #W1=W1+r_wts1[w][1]
                                                                       # margs[r][1]=margs[r][1]+1
                                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                                            expns[r33][hhlll] =C1
                                                                            if r33 not in Relational_formula_filter:
                                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                                        else:
                                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                                    elif Sample[r1]==3:
                                                                        #W1=W1+r_wts1[w][1]
                                                                       # margs[r][1]=margs[r][1]+1
                                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                                            expns[r33][hhlll] =C1
                                                                            if r33 not in Relational_formula_filter:
                                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                                        else:
                                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                                    elif Sample[r1]==4:
                                                                        #W1=W1+r_wts1[w][1]
                                                                       # margs[r][1]=margs[r][1]+1
                                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                                            expns[r33][hhlll] =C1
                                                                            if r33 not in Relational_formula_filter:
                                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                                        else:
                                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                                    elif Sample[r1]==5:
                                                                        #W1=W1+r_wts1[w][1]
                                                                       # margs[r][1]=margs[r][1]+1
                                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                                            expns[r33][hhlll] =C1
                                                                            if r33 not in Relational_formula_filter:
                                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                                        else:
                                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                                    elif Sample[r1]==6:
                                                                        #W1=W1+r_wts1[w][1]
                                                                       # margs[r][1]=margs[r][1]+1
                                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                                            expns[r33][hhlll] =C1
                                                                            if r33 not in Relational_formula_filter:
                                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                                        else:
                                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 




                                    #Computing Marginal Probability of original
                                    margs1={}
                                    for t in margs:
                                        pass# print(t,margs[t])
                                        gh=[]
                                        if iter1[t]>0:
                                            for kk in margs[t]:
                                                vv=float(kk)/float(iter1[t])
                                                if float(vv)>=1.0:
                                                    gh.append(float(1.0))
                                                elif float(vv)<1.0:
                                                    gh.append(abs(float(vv)))
                                            margs1[t]=gh
                                    #d_tt={}
                                    margs2={}
                                    #d_tt[0]="Neural_Networks"
                                    #d_tt[1]="Probabilistic_Methods"
                                    for dd in margs1:
                                        v=max(margs1[dd])
                                        pass#print(v)
                                        if v>0:
                                            margs2[dd]=v
                                    #check the marginal
                                    for t in margs:
                                         pass#print(t,margs[t])
                                    for t in margs1:
                                        s=0
                                        for dd in margs1[t]:
                                            s=s+dd
                                        pass#print(t,s)

                                    #predicting review original
                                    sampled_doc=[]
                                    pred_t=[]
                                    for a in margs1:
                                        for ss in range(0,len(margs1[a])):
                                                if margs1[a][ss]==margs2[a]:
                                                    #print(a,d_tt[ss])
                                                    sampled_doc.append(a)
                                                    pred_t.append(d_tt[ss])
                                    ss=set(sampled_doc)
                                    sampled_doc_up=[]
                                    sampled_doc_up_map1={}
                                    for kk in ss:
                                        sampled_doc_up.append(kk)
                                    for tt in sampled_doc_up:
                                        ggf=[]
                                        gvv=[]
                                        c=0
                                        for gg in range(0,len(sampled_doc)):
                                            if tt==sampled_doc[gg]:
                                                ggf.append(pred_t[gg])
                                        for ggh in ggf:
                                            if c<1:
                                                gvv.append(ggh)
                                                c=c+1

                                        sampled_doc_up_map1[tt]=gvv

                                    cx=0   
                                    for s in sampled_doc_up_map1:
                                        if len(sampled_doc_up_map1[s])>1:
                                                cx=cx+1
                                               #print(s,sampled_doc_up_map[s])


                                    #print(doc_per_pred_topic)
                                    #print(cx)

                                    ffd=open("Original_Prediction1.txt","w")

                                    for s in sampled_doc_up_map1:
                                        ccvb=str(s)+":"+str(sampled_doc_up_map1[s])
                                        ffd.write(str(ccvb)+"\n")
                                    ffd.close()

                                    #Computing Prediction Probability
                                    from sklearn import svm
                                    #from sklearn import cross_validation
                                    from sklearn.model_selection import cross_validate
                                    from sklearn.preprocessing import MinMaxScaler
                                    from sklearn.metrics import (precision_score,recall_score,f1_score)
                                    from sklearn.feature_extraction.text import CountVectorizer
                                    pred=[]
                                    true=[]
                                    #topicindex doc_per_pred_topic sampled_doc_up_map
                                    f4=[]
                                    f5=[]
                                    f6=[]
                                    #for d in range(0,2):
                                    for t in margs2:
                                       # if t in qrat and t in sampled_doc_up_map1:
                                                        for tt in sampled_doc_up_map1[t]:
                                                                        #print(tt,d_tt[0])
                                                                        if str(tt)==str(d_tt[1]):
                                                                            pred.append(1)
                                                                        else:
                                                                            pred.append(0)
                                                                        if str(label[t])=='Probabilistic_Methods':
                                                                            true.append(1)
                                                                        else:
                                                                            true.append(0)
                                    #print(precision_score(true,pred))
                                    #print(recall_score(true,pred))
                                    #print(f1_score(true,pred))
                                    f4.append(float(precision_score(true,pred)))
                                    f5.append(float(recall_score(true,pred)))
                                    f6.append(float(f1_score(true,pred)))
                                    #Explanation Generation
                                    import operator
                                    correct_predictions_r = {}

                                    for m in margs1.keys():
                                                if m in WORDS and m in sampled_doc_up_map1:
                                                              correct_predictions_r[m] = 1
                                                #if len(WORDS[m])==0:#or ratings[m]==3:
                                                   # continue
                                                #else:
                                                   # correct_predictions[m] = 1
                                                #if margs[m] > 0.5 and spamindex[m] ==-1:
                                                    #correct_predictions[m] = 1
                                    fft_r=open("expn_n1_r1_or.txt","w")  
                                    explanation_r={}
                                    for e in expns: 
                                        if e in correct_predictions_r:
                                            sorted_expns_r = sorted(expns[e].items(), key=operator.itemgetter(1),reverse=True)
                                            z = 0
                                            for s in sorted_expns_r[:]:
                                                z = z + s[1]
                                            rex_r = {}
                                            keys_r = []
                                            for s in sorted_expns_r[:]:
                                                #if 'same' in s[0]:
                                                rex_r[s[0]] = s[1]/z
                                                keys_r.append(s[0])
                                            #if "Sameuser" not in keys or "Samehotel" not in keys:
                                                #continue
                                            sorted1 = sorted(rex_r.items(), key=operator.itemgetter(1),reverse=True)
                                            #if sorted1[0][0]=="JNTM":
                                            #print(str(e) +" "+str(sorted1))
                                            gg=str(e) +":"+str(sorted1)
                                            explanation_r[e]=sorted1
                                            fft_r.write(str(gg)+"\n")
                                    hhh="Explanation_Topic1"+"_original"+" before user feedback"+".txt"
                                    f11_r=open(hhh,"w")
                                    Store_Explanation_r={}
                                    for t in explanation_r:
                                        #for k in WORDS1:
                                               #if str(t)==str(k):
                                                    ggg=str(t)+":"+str(explanation_r[t])
                                                    f11_r.write(str(ggg)+"\n")
                                                    print(t,explanation_r[t])
                                                    print("\n")
                                                    Store_Explanation_r[t]=explanation_r[t]
                                    return WORDS,Store_Explanation_r


                WORDS,Store_Explanation_r=MLN_EXP.cora_mln()
                return WORDS,Store_Explanation_r

# %%
# GCN Prediction and Explanations.


import pandas as pd
import os

import stellargraph as sg
from stellargraph.mapper import FullBatchNodeGenerator
from stellargraph.layer import GCN

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from sklearn import preprocessing, model_selection
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import f1_score
def GCN_Result(WORDS,Store_Explanation_r):
        class gcn:
            @classmethod
            def data(cls,dataset):
                display(HTML(dataset.description))
                G, node_subjects = dataset.load()
                return G, node_subjects
            @classmethod
            def update_inp_mlev(cls,node_subjects,WORDS):
                rm1=[]
                for t in node_subjects.index:
                    #print(t)
                    if str(t) not in WORDS:
                        rm1.append(t)
                print(len(rm1))
                node_subjects1=node_subjects.drop(labels=rm1)
                return node_subjects1
            @classmethod
            def dis_graph_info(cls,G):
                return  G.info()
            @classmethod
            def updated_nodes(cls,node_subjects1):
                return node_subjects1.value_counts().to_frame()
            @classmethod
            def train_val(cls,node_subjects1):
                train_subjects, test_subjects = model_selection.train_test_split(node_subjects1, train_size=100, test_size=None, stratify=node_subjects1)
                val_subjects, test_subjects = model_selection.train_test_split(test_subjects, train_size=200, test_size=None, stratify=test_subjects)
                return train_subjects,val_subjects, test_subjects
            @classmethod
            def encoding(cls,train_subjects,val_subjects,test_subjects):
                target_encoding = preprocessing.LabelBinarizer()
                train_targets = target_encoding.fit_transform(train_subjects)
                val_targets = target_encoding.transform(val_subjects)
                test_targets = target_encoding.transform(test_subjects)
                return target_encoding,train_targets, val_targets,test_targets
            @classmethod
            def gcn_model(cls,G,target_encoding,train_targets, val_targets,test_targets,node_subjects1):
                generator = FullBatchNodeGenerator(G, method="gcn")
                train_gen = generator.flow(train_subjects.index, train_targets)
                gcn = GCN(layer_sizes=[16, 16], activations=["relu", "relu"], generator=generator, dropout=0.5)
                x_inp, x_out = gcn.in_out_tensors()
                predictions = layers.Dense(units=train_targets.shape[1], activation="softmax")(x_out)
                model = Model(inputs=x_inp, outputs=predictions)
                model.compile(optimizer=optimizers.Adam(lr=0.01),loss=losses.categorical_crossentropy,metrics=["acc"],)
                val_gen = generator.flow(val_subjects.index, val_targets)
                es_callback = EarlyStopping(monitor="val_acc", patience=50, restore_best_weights=True)
                history = model.fit(train_gen,epochs=200,validation_data=val_gen,verbose=2,shuffle=False,  callbacks=[es_callback],)
                # this should be False, since shuffling data means shuffling the whole graph
                sg.utils.plot_history(history)
                test_gen = generator.flow(test_subjects.index, test_targets)
                '''
                test_metrics = model.evaluate(test_gen)
                print("\nTest Set Metrics:")
                for name, val in zip(model.metrics_names, test_metrics):
                    print("\t{}: {:0.4f}".format(name, val))
                '''
                all_nodes = node_subjects1.index
                all_gen = generator.flow(all_nodes)
                all_predictions = model.predict(all_gen)
                node_predictions = target_encoding.inverse_transform(all_predictions.squeeze())
                #mapping categories to numbers
                d_tt1={}
                #margs2={}
                d_tt1["Neural_Networks"]=0
                d_tt1["Probabilistic_Methods"]=1
                d_tt1["Genetic_Algorithms"]=2
                d_tt1["Theory"]=3
                d_tt1["Case_Based"]=4
                d_tt1["Reinforcement_Learning"]=5
                d_tt1["Rule_Learning"]=6
                # mapping and computing f-score
                gcnp={}
                gcnr={}
                for t in range(0,len(node_predictions)):#node_predictions:
                    if str(node_subjects1.index[t]) in WORDS:
                        #print(node_subjects1.index[t],node_subjects1[node_subjects1.index[t]],node_predictions[t])
                        gcnp[node_subjects1.index[t]]=node_predictions[t]
                        gcnr[node_subjects1.index[t]]=node_subjects1[node_subjects1.index[t]]
                p=[]
                tr=[]
                for k in gcnp:
                    p.append(d_tt1[gcnp[k]])
                for k in gcnr:
                    #print(d_tt1[gcnr[k]])
                    tr.append(d_tt1[gcnr[k]])

                rs=f1_score(tr, p, average='micro')
                return rs,gcnp,x_inp, x_out,all_gen


        dataset = sg.datasets.Cora()
        G, node_subjects=gcn.data(dataset)
        node_subjects1=gcn.update_inp_mlev(node_subjects,WORDS)
        train_subjects,val_subjects, test_subjects=gcn.train_val(node_subjects1)
        target_encoding,train_targets, val_targets,test_targets=gcn.encoding(train_subjects,val_subjects,test_subjects)
        rs,gcnp,x_inp, x_out,all_gen=gcn.gcn_model(G,target_encoding,train_targets, val_targets,test_targets,node_subjects1)
        print(rs)


        #Embedding Representation
        def embed(x_inp,x_out,all_gen):
            embedding_model = Model(inputs=x_inp, outputs=x_out)
            emb = embedding_model.predict(all_gen)
            emb.shape
            from sklearn.decomposition import PCA
            from sklearn.manifold import TSNE

            transform = TSNE  # or PCA
            X = emb.squeeze(0)
            X.shape
            trans = transform(n_components=2)
            X_reduced = trans.fit_transform(X)
            X_reduced.shape
            fig, ax = plt.subplots(figsize=(7, 7))
            ax.scatter(
                X_reduced[:, 0],
                X_reduced[:, 1],
                c=node_subjects1.astype("category").cat.codes,
                cmap="jet",
                alpha=0.7,
            )
            ax.set(
                aspect="equal",
                xlabel="$X_1$",
                ylabel="$X_2$",
                title=f"{transform.__name__} visualization of GCN embeddings for cora dataset",
            )
        embed(x_inp,x_out,all_gen)
        #MLN explanation of the GCN Prediction Store_Explanation_r
        def gcn_exp(gcnp,Store_Explanation_r):
            for k in gcnp:
                if str(k) in Store_Explanation_r:
                   
                          print(k,gcnp[k],Store_Explanation_r[str(k)])
                          print("\n")



        gcn_exp(gcnp,Store_Explanation_r)

# %%
# MLN Cora Explanation
WORDS,Store_Explanation_r=MLN__Cora_explanation()
# Out:
# C:\Users\khanfarabi\anaconda\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 20601 [('Samelink(20601,31489)', 0.9906811140826661), ('w_1143', 0.0043448840149249305), ('w_801', 0.002298840050872454), ('w_1058', 0.001382655739232927), ('w_1264', 0.00129250611230343)]
#
#
# 34257 [('Samelink(34257,31489)', 0.9859020927680061), ('w_90', 0.0012856986643300684), ('w_1210', 0.0012841646730579323), ('w_399', 0.0012042321027705065), ('w_786', 0.001159578421414569), ('w_1178', 0.0010570591951535886), ('w_1209', 0.000642521289137876), ('w_1072', 0.0006302430317785843), ('w_912', 0.0005991884064232915), ('w_293', 0.0005802649926126838), ('w_1076', 0.0005261034457494738), ('w_1275', 0.00048461798352835334), ('w_20', 0.000483555498615639), ('w_86', 0.0004532108708065865), ('w_1393', 0.0004521000632643113), ('w_989', 0.00044676984380003496), ('w_1430', 0.00044251509721344214), ('w_1006', 0.00042652130702681875), ('w_600', 0.00042191363174146177), ('w_769', 0.00042031501280384657), ('w_692', 0.00038255921474538666), ('w_169', 0.0003708313137939588), ('w_386', 0.0003439431722255325)]
#
#
# 38205 [('Samelink(38205,31489)', 0.9894541823643884), ('w_1167', 0.0017974537272746696), ('w_861', 0.0015040664745378295), ('w_1382', 0.0014965777544962916), ('w_234', 0.0014866921125543434), ('w_938', 0.0011267859396372048), ('w_1263', 0.0008778610680334654), ('w_795', 0.000610870276971128), ('w_931', 0.0005708746421639115), ('w_1036', 0.0005377089927727914), ('w_300', 0.0005369266471696912)]
#
#
# 22563 [('Samelink(22563,31489)', 0.9806481351441817), ('w_845', 0.0021449749272716883), ('w_1160', 0.0020169159889849657), ('w_704', 0.001909872872913165), ('w_1297', 0.0015849918925646426), ('w_89', 0.0011802842556799388), ('w_1264', 0.0011650856133627804), ('w_508', 0.001148366412358107), ('w_761', 0.001147362384394855), ('w_1302', 0.0010549953007769728), ('w_648', 0.0009196029798099301), ('w_418', 0.0008572057887936254), ('w_1097', 0.0007368683154892706), ('w_1263', 0.0006256942294039539), ('w_1172', 0.0005541175973556012), ('w_1401', 0.0004484682879011313), ('w_25', 0.00039054699285911217), ('w_1268', 0.0003808556524066687), ('w_1008', 0.00038034173073691496), ('w_906', 0.000360029644202481), ('w_1321', 0.00034528398855234675)]
#
#
# 8224 [('Samelink(8224,31489)', 0.9729508421369786), ('w_818', 0.003369527443604049), ('w_426', 0.002333238225277836), ('w_206', 0.0019813183660886877), ('w_815', 0.0016961264141831965), ('w_704', 0.0016492490775502128), ('w_332', 0.0014051257460531055), ('w_221', 0.0013598235634403298), ('w_661', 0.0013249626048509168), ('w_875', 0.0012497137538980162), ('w_764', 0.0012187655158002611), ('w_1206', 0.001070764838133226), ('w_1204', 0.001054693843304031), ('w_1250', 0.0009730130190830536), ('w_399', 0.0009375256308699028), ('w_1382', 0.0009211225950883916), ('w_26', 0.0008722160664005656), ('w_465', 0.0008377259366637995), ('w_1349', 0.0008269354036903251), ('w_94', 0.0007084195053671924), ('w_506', 0.0006363146484530695), ('w_1248', 0.0006225756652213818)]
#
#
# 123825 [('Samelink(123825,31489)', 0.9042781119681442), ('w_1361', 0.009128139062657635), ('w_1135', 0.007787293023038887), ('w_716', 0.007680257135324025), ('w_923', 0.006155740814666749), ('w_89', 0.005948053041956075), ('w_1264', 0.005871459348332587), ('w_1210', 0.005834452341816035), ('w_1302', 0.005316658235367916), ('w_541', 0.005267375348821459), ('w_913', 0.00451391907020713), ('w_195', 0.004021274500668486), ('w_129', 0.0038774239744386874), ('w_1145', 0.0029407588514827167), ('w_20', 0.0021969779814747788), ('w_1389', 0.002137116158257272), ('w_775', 0.0020984493165515914), ('w_86', 0.002059110705963708), ('w_878', 0.0019712759215837934), ('w_122', 0.0019392764579528538), ('w_655', 0.0019347172941396804), ('w_679', 0.001928578839406543), ('w_97', 0.001907458612571465), ('w_1330', 0.0017862696011776765), ('w_174', 0.0014198523939981558)]
#
#
# 84021 [('Samelink(84021,31489)', 0.9866034395937913), ('w_1337', 0.0015084574658417943), ('w_730', 0.001341449547410757), ('w_180', 0.0010717721265697908), ('w_781', 0.0008253422598747407), ('w_626', 0.0008118565098184346), ('w_1264', 0.0007694352764453043), ('w_508', 0.0007583937333179756), ('w_616', 0.0007455551193482968), ('w_399', 0.0007169941530418976), ('w_1302', 0.0006967304304435412), ('w_1178', 0.0006293680932443412), ('w_370', 0.0005479121401877284), ('w_1306', 0.0005463833488873154), ('w_1171', 0.0005215555984105277), ('w_1152', 0.000498999424174709), ('w_912', 0.0003567539704244747), ('w_1076', 0.0003132395271889329), ('w_511', 0.0002592813762159219), ('w_496', 0.00024382325161870872), ('w_193', 0.00023325705374377644)]
#
#
# 112378 [('Samelink(112378,31489)', 0.994169627184656), ('w_1115', 0.0006741054679997253), ('w_1361', 0.0005895193901779562), ('w_339', 0.0005014348225582263), ('w_1167', 0.0004169636010944778), ('w_1264', 0.00037919439118140765), ('w_1382', 0.0003471680190503756), ('w_1302', 0.00034336386630224794), ('w_925', 0.0003421411747232165), ('w_1353', 0.0002954847618115571), ('w_1171', 0.00025703391001282404), ('w_676', 0.00024329113970032853), ('w_1175', 0.00018327127509250155), ('w_5', 0.0001720261343907226), ('w_945', 0.00013976226860847038), ('w_237', 0.0001311643252634941), ('w_1103', 0.00012733312304849835), ('w_858', 0.00012484102170210785), ('w_171', 0.00012459868116743234), ('w_1398', 0.00011630486274186532), ('w_193', 0.00011495413479320463), ('w_855', 0.00010567844024678734), ('w_187', 0.00010073800367666147)]
#
#
# 35 [('Samelink(35,31489)', 0.9909906230268865), ('w_661', 0.0010909367332777881), ('w_508', 0.000816503809748135), ('w_1250', 0.0008011513989820587), ('w_465', 0.0006897598418099598), ('w_1306', 0.0005882486449322871), ('w_1152', 0.0005372340421620391), ('w_100', 0.0005177419830915632), ('w_1248', 0.0005126111936655615), ('w_1175', 0.00040037603087837107), ('w_20', 0.0003099668282336636), ('w_866', 0.00030933854336279864), ('w_775', 0.0002960656339504889), ('w_581', 0.00029436919417419837), ('w_749', 0.0002935825157580678), ('w_1228', 0.0002773019974452686), ('w_639', 0.0002714841280156681), ('w_496', 0.00026250561562641953), ('w_192', 0.0002603007132715056), ('w_141', 0.0002594250363388869), ('w_386', 0.00022047308838920736)]
#
#
# 78557 [('Samelink(78557,31489)', 0.9979087647271935), ('w_1210', 0.0005673323502643793), ('w_699', 0.0004337301463318507), ('w_620', 0.0003869646395361043), ('w_1390', 0.0003782404964385263), ('w_1061', 0.00032496764023568376)]
#
#
# 35061 [('Samelink(35061,31489)', 0.9972623587345243), ('w_1264', 0.0008262129946290425), ('w_508', 0.0008143566804050552), ('w_20', 0.0003091517201296523), ('w_300', 0.00027138478798894694), ('w_496', 0.0002618153144872141), ('w_394', 0.0002547197678358158)]
#
#
# 910 [('Samelink(910,31489)', 0.9922697257059241), ('w_1423', 0.0009291015220289263), ('w_726', 0.0008999487375280155), ('w_725', 0.0007138754443204986), ('w_1111', 0.0006371452361366641), ('w_472', 0.0006145423427480705), ('w_1264', 0.0005983581974451535), ('w_1382', 0.0005478214734199706), ('w_1178', 0.0004894337046034141), ('w_1267', 0.0003323640379061399), ('w_253', 0.00022399269061610893), ('w_20', 0.00022389319363937403), ('w_1075', 0.0002093725096325487), ('w_298', 0.00020330997404736527), ('w_565', 0.00019956660563723603), ('w_423', 0.00019674418001012735), ('w_170', 0.00019500099785106452), ('w_68', 0.0001760558917806921), ('w_82', 0.00017445515402558082), ('w_587', 0.00016529240069899323)]
#
#
# 83725 [('Samelink(83725,31489)', 0.9866197062336479), ('w_941', 0.0013292918115468723), ('w_180', 0.0009914747996895114), ('w_875', 0.0008841424362957857), ('w_1258', 0.0008417614815630062), ('w_1380', 0.00079295454003262), ('w_1210', 0.0007073027619527939), ('w_508', 0.0007015747621966703), ('w_133', 0.0006958858625225858), ('w_399', 0.0006632768446226949), ('w_1302', 0.0006445312831305607), ('w_26', 0.0006170718978793075), ('w_593', 0.0005521618398282099), ('w_55', 0.0005174281748322335), ('w_817', 0.00046977347868782277), ('w_1263', 0.0003822571571912353), ('w_1172', 0.00033852864156437616), ('w_625', 0.00025051243774816285), ('w_1407', 0.0002483380863281734), ('w_735', 0.00024319402780604584), ('w_511', 0.00023985597700665922), ('w_549', 0.0002365674116504532), ('w_808', 0.0002331866993222868), ('w_496', 0.00022555597739979373), ('w_1292', 0.00021314460431747192), ('w_960', 0.00018690816172317224), ('w_150', 0.00017361260951397636)]
#
#
# 20602 [('Samelink(20602,31489)', 0.9559419864767572), ('w_959', 0.004355326311317192), ('w_474', 0.00432983788629237), ('w_1091', 0.004329329293855103), ('w_1212', 0.003335178590435077), ('w_480', 0.0033089498229311996), ('w_206', 0.0025269423449713222), ('w_381', 0.002401332521036089), ('w_442', 0.0022563931700697705), ('w_698', 0.0019416515778676504), ('w_1315', 0.0018673583307984008), ('w_1426', 0.001758969508186288), ('w_282', 0.001683757434893048), ('w_1214', 0.0016682838951099785), ('w_435', 0.0014083564083512436), ('w_923', 0.0013452870585985359), ('w_1264', 0.0012831596576612584), ('w_1199', 0.001140698288329183), ('w_809', 0.0011024292273077647), ('w_1178', 0.0010495746319316762), ('w_724', 0.0009651975632996703)]
#
#
# 6125 [('Samelink(6125,31489)', 0.9901887129736267), ('w_828', 0.0010360133857147446), ('w_962', 0.000714639360078244), ('w_1337', 0.0006089777639063714), ('w_346', 0.0005721584590377619), ('w_1115', 0.0005522127184506385), ('w_730', 0.0005415551742584525), ('w_970', 0.00048292093681602603), ('w_726', 0.00046719370972442476), ('w_785', 0.00042438526645692493), ('w_339', 0.0004107646349648132), ('w_1309', 0.00039869861423674226), ('w_1258', 0.0003673484343357753), ('w_1092', 0.00035877784846015886), ('w_1204', 0.00032563212371543705), ('w_1329', 0.0003235339669924066), ('w_1064', 0.000311573521884711), ('w_1264', 0.0003106278995137973), ('w_508', 0.00030617032984675725), ('w_1356', 0.0002934004581320143), ('w_1077', 0.00028351828220391786), ('w_40', 0.0002685924647661391), ('w_1353', 0.0002420547693595713), ('w_620', 0.00021053690351753243)]
#
#
# 14429 [('Samelink(14429,31489)', 0.9898097416154473), ('w_1386', 0.0013857433837784483), ('w_1092', 0.0008891088464881107), ('w_736', 0.0008460656446524495), ('w_1213', 0.0008330284896202867), ('w_127', 0.0008222902696889614), ('w_90', 0.0007658474715739539), ('w_1353', 0.0005998504024033491), ('w_251', 0.0005171962101081199), ('w_62', 0.0004900203804545628), ('w_697', 0.0004855302013984261), ('w_703', 0.0004433860048793009), ('w_1387', 0.00043891433263602267), ('w_1072', 0.0003754145864468436), ('w_1076', 0.00031338213602603675), ('w_1202', 0.00026759516774664874), ('w_1006', 0.00025406440375289106), ('w_303', 0.000232308846246892), ('w_1292', 0.00023051160665154847)]
#
#
# 6923 [('Samelink(6923,31489)', 0.94063052794341), ('w_480', 0.007609411011066087), ('w_306', 0.005512464779415045), ('w_1020', 0.00535595159195166), ('w_815', 0.004974622689223161), ('w_726', 0.004438110231636582), ('w_48', 0.0037776785835523284), ('w_1058', 0.003156625155133135), ('w_1264', 0.0029508121157648596), ('w_1094', 0.002786584115465848), ('w_1022', 0.002769857490973607), ('w_1349', 0.0024253449432310357), ('w_676', 0.001893241196024237), ('w_697', 0.0018611785436633127), ('w_1133', 0.0016843794431992568), ('w_1076', 0.0012012849166933984), ('w_784', 0.0010863567728143526), ('w_909', 0.0010439842288290314), ('w_988', 0.0010340920912320125), ('w_654', 0.0009957056905385649), ('w_1006', 0.0009739027883570631), ('w_614', 0.0009503574182926037), ('w_1059', 0.0008875262595320818)]
#
#
# 10796 [('Samelink(10796,31489)', 0.9749898211039626), ('w_206', 0.0031533943958274332), ('w_815', 0.0026994932367475767), ('w_875', 0.0019889990500164116), ('w_764', 0.0019397429575839522), ('w_1204', 0.0016786124389258077), ('w_1264', 0.0016012666381063714), ('w_508', 0.001578288156115416), ('w_9', 0.0015674694134101665), ('w_1250', 0.0015486122038533053), ('w_1178', 0.0013097737544041789), ('w_1248', 0.000990868831223343), ('w_302', 0.0006124588258803088), ('w_1238', 0.0005598082596205628), ('w_787', 0.0005416472010148778), ('w_604', 0.0005336066485469279), ('w_1294', 0.000483480604396908), ('w_169', 0.00045948715487780764), ('w_248', 0.00045387016927767347), ('w_494', 0.0004495608284905088), ('w_296', 0.00043434047356421987), ('w_187', 0.00042539765415386806)]
#
#
# 66556 [('Samelink(66556,31489)', 0.9884810259981003), ('w_508', 0.0011674749033974514), ('w_700', 0.0011595637915061492), ('w_1094', 0.0011185502793303968), ('w_1234', 0.0010902268180267272), ('w_1302', 0.0010725501230310051), ('w_55', 0.0008610406773127913), ('w_152', 0.0007579864627388524), ('w_1231', 0.0007452785421721145), ('w_183', 0.000426395878296614), ('w_1066', 0.000419099585096919), ('w_1017', 0.00041392692638738245), ('w_18', 0.0004054836761056078), ('w_373', 0.00039992466143030854), ('w_1396', 0.00038347986635392826), ('w_496', 0.00037534266783063554), ('w_93', 0.0003699144368828448), ('w_463', 0.00035273470599981433)]
#
#
# 2698 [('Samelink(2698,31489)', 0.9535041237602486), ('w_1361', 0.0068979494859344485), ('w_1297', 0.006036052740843932), ('w_1427', 0.005060672698121767), ('w_616', 0.004299237956358387), ('w_913', 0.003411077057016218), ('w_1076', 0.0018062933641976493), ('w_20', 0.001660211685415649), ('w_542', 0.0016469279471828303), ('w_775', 0.001585755572412608), ('w_565', 0.0014798252921941844), ('w_883', 0.001463134175246851), ('w_423', 0.0014588964558540772), ('w_1428', 0.001443390041180369), ('w_1188', 0.001425526578570663), ('w_1224', 0.0014173746351482193), ('w_178', 0.0013730838639690822), ('w_1369', 0.001370558190797609), ('w_1307', 0.0013544197344656885), ('w_68', 0.0013054887648410209)]
#
#
# 7419 [('Samelink(7419,31489)', 0.9984668872694582), ('w_1146', 0.0011747180408388153), ('w_1133', 0.00035839468970301204)]
#
#
# 22229 [('Samelink(22229,31489)', 0.9887812997801272), ('w_815', 0.0012681343412187902), ('w_980', 0.0007653611375781957), ('w_1264', 0.000752223115653069), ('w_1210', 0.0007474819560722266), ('w_133', 0.0007354165057764998), ('w_40', 0.0006504292145153825), ('w_1178', 0.0006152892159819544), ('w_7', 0.0006096381210819655), ('w_62', 0.0004788406900431074), ('w_506', 0.00047575018629286177), ('w_1133', 0.0004293832013011471), ('w_625', 0.0002647431016265651), ('w_762', 0.0002642511802107808), ('w_84', 0.00026316387067964466), ('w_1407', 0.00026244523352816424), ('w_155', 0.0002607199866976438), ('w_1195', 0.00025671844356704466), ('w_511', 0.00025348128766464304), ('w_1055', 0.0002511383133187157), ('w_122', 0.00024845076713819265), ('w_300', 0.0002470814573105933), ('w_538', 0.00024384183640265656), ('w_651', 0.00023577132223925976), ('w_1307', 0.00022962339184314138), ('w_39', 0.00022408695550541215), ('w_780', 0.00018523538662565246)]
#
#
# 227178 [('Samelink(227178,31489)', 0.9802834509648309), ('w_221', 0.001554283162291226), ('w_1305', 0.0014709303116940378), ('w_764', 0.001393053312884919), ('w_476', 0.0013824415062190377), ('w_1427', 0.001311630897650304), ('w_1111', 0.0012245158305654903), ('w_1260', 0.001175460604697306), ('w_1210', 0.001142723733214298), ('w_925', 0.0010376016322472198), ('w_1178', 0.0009406321907594766), ('w_648', 0.0009076736736562021), ('w_42', 0.0008723540870870353), ('w_1139', 0.0008315886109446283), ('w_1076', 0.00046815716566330363), ('w_777', 0.00045234421405607086), ('w_353', 0.0004172815060024524), ('w_1230', 0.00040187317618622806), ('w_878', 0.00038609001296710136), ('w_300', 0.0003777293124099283), ('w_464', 0.0003741150030253297), ('w_56', 0.00034911758912409356), ('w_220', 0.00034314719874492186), ('w_82', 0.0003352816370775527), ('w_268', 0.00028334141886982044), ('w_780', 0.00028318124713074173)]
#
#
# 579008 [('Samelink(579008,31489)', 0.988245222729324), ('w_206', 0.0017086957324888175), ('w_1297', 0.0011803731015088757), ('w_221', 0.001172716489967783), ('w_508', 0.0008552099415666104), ('w_1382', 0.0007943792750650291), ('w_204', 0.0006687700245659574), ('w_94', 0.0006109434033170303), ('w_620', 0.0005880819772607074), ('w_1152', 0.0005627014697539699), ('w_100', 0.0005422853951445731), ('w_1133', 0.000495277356706406), ('w_602', 0.0003209911239622501), ('w_1050', 0.00030368600142080104), ('w_1165', 0.000301200221822407), ('w_1424', 0.00030114924101295293), ('w_97', 0.00028187669052281755), ('w_496', 0.00027494961997792455), ('w_1123', 0.00026932771299685587), ('w_533', 0.000263255756845861), ('w_220', 0.00025890673476846275)]
#
#
# 73327 [('Samelink(73327,31489)', 0.9903750743899968), ('w_1322', 0.0012262555005596834), ('w_442', 0.001197623315978909), ('w_698', 0.0010305682679803683), ('w_589', 0.0008495855736872601), ('w_3', 0.0007112368971535629), ('w_1210', 0.0006767686012752082), ('w_79', 0.00045534516243948505), ('w_1390', 0.0004512016485593559), ('w_396', 0.0004354554959921011), ('w_229', 0.00037473926892641067), ('w_1072', 0.0003321448596343665), ('w_5', 0.00030897169012206264), ('w_625', 0.00023969785107128152), ('w_751', 0.00023523426214870754), ('w_850', 0.00023157361167279567), ('w_565', 0.00022715002473461777), ('w_162', 0.0002179182110964084), ('w_832', 0.00021456321149672207), ('w_1398', 0.00020889215547417785)]
#
#
# 6910 [('Samelink(6910,31489)', 0.9980185508231324), ('w_1333', 0.0005228602577011438), ('w_1274', 0.0005149940819515994), ('w_1390', 0.00031773092804771497), ('w_172', 0.0001658842723566814), ('w_534', 0.000157001764336455), ('w_1242', 0.000156115342132761), ('w_821', 0.00014686253034129287)]
#
#
# 36145 [('Samelink(36145,31489)', 0.9801760764926676), ('w_1160', 0.0019025987870687606), ('w_958', 0.0016958138425717559), ('w_1297', 0.0014951558065762287), ('w_936', 0.0013225647397459932), ('w_1329', 0.0011447131429313342), ('w_1332', 0.001070899797793117), ('w_616', 0.0010649394348074275), ('w_1356', 0.0010380961346592524), ('w_756', 0.00094191467131163), ('w_204', 0.000847118071578997), ('w_1171', 0.0007449819735359928), ('w_1097', 0.0006951032025805104), ('w_1231', 0.0006915298833623743), ('w_1180', 0.0006489647680361194), ('w_1387', 0.0006266531670234759), ('w_820', 0.000626040159445914), ('w_1267', 0.0006104780139493108), ('w_20', 0.00041124145996906166), ('w_105', 0.00035099676024108163), ('w_110', 0.00034662704413260015), ('w_336', 0.00034456760026962507), ('w_991', 0.0003251363704748469), ('w_338', 0.0003145564479469802), ('w_558', 0.0002974570687286373), ('w_174', 0.0002657751585914436)]
#
#
# 50336 [('Samelink(50336,31489)', 0.9832683357302753), ('w_940', 0.00190083060745278), ('w_467', 0.0017828681627170648), ('w_765', 0.0015878125497184132), ('w_572', 0.0014698490461844732), ('w_475', 0.0014464271757793827), ('w_1232', 0.0013332918364818039), ('w_1282', 0.0013132570189860015), ('w_1154', 0.0013005288862545266), ('w_371', 0.001287149562283319), ('w_1171', 0.0006693731236576561), ('w_620', 0.0006693103243022667), ('w_20', 0.00036950421676710035), ('w_78', 0.0003554095977450965), ('w_939', 0.00034265358781648445), ('w_289', 0.00033321164378947), ('w_961', 0.0003119972864735424), ('w_182', 0.0002581896433150121)]
#
#
# 56167 [('Samelink(56167,31489)', 0.989310989832916), ('w_567', 0.0012059621279576092), ('w_997', 0.0011817824253397137), ('w_1419', 0.000858314821306856), ('w_1377', 0.0008455747844739835), ('w_736', 0.0007228202789666709), ('w_399', 0.0006128293528238121), ('w_1173', 0.0005400957029275102), ('w_593', 0.0005101655299732578), ('w_370', 0.00046831154877762903), ('w_1390', 0.0004356929703270152), ('w_703', 0.0003787984983936153), ('w_759', 0.0003433985943619584), ('w_1172', 0.0003127808395606434), ('w_5', 0.0002983517321934843), ('w_1076', 0.0002677321368823119), ('w_63', 0.0002314365445193357), ('w_237', 0.00022748347966402665), ('w_751', 0.00022714880303628042), ('w_729', 0.00021663255127560418), ('w_1278', 0.00021593557410503993), ('w_93', 0.00020538674294640508), ('w_1398', 0.00020171212580262637), ('w_203', 0.0001806630014688358)]
#
#
# 37888 [('Samelink(37888,31489)', 0.9870880420856699), ('w_731', 0.0014180697004079071), ('w_934', 0.0013826525964909903), ('w_475', 0.001150053619807404), ('w_914', 0.0010396638003717638), ('w_1309', 0.001007779536552265), ('w_337', 0.0009114257393702557), ('w_1176', 0.0007957216934151153), ('w_508', 0.0007738983334810506), ('w_1332', 0.0007650553554949589), ('w_1382', 0.000718851322049123), ('w_293', 0.0003525501953059281), ('w_20', 0.00029379264241086075), ('w_262', 0.0002859244377550298), ('w_1142', 0.0002832594596265967), ('w_78', 0.00028258601694260816), ('w_103', 0.00026626355516936445), ('w_1350', 0.00026381795853650544), ('w_549', 0.0002609545489620811), ('w_336', 0.00024616055438573284), ('w_1412', 0.00023102411646240632), ('w_1082', 0.0001824527313323166)]
#
#
# 12195 [('Samelink(12195,31489)', 0.9697781048865252), ('w_1316', 0.003426345203164189), ('w_439', 0.0027068022030761565), ('w_368', 0.002213484891999781), ('w_922', 0.001948288404257538), ('w_719', 0.0019313011091928762), ('w_631', 0.001881374494575168), ('w_730', 0.0018086170139768546), ('w_572', 0.0015441068313083739), ('w_459', 0.0014458875479498436), ('w_281', 0.001425039411790887), ('w_716', 0.0013569819298975838), ('w_702', 0.0013416458400614154), ('w_1111', 0.0011046420146297697), ('w_1132', 0.0010826134076489594), ('w_472', 0.001065454551123596), ('w_1264', 0.001037395506091922), ('w_1210', 0.0010308569438748326), ('w_508', 0.0010225086825067999), ('w_1178', 0.0008485491263484243)]
#
#
# 154982 [('Samelink(154982,31489)', 0.9846619639146963), ('w_1063', 0.002095515133796294), ('w_1160', 0.001491897352718937), ('w_869', 0.0010675088676434172), ('w_531', 0.000989543248780419), ('w_736', 0.0009472034348151664), ('w_1333', 0.0009395494229252144), ('w_646', 0.0009081952959868439), ('w_1132', 0.0008993692051709675), ('w_616', 0.0008350579924645893), ('w_399', 0.0008030683211878119), ('w_53', 0.0007148791098006215), ('w_136', 0.0006415590318603714), ('w_515', 0.0005982244004865369), ('w_817', 0.0005687824050046444), ('w_1172', 0.00040987655465304636), ('w_1113', 0.00030243781796091473), ('w_1055', 0.0002877234586014209), ('w_883', 0.00028419033779718473), ('w_163', 0.0002811720002145796), ('w_961', 0.0002722826934348133)]
#
#
# 3233 [('Samelink(3233,31489)', 0.9899532263637362), ('w_1115', 0.0008949953337380409), ('w_730', 0.0008777221851805868), ('w_314', 0.000810402457393285), ('w_755', 0.0007722454744502042), ('w_1281', 0.0006784935697745539), ('w_1335', 0.0006019994952084822), ('w_1354', 0.0005677459331385264), ('w_1333', 0.0005488649298345606), ('w_1210', 0.0005002750733815549), ('w_1382', 0.0004609275133090777), ('w_541', 0.0004516510607642798), ('w_1199', 0.00044755345987483125), ('w_465', 0.0004191960276296443), ('w_136', 0.00037478523685368693), ('w_540', 0.00036532513526800573), ('w_152', 0.000322174648961942), ('w_1097', 0.0003184101249454565), ('w_886', 0.00017721954131582279), ('w_163', 0.00016425474424617062), ('w_1321', 0.00014920158137566054), ('w_278', 0.0001433301096192381)]
#
#
# 12182 [('Samelink(12182,31489)', 0.9688227594227032), ('w_260', 0.0033191952931373786), ('w_1316', 0.003248709566969547), ('w_238', 0.0022907632834437077), ('w_4', 0.0017818246419347172), ('w_1423', 0.001527306008063446), ('w_134', 0.0014728978173545954), ('w_1315', 0.0014314332478724441), ('w_180', 0.0013701070418604428), ('w_1377', 0.001264678452902205), ('w_725', 0.0011735060477984173), ('w_1092', 0.0011360809956307083), ('w_1208', 0.0011228282613880104), ('w_1427', 0.0011218855737972339), ('w_1329', 0.0010244801704414658), ('w_360', 0.0010223002729163972), ('w_508', 0.0009694976840341696), ('w_1356', 0.0009290614959193602), ('w_1326', 0.0009092630427144105), ('w_1077', 0.0008977692845535397), ('w_1302', 0.000890669989790029), ('w_53', 0.0008159203519005804), ('w_522', 0.0007962017008068966), ('w_251', 0.0006608603520670502)]
#
#
# 3220 [('Samelink(3220,31489)', 0.9313820826343604), ('w_275', 0.005949575133827727), ('w_726', 0.005925881537031433), ('w_282', 0.005170056246243985), ('w_716', 0.00515378314214929), ('w_1262', 0.004699292789551068), ('w_232', 0.004293080931351349), ('w_1026', 0.004151629661140233), ('w_360', 0.004094970536861968), ('w_1264', 0.003940001965568915), ('w_508', 0.0038834621850878702), ('w_9', 0.0038568420916510423), ('w_757', 0.0032632134055892684), ('w_94', 0.0027742610190713973), ('w_1267', 0.0021885134493451054), ('w_261', 0.0014809397248749657), ('w_262', 0.001434783735506464), ('w_1169', 0.001423379607848287), ('w_274', 0.001293144995682553), ('w_83', 0.0012828378190275565), ('w_87', 0.0012049919469270896), ('w_284', 0.0011532754413019956)]
#
#
# 643221 [('Samelink(643221,31489)', 0.9849433013830375), ('w_1012', 0.0013845912124329021), ('w_972', 0.0012049673497821635), ('w_781', 0.001088469901179591), ('w_508', 0.0010001774925291228), ('w_1332', 0.0009887489273468775), ('w_1382', 0.0009290353547530175), ('w_1255', 0.0008595613216789749), ('w_1276', 0.0008400298787800446), ('w_648', 0.0008009344339668698), ('w_699', 0.0007708866658736284), ('w_649', 0.0006378925903889963), ('w_277', 0.0003642609133438265), ('w_103', 0.0003441160207223854), ('w_822', 0.00033965544164256373), ('w_549', 0.0003372547208765288), ('w_1237', 0.0003366301749043049), ('w_627', 0.00033590273174280205), ('w_1415', 0.0003288053323499114), ('w_1413', 0.00032589830832366475), ('w_683', 0.00032262257700201935), ('w_1002', 0.00031768561273042565), ('w_173', 0.00031116257164689017), ('w_598', 0.0003086021315199024), ('w_686', 0.00029600726415559924), ('w_855', 0.00028279968728966775)]
#
#
# 31353 [('Samelink(31353,31489)', 0.9716187379485922), ('w_1274', 0.002624295041257528), ('w_1206', 0.002600997112858475), ('w_1210', 0.00242850742881621), ('w_1382', 0.002237500826596548), ('w_522', 0.0019782645339388107), ('w_699', 0.0018566134682388396), ('w_94', 0.0017208233054842221), ('w_620', 0.0016564303117294306), ('w_1390', 0.0016190859820562667), ('w_1152', 0.0015849419077537397), ('w_649', 0.0015363088078113388), ('w_846', 0.0009285501763733417), ('w_737', 0.0008418372177346258), ('w_510', 0.0008250620883701455), ('w_903', 0.0008077460080593498), ('w_457', 0.0008001822073678011), ('w_1313', 0.0007926625051193825), ('w_1397', 0.0007805476656971692), ('w_255', 0.0007609054561446232)]
#
#
# 23738 [('Samelink(23738,31489)', 0.9959246288121911), ('w_1264', 0.0010947255413619346), ('w_616', 0.0010607496908828621), ('w_399', 0.0010201141491306828), ('w_1349', 0.0008997818064332501)]
#
#
# 10169 [('Samelink(10169,31489)', 0.9402268188644848), ('w_995', 0.006425053455647415), ('w_1328', 0.006397803620465326), ('w_1290', 0.006394592077166955), ('w_1063', 0.004659146755767442), ('w_470', 0.004423361107359164), ('w_346', 0.003529396297966563), ('w_815', 0.0032303021840565604), ('w_1297', 0.0026067163033120793), ('w_716', 0.0025064224091468387), ('w_1124', 0.002327428005986906), ('w_727', 0.002252013931449178), ('w_1333', 0.0020889845055782467), ('w_1119', 0.0019827765526615384), ('w_1264', 0.001916128200626269), ('w_90', 0.0019063255791515734), ('w_508', 0.0018886313950957914), ('w_1178', 0.0015673182513949774), ('w_94', 0.0013491972392387622), ('w_1097', 0.0012118715940382337), ('w_131', 0.0011097116694053883)]
#
#
# 19697 [('Samelink(19697,31489)', 0.8615520957669949), ('w_1157', 0.013124628648742918), ('w_1361', 0.012063366815863188), ('w_970', 0.012063349736154978), ('w_974', 0.010899710521333693), ('w_64', 0.008813741155426576), ('w_736', 0.008528381798683322), ('w_1329', 0.008081868268308017), ('w_1264', 0.007759475110663266), ('w_761', 0.007641438330807861), ('w_624', 0.007578566735316844), ('w_40', 0.0067094312794398064), ('w_331', 0.005344575079296939), ('w_129', 0.00512424135776232), ('w_62', 0.004939428660253983), ('w_759', 0.004051677031027242), ('w_20', 0.002903434215340347), ('w_262', 0.0028256759215193198), ('w_775', 0.002773222852576596), ('w_230', 0.002565304783999463), ('w_856', 0.0023940614041957973), ('w_82', 0.002262324526292633)]
#
#
# 12210 [('Samelink(12210,31489)', 0.96659838491922), ('w_1091', 0.004101526376030046), ('w_1337', 0.00238323331360786), ('w_1042', 0.002278545284121911), ('w_1020', 0.002206483432647707), ('w_72', 0.0021865572150667916), ('w_755', 0.0018646878097150171), ('w_726', 0.001828361688908031), ('w_70', 0.001592854614077033), ('w_702', 0.0015721685771628924), ('w_48', 0.0015562846424903797), ('w_979', 0.001499811494030911), ('w_764', 0.0014726044692045966), ('w_1176', 0.001231985268052824), ('w_1264', 0.0012156416902787525), ('w_1210', 0.001207979666702499), ('w_133', 0.0011884811109066729), ('w_325', 0.0011232146235417855), ('w_756', 0.0010418372975117111), ('w_1178', 0.0009943475638570529), ('w_1385', 0.0008550089428653322)]
#
#
# 25772 [('Samelink(25772,31489)', 0.9672648692105609), ('w_537', 0.0027306973481632), ('w_561', 0.0026976395233438808), ('w_970', 0.0026913419808504875), ('w_180', 0.002411369013777551), ('w_875', 0.002150325631389826), ('w_212', 0.0019223816398617466), ('w_435', 0.001900050695400422), ('w_232', 0.0018862790814185855), ('w_1213', 0.001873369285718496), ('w_1111', 0.0018433614732759008), ('w_1026', 0.0018241287105530335), ('w_399', 0.0016131577234037423), ('w_809', 0.0014873162841131176), ('w_756', 0.0014836369010223919), ('w_204', 0.0013343200491477574), ('w_261', 0.0006506901846348686), ('w_720', 0.0006329993016227205), ('w_274', 0.0005681775847233611), ('w_323', 0.0005235754860005823), ('w_473', 0.0005103128910174888)]
#
#
# 16819 [('Samelink(16819,31489)', 0.983925862681419), ('w_914', 0.001388370039989534), ('w_677', 0.0013865545132031123), ('w_1335', 0.0012537613599690248), ('w_972', 0.0012450718785439992), ('w_813', 0.0010499698777552628), ('w_1382', 0.0009599561304173457), ('w_648', 0.0008275916691601518), ('w_42', 0.0007953882501879115), ('w_136', 0.000780550900779843), ('w_620', 0.0007106591485700035), ('w_79', 0.0007010163446690669), ('w_1390', 0.0006946372916035372), ('w_152', 0.0006709808384310689), ('w_649', 0.000659123357963605), ('w_822', 0.0003509600810843965), ('w_1415', 0.0003397488512018171), ('w_1413', 0.00033674507365881077), ('w_683', 0.00033336031725774833), ('w_884', 0.0003277898817962398), ('w_598', 0.00031887323393752485), ('w_56', 0.00031831573031368204), ('w_1292', 0.00031397611215347275), ('w_1321', 0.00031073643593387774)]
#
#
# 35922 [('Samelink(35922,31489)', 0.9909838614181168), ('w_940', 0.001147796140023864), ('w_475', 0.0008734095098615655), ('w_371', 0.0007772314342107418), ('w_337', 0.0006921832987508023), ('w_964', 0.0006138335800119323), ('w_1022', 0.0005597279109257926), ('w_1349', 0.0004901094235978071), ('w_648', 0.0004706560294121653), ('w_1353', 0.0004646589221254867), ('w_699', 0.00045299894960175034), ('w_1098', 0.0004114800724031003), ('w_1061', 0.0003394045835326664), ('w_1172', 0.00028359932919388753), ('w_20', 0.000223121151387686), ('w_1090', 0.00021630472233616642), ('w_641', 0.0002110112874282432), ('w_289', 0.00020120627111801245), ('w_1339', 0.0001971358253695024), ('w_521', 0.0001959446587606478), ('w_52', 0.00019432548183162854)]
#
#
# 103515 [('Samelink(103515,31489)', 0.9764073183833852), ('w_859', 0.002739394391569786), ('w_785', 0.002013221827928818), ('w_1335', 0.0017620291693879542), ('w_835', 0.001618099388453799), ('w_779', 0.0015592810317210637), ('w_1119', 0.0015248285132648798), ('w_508', 0.0014524274046027023), ('w_1302', 0.00133433377194396), ('w_837', 0.001330433497923282), ('w_593', 0.0011431069518967741), ('w_60', 0.00114298167611835), ('w_946', 0.0010291793854577728), ('w_119', 0.0009246539162298238), ('w_1076', 0.0005998964040796564), ('w_929', 0.000552680288630705), ('w_1093', 0.0005114493702358658), ('w_829', 0.0004907631413117289), ('w_763', 0.00047983742033439467), ('w_1067', 0.0004691310096697851), ('w_496', 0.00046695477160789325), ('w_382', 0.00044799828424578415)]
#
#
# 61069 [('Samelink(61069,31489)', 0.9874221523203851), ('w_731', 0.0019680274349907555), ('w_937', 0.0016281904942896564), ('w_180', 0.001517837242276096), ('w_727', 0.0012806821316942484), ('w_1293', 0.001138226375664645), ('w_119', 0.0006837577485129614), ('w_1180', 0.0006434261591051714), ('w_912', 0.0005052328281508747), ('w_929', 0.0004086928343335942), ('w_311', 0.0003752919672033322), ('w_747', 0.00036244036367425955), ('w_549', 0.0003621582997614906), ('w_956', 0.0003571654892565952), ('w_1374', 0.0003459674400164834), ('w_1002', 0.000341144168615685), ('w_193', 0.0003303372371970772), ('w_553', 0.0003292694648718988)]
#
#
# 126927 [('Samelink(126927,31489)', 0.9840146834662319), ('w_940', 0.002003151565256587), ('w_1044', 0.0019115068981461105), ('w_1335', 0.001244375489756916), ('w_279', 0.0011701321745743126), ('w_508', 0.0010257293660845851), ('w_403', 0.0009285190731461241), ('w_809', 0.0008940877998298874), ('w_1178', 0.000851221874544043), ('w_1231', 0.0006547927363526362), ('w_649', 0.0006541890487009806), ('w_759', 0.0005433912266042499), ('w_179', 0.0004078045396232646), ('w_34', 0.0003636730722328293), ('w_215', 0.0003515303631374046), ('w_1296', 0.00035059344306330274), ('w_1350', 0.0003496658613466378), ('w_822', 0.00034833273438520437), ('w_1245', 0.0003472276949798975), ('w_1190', 0.00033100102194611597), ('w_548', 0.00031786637512186666), ('w_598', 0.0003164860948188596), ('w_432', 0.000316468618009611), ('w_686', 0.0003035694621071613)]
#
#
# 35797 [('Samelink(35797,31489)', 0.9852298319405078), ('w_730', 0.001718890039153259), ('w_1157', 0.001667633170596609), ('w_337', 0.0011444738266912103), ('w_1148', 0.0009864625133757295), ('w_1264', 0.0009859294633985892), ('w_235', 0.000976006382417597), ('w_133', 0.000963901249279206), ('w_616', 0.0009553302028846996), ('w_1356', 0.0009312497579894571), ('w_399', 0.0009187331049264348), ('w_541', 0.0008844922945191321), ('w_94', 0.0006942193688641306), ('w_20', 0.0003689143011760913), ('w_775', 0.00035236946828634563), ('w_575', 0.00031631185384912075), ('w_178', 0.0003051118592780545), ('w_177', 0.00030187461744413645), ('w_1392', 0.0002982645853624764)]
#
#
# 6130 [('Samelink(6130,31489)', 0.9858799650908825), ('w_1160', 0.0018397835918140476), ('w_360', 0.0011045645857783565), ('w_1411', 0.0010967849671191996), ('w_1264', 0.0010627638465012074), ('w_1331', 0.0010323066813077196), ('w_1382', 0.0009730038942787824), ('w_925', 0.0009589152143374734), ('w_756', 0.0009108169147095279), ('w_53', 0.0008815773108953262), ('w_1178', 0.0008692994409244941), ('w_611', 0.0008420768853991034), ('w_136', 0.00079116018125892), ('w_510', 0.00035878807974656907), ('w_968', 0.00035367146945535784), ('w_1053', 0.0003489053965020511), ('w_932', 0.0003486683362751795), ('w_1205', 0.00034694811281419546)]
#
#
# 27627 [('Samelink(27627,31489)', 0.8657052425259932), ('w_238', 0.0122371642880893), ('w_1348', 0.01215750989106091), ('w_1254', 0.009779958593362897), ('w_537', 0.008288290570831988), ('w_698', 0.007950882106698833), ('w_275', 0.007934402462853983), ('w_750', 0.007889454665569015), ('w_180', 0.007319056091343316), ('w_702', 0.00679545024430362), ('w_933', 0.006693438990713588), ('w_476', 0.006316612951201697), ('w_1354', 0.005925485188300593), ('w_412', 0.005803693183517241), ('w_1264', 0.005254419113310206), ('w_133', 0.0051370218008270265), ('w_1331', 0.005103835602724322), ('w_541', 0.00471381918324724), ('w_40', 0.004543369680467524), ('w_1255', 0.004450892865583164)]
#
#
# 39890 [('Samelink(39890,31489)', 0.9869411538384557), ('w_459', 0.0016204870434576115), ('w_26', 0.0010079520228435275), ('w_916', 0.0009564843071073285), ('w_1349', 0.0009556246955531335), ('w_1178', 0.0009510164652393819), ('w_540', 0.000843684626520653), ('w_1139', 0.0008407690796498719), ('w_79', 0.0007773381309039886), ('w_229', 0.0006397325521654062), ('w_1263', 0.0006243954329495032), ('w_1209', 0.0005780644338921527), ('w_552', 0.0004088513521348181), ('w_96', 0.00040159464669200324), ('w_883', 0.0003834032076201938), ('w_288', 0.00036049712459733255), ('w_1400', 0.0003587864906519615), ('w_382', 0.0003534760278079419), ('w_19', 0.00034022462649850854), ('w_264', 0.0003345733339392153), ('w_758', 0.0003218905613192745)]
#
#
# 3191 [('Samelink(3191,31489)', 0.9915815740336973), ('w_1277', 0.0008133783589316018), ('w_1377', 0.0007721399142480488), ('w_337', 0.0006971079530858567), ('w_1208', 0.0006855343470696941), ('w_1354', 0.0006772347331996661), ('w_1260', 0.0006138480591449166), ('w_196', 0.0006044718177480499), ('w_1210', 0.0005967522373521516), ('w_1353', 0.0004679648160690371), ('w_1390', 0.0003978547361201852), ('w_1076', 0.00024448064560292685), ('w_1432', 0.00024329611635439175), ('w_277', 0.00021557488084578347), ('w_402', 0.00021435458130053688), ('w_662', 0.00021329754621995538), ('w_199', 0.00020810480598864721), ('w_807', 0.00020557872011407448), ('w_1286', 0.0001973611693067121), ('w_1251', 0.00018530582794810764), ('w_305', 0.0001647846996524478)]
#
#
# 10435 [('Samelink(10435,31489)', 0.9423810599100675), ('w_306', 0.006922850691186938), ('w_727', 0.004355391563252149), ('w_337', 0.004301705901307768), ('w_1204', 0.0038847893728710618), ('w_964', 0.0038147865432806975), ('w_1210', 0.003682431981550213), ('w_235', 0.0036684914211608404), ('w_399', 0.003453219747816192), ('w_1077', 0.003382371484586503), ('w_1340', 0.0031742816311251176), ('w_1259', 0.0029054618846204995), ('w_396', 0.002369399587926576), ('w_697', 0.002337368433724327), ('w_5', 0.0016811761523144776), ('w_1076', 0.0015086384128745074), ('w_667', 0.0013479839738438943), ('w_751', 0.0012799562043223588), ('w_304', 0.001279549883509712), ('w_510', 0.001251070919087053), ('w_203', 0.0010180142995717296)]
#
#
# 1717 [('Samelink(1717,31489)', 0.9821158076323868), ('w_922', 0.0020681628495031476), ('w_707', 0.002050295180197051), ('w_126', 0.0014814685940630888), ('w_24', 0.0012256110680467565), ('w_1264', 0.0011012244600195353), ('w_508', 0.0010854216787585186), ('w_403', 0.0009825542335603367), ('w_1073', 0.0009236992960488878), ('w_447', 0.0009186426824809888), ('w_204', 0.0008487944859925586), ('w_1098', 0.0007599124510921285), ('w_1080', 0.0006536619527981451), ('w_78', 0.00039633757514873796), ('w_1205', 0.0003595039005574369), ('w_503', 0.00035948506828665665), ('w_1128', 0.00035766695754954234), ('w_93', 0.0003439158716902196), ('w_1110', 0.0003430522172312646), ('w_137', 0.00034218160384394034), ('w_598', 0.00033490400070469115), ('w_104', 0.0003256695473277335), ('w_695', 0.00031782089176799573), ('w_587', 0.0003042058009437835)]
#
#
# 67415 [('Samelink(67415,31489)', 0.9941243725559875), ('w_904', 0.0025646094500646806), ('w_4', 0.0013889463562623443), ('w_1414', 0.0013168880018950809), ('w_648', 0.0006051836357904409)]
#
#
# 33818 [('Samelink(33818,31489)', 0.9946638705063813), ('w_1064', 0.0005851968354862386), ('w_1210', 0.0005797435477869768), ('w_508', 0.0005750485697959822), ('w_699', 0.00044321860669396676), ('w_1390', 0.0003865150422319334), ('w_119', 0.000366091214197147), ('w_100', 0.0003646361270402132), ('w_1080', 0.0003463053838362192), ('w_1061', 0.0003320767669575038), ('w_912', 0.0002705070617660519), ('w_2', 0.00019750649746546107), ('w_549', 0.0001939034284870633), ('w_1053', 0.0001915370526437745), ('w_551', 0.00019092304643490517), ('w_424', 0.00016639704706105285), ('w_408', 0.0001465232657343689)]
#
#
# 28287 [('Samelink(28287,31489)', 0.9936984228008119), ('w_306', 0.0009157036263278722), ('w_835', 0.0005382500335708879), ('w_626', 0.0005171992044091363), ('w_1264', 0.0004901744434011301), ('w_1326', 0.00045312296129719265), ('w_1302', 0.00044385728260480867), ('w_837', 0.0004425598823106452), ('w_1178', 0.0004009436066223893), ('w_396', 0.0003134067007462987), ('w_131', 0.00028388095311615325), ('w_1172', 0.00023312817680289988), ('w_1393', 0.00017148200474531198), ('w_989', 0.00016946024718821954), ('w_1312', 0.00016321053208456454), ('w_549', 0.000162912446976997), ('w_924', 0.000153643028262945), ('w_137', 0.00015231107126274148), ('w_582', 0.00015030823319720995), ('w_39', 0.0001460227642605163)]
#
#
# 6898 [('Samelink(6898,31489)', 0.9959288705856082), ('w_704', 0.0013854521785247903), ('w_1411', 0.000872227221419311), ('w_1255', 0.0007159247048753808), ('w_534', 0.0002766779031257686), ('w_163', 0.00027574523450264385), ('w_1242', 0.00027511579688041066), ('w_1102', 0.0002699863750635307)]
#
#
# 6214 [('Samelink(6214,31489)', 0.9877516242980908), ('w_4', 0.0018299466453344391), ('w_337', 0.0011726208728468877), ('w_212', 0.0011217702012798916), ('w_1264', 0.001010177289312401), ('w_1382', 0.0009248587441592404), ('w_1178', 0.0008262856849382799), ('w_1353', 0.0007871740792102588), ('w_506', 0.0006388955930474829), ('w_1133', 0.0005766283292026937), ('w_820', 0.0005754168134281733), ('w_1267', 0.000561113066237759), ('w_293', 0.00045358354486194324), ('w_1076', 0.0004112463597238094), ('w_667', 0.0003674528617848794), ('w_625', 0.00035552944758031763), ('w_592', 0.00032591305173502755), ('w_582', 0.0003097631172260821)]
#
#
# 20534 [('Samelink(20534,31489)', 0.9884125152415374), ('w_1264', 0.0014524364183869983), ('w_508', 0.0014315936784655683), ('w_1360', 0.001426504864392335), ('w_1356', 0.001371884210109205), ('w_1382', 0.0013297651175615812), ('w_341', 0.0005068906236068316), ('w_735', 0.0004962479433519271), ('w_510', 0.0004903411752504166), ('w_1256', 0.000474677228694671), ('w_1156', 0.0004740055842599475), ('w_582', 0.00044537848681837263), ('w_1059', 0.00043685446956525525), ('w_153', 0.0004286160671288124), ('w_169', 0.00041677998007551157), ('w_1032', 0.0004055089107948816)]
#
#
# 2354 [('Samelink(2354,31489)', 0.9741685866961531), ('w_696', 0.003400005891898721), ('w_1343', 0.0018998157805198684), ('w_730', 0.001775978093243207), ('w_1291', 0.001587741102982727), ('w_701', 0.001411339073340899), ('w_860', 0.001366905862821727), ('w_702', 0.0013174340407208212), ('w_1370', 0.0011523292640438208), ('w_1167', 0.0011201381651705187), ('w_1204', 0.0010678792220326601), ('w_1119', 0.0010541066826742446), ('w_980', 0.0010364660620318827), ('w_188', 0.0010229114675330408), ('w_1264', 0.0010186743122564594), ('w_235', 0.0010084216643044114), ('w_1302', 0.0009224185760485775), ('w_40', 0.0008808231480532581), ('w_811', 0.0008504075632541312), ('w_699', 0.0007738761339440948), ('w_1394', 0.0007490356724155639), ('w_1076', 0.0004147055245567589)]
#
#
# 108047 [('Samelink(108047,31489)', 0.9992049505685006), ('w_300', 0.0004165219284190379), ('w_908', 0.0003785275030802969)]
#
#
# 23070 [('Samelink(23070,31489)', 0.9688475664182179), ('w_98', 0.002786951213011549), ('w_936', 0.0026040998257823847), ('w_1333', 0.0023592208127260236), ('w_1213', 0.002341790387921878), ('w_1329', 0.0022539140856354624), ('w_1260', 0.0022119678184771316), ('w_90', 0.002152932666641037), ('w_1331', 0.0021019863960052973), ('w_1022', 0.0020312987534750145), ('w_403', 0.0019308058979975282), ('w_1139', 0.0015648735808507128), ('w_1230', 0.0007562401745161303), ('w_1287', 0.0007274126773773835), ('w_666', 0.0007112251600237858), ('w_52', 0.0007052232009658554), ('w_1396', 0.0007006088043788275), ('w_500', 0.0006738497821518109), ('w_1398', 0.0006637337522208183), ('w_193', 0.0006560253580190738), ('w_39', 0.0006446557132175961), ('w_760', 0.0005736175203866498)]
#
#
# 195792 [('Samelink(195792,31489)', 0.986087474485198), ('w_214', 0.0020203898937844796), ('w_704', 0.0017425080533001191), ('w_702', 0.0013747435772768725), ('w_508', 0.0010477334643855883), ('w_465', 0.0008850962604528805), ('w_1178', 0.0008694824122869848), ('w_7', 0.0008614966919166655), ('w_987', 0.0008202178168278608), ('w_100', 0.0006643638341010536), ('w_20', 0.0003977478303378006), ('w_262', 0.00038709555087692167), ('w_667', 0.0003866626355633135), ('w_1416', 0.0003806521797631406), ('w_775', 0.0003799098897531749), ('w_1357', 0.00036200471972415736), ('w_1323', 0.0003476557203415614), ('w_496', 0.00033684584786662517), ('w_141', 0.00033289286446262035), ('w_1321', 0.0003150262717802399)]
#
#
# 7537 [('Samelink(7537,31489)', 0.9737282812224166), ('w_470', 0.003606856491795548), ('w_940', 0.003007493478302268), ('w_57', 0.0028611352686049142), ('w_1414', 0.0026835224055621466), ('w_781', 0.001675957571708819), ('w_923', 0.0016380807174987907), ('w_1199', 0.001388964428560321), ('w_1178', 0.0012780082549327817), ('w_724', 0.0011752670234300054), ('w_239', 0.0008721329723579008), ('w_759', 0.0008158372029974767), ('w_1076', 0.0006360708555387147), ('w_1358', 0.0006257638176960921), ('w_641', 0.0005528987671760356), ('w_350', 0.0005466981401576347), ('w_1341', 0.000539761875791905), ('w_1121', 0.0005361097870552947), ('w_1181', 0.0005005364833339187), ('w_953', 0.00048248650171398526), ('w_663', 0.00043729776201167453), ('w_349', 0.0004108389713568219)]
#
#
# 714289 [('Samelink(714289,31489)', 0.9854767548765032), ('w_1419', 0.0012733868047896753), ('w_725', 0.001164048216423139), ('w_1210', 0.0009695357103104074), ('w_1120', 0.0009217291011867758), ('w_325', 0.0009015024986631829), ('w_861', 0.0008977498132146525), ('w_524', 0.000865483663984143), ('w_40', 0.0008436516030640846), ('w_1178', 0.0007980725985655173), ('w_699', 0.0007412178510725242), ('w_1080', 0.0005791447573390473), ('w_1072', 0.00047582925952057277), ('w_1175', 0.0004715657645485098), ('w_1225', 0.00036613915914173817), ('w_622', 0.00035924870933887063), ('w_662', 0.00034654178910065175), ('w_1424', 0.0003386424876259903), ('w_237', 0.0003374920881253785), ('w_304', 0.0003368885865106838), ('w_1296', 0.0003287028077085497), ('w_93', 0.0003047096028802923), ('w_137', 0.00030317304085967177), ('w_288', 0.0003025214468083601), ('w_1051', 0.0002962677627149012)]
#
#
# 578337 [('Samelink(578337,31489)', 0.9945242020898929), ('w_1264', 0.0022759777950243708), ('w_1028', 0.0008672404090418508), ('w_73', 0.000845644955759356), ('w_1053', 0.0007472035651355212), ('w_448', 0.0007397311851460032)]
#
#
# 575077 [('Samelink(575077,31489)', 0.9605979758674081), ('w_368', 0.004505911328315319), ('w_1003', 0.0038892500417506003), ('w_631', 0.0038298461753903837), ('w_1423', 0.0032790826824661778), ('w_180', 0.002941580960442938), ('w_1229', 0.002700043360176919), ('w_1252', 0.0025157954489690095), ('w_360', 0.0021948496918774325), ('w_813', 0.0021147240345608903), ('w_1340', 0.0018089026785950136), ('w_1179', 0.0017292371140698386), ('w_1231', 0.001328752660762392), ('w_119', 0.0013251280957930238), ('w_1133', 0.0012054489299644208), ('w_1145', 0.0010577031452768631), ('w_929', 0.0007920500476996983), ('w_1317', 0.0007753842417036986), ('w_1050', 0.0007391372944894884), ('w_496', 0.0006691962002878021)]
#
#
# 12576 [('Samelink(12576,31489)', 0.9911497848647869), ('w_875', 0.000921539329133932), ('w_531', 0.000851861048225641), ('w_1264', 0.0007418958714097508), ('w_1210', 0.0007372198030391743), ('w_508', 0.0007312495240028546), ('w_399', 0.0006913317055388838), ('w_1382', 0.0006792361016114206), ('w_1152', 0.0004811393810033817), ('w_62', 0.0004722667033404773), ('w_229', 0.0004082122153841314), ('w_1263', 0.0003984256266111475), ('w_795', 0.0002772493071432901), ('w_415', 0.00026497169809320094), ('w_988', 0.00025999237601193314), ('w_155', 0.00025714057132777225), ('w_549', 0.0002465735891387261), ('w_496', 0.0002350964002655519), ('w_960', 0.00019481388393216483)]
#
#
# 578646 [('Samelink(578646,31489)', 0.9866619716575304), ('w_1107', 0.0017466128473618942), ('w_1329', 0.0013662840957857725), ('w_1382', 0.0012009900145341782), ('w_541', 0.0011768193444072858), ('w_1178', 0.0010729864025511612), ('w_946', 0.0009161801460332778), ('w_620', 0.0008890974432330301), ('w_1133', 0.0007487898772039121), ('w_1145', 0.0006570144852950593), ('w_502', 0.00046537915743952423), ('w_910', 0.00044569766685460273), ('w_538', 0.00042522925485635163), ('w_496', 0.0004156852506838408), ('w_1307', 0.00040043408978354987), ('w_248', 0.00037181728410802826), ('w_976', 0.00035868010519968815), ('w_742', 0.00035158756414663836), ('w_599', 0.0003287433129917303)]
#
#
# ...
#
#
# 10177 [('Samelink(10177,31489)', 0.9153879289696732), ('w_550', 0.009914716169612117), ('w_841', 0.009880599805054568), ('w_1023', 0.009788518135669378), ('w_1160', 0.00508543833920565), ('w_958', 0.004532724812915792), ('w_726', 0.004418297452420156), ('w_475', 0.004302840458534416), ('w_589', 0.003664539352974421), ('w_1258', 0.003474050736970862), ('w_337', 0.0034100319139630532), ('w_1333', 0.0032026470508943754), ('w_127', 0.003138006252301632), ('w_1293', 0.0030685431072697664), ('w_1329', 0.0030596929547213134), ('w_1264', 0.0029376389889366776), ('w_1210', 0.0029191234515281235), ('w_508', 0.002895483308554154), ('w_1340', 0.002516304441629216), ('w_1178', 0.0024028742971712942)]
#
#
# 503883 [('Samelink(503883,31489)', 0.9760987182679193), ('w_27', 0.002418613265791584), ('w_979', 0.0021415966407065047), ('w_127', 0.0018542230096939168), ('w_1293', 0.001813177788146216), ('w_1329', 0.0018079483031881772), ('w_508', 0.001710918125471509), ('w_1302', 0.0015718071888571694), ('w_1178', 0.0014198393670978712), ('w_1390', 0.001149982151519162), ('w_1061', 0.0009880142121510606), ('w_483', 0.0006630354201620658), ('w_609', 0.0006282674641641148), ('w_165', 0.0006215404231148681), ('w_778', 0.0006122370533053266), ('w_164', 0.0006112889574008396), ('w_1050', 0.0006075489292500768), ('w_168', 0.000577139093081654), ('w_733', 0.0005682803233111911), ('w_496', 0.0005500594246484152), ('w_1123', 0.0005388123353828187), ('w_1410', 0.0005238322847047658), ('w_1161', 0.0005231199709309481)]
#
#
# 45188 [('Samelink(45188,31489)', 0.9635985626574364), ('w_95', 0.00340801677361964), ('w_1367', 0.0033760524483032175), ('w_1431', 0.003364075106832499), ('w_263', 0.0021199669684784507), ('w_940', 0.001954188387232708), ('w_306', 0.0018965619547891043), ('w_1003', 0.0018697269519770308), ('w_121', 0.0018530291550422696), ('w_731', 0.001833576663567229), ('w_1115', 0.0018047984514217566), ('w_1160', 0.001757489479176655), ('w_180', 0.0014141423524127656), ('w_1012', 0.0013852555553579057), ('w_126', 0.0013657756470729521), ('w_725', 0.0012112225923245025), ('w_337', 0.0011784815413537833), ('w_1213', 0.0010986335287163835), ('w_1329', 0.0010574070156307497), ('w_133', 0.0009925433010971629), ('w_136', 0.0007557713315265749), ('w_515', 0.0007047221366307511)]
#
#
# 1272 [('Samelink(1272,31489)', 0.920777421400434), ('w_206', 0.013322882443757006), ('w_71', 0.012500909888859197), ('w_815', 0.011405180112736276), ('w_98', 0.00871274475317783), ('w_875', 0.00840338923642939), ('w_764', 0.008195285508590966), ('w_399', 0.006304157868756029), ('w_1349', 0.005560521398535199), ('w_370', 0.004817507388724246)]
#
#
# 22431 [('Samelink(22431,31489)', 0.9081187952350014), ('w_1337', 0.01183496135572067), ('w_750', 0.009064172104859361), ('w_1281', 0.008135734717787255), ('w_1214', 0.00784865300985064), ('w_979', 0.007447953572724418), ('w_443', 0.006409910307888884), ('w_1132', 0.006299918163162741), ('w_1264', 0.006036787227127212), ('w_508', 0.005950158177797979), ('w_1144', 0.005134491854099967), ('w_1385', 0.004245911526928153), ('w_946', 0.004216238358899436), ('w_703', 0.0034771071941304926), ('w_229', 0.0033216120789371453), ('w_1076', 0.002457595115084299)]
#
#
# 714256 [('Samelink(714256,31489)', 0.9646234621277417), ('w_1258', 0.004753716155693253), ('w_1176', 0.004073760023832693), ('w_40', 0.003475752772337106), ('w_916', 0.0033068763371059255), ('w_94', 0.0028303907380464502), ('w_946', 0.002807467900212518), ('w_1180', 0.0023735554761418294), ('w_1050', 0.0014069225414809158), ('w_1424', 0.0013951701874591958), ('w_1195', 0.0013718477307373773), ('w_1418', 0.0013390799234019083), ('w_130', 0.0013040637340141655), ('w_814', 0.0012694533007464191), ('w_288', 0.0012463554311005294), ('w_87', 0.001229371721895365), ('w_59', 0.0011927538980526183)]
#
#
# 3097 [('Samelink(3097,31489)', 0.9682079025207155), ('w_1426', 0.002786166660502189), ('w_1208', 0.002320163970890214), ('w_839', 0.0020968303697543457), ('w_88', 0.0020697450568488607), ('w_1264', 0.002032494958916918), ('w_1210', 0.002019684420730895), ('w_624', 0.0019851083308688225), ('w_1300', 0.0017615958442435394), ('w_1173', 0.0016691837995256441), ('w_42', 0.001541824946695316), ('w_1394', 0.0014945024233126026), ('w_620', 0.001377581330380001), ('w_1152', 0.001318127521814548), ('w_1231', 0.0012788605278465028), ('w_1263', 0.0010915252514503051), ('w_1072', 0.0009912218107716074), ('w_227', 0.0007314185617275674), ('w_778', 0.0007168734596109958), ('w_155', 0.0007044612796720359), ('w_41', 0.0006457696657309065), ('w_993', 0.0005962502960066961), ('w_758', 0.0005627069919839018)]
#
#
# 12198 [('Samelink(12198,31489)', 0.9409918256873112), ('w_959', 0.005504569167301937), ('w_474', 0.005472355094581335), ('w_1091', 0.0054717122995187415), ('w_877', 0.005466341760910156), ('w_480', 0.004182084617661559), ('w_214', 0.0030824095775796086), ('w_306', 0.003029616106406499), ('w_275', 0.0024489101212104357), ('w_475', 0.0023754185914536576), ('w_1426', 0.0022231099644192285), ('w_1282', 0.002156717732142614), ('w_972', 0.0019257689294441209), ('w_212', 0.0018009001322184862), ('w_1132', 0.0016924364503519472), ('w_813', 0.0016240021176912897), ('w_133', 0.0015855138102484072), ('w_1382', 0.0014847766795190725), ('w_58', 0.0014750226374146448), ('w_1178', 0.0013265265894545784), ('w_648', 0.0012800468392227828), ('w_1353', 0.001263736460204839), ('w_1171', 0.0010992889162906093), ('w_396', 0.0010369097174425018)]
#
#
# 6151 [('Samelink(6151,31489)', 0.9657110987504376), ('w_962', 0.006081434284077581), ('w_1208', 0.0030175102038602986), ('w_1333', 0.0028818422361749146), ('w_1264', 0.002643379672632898), ('w_325', 0.0024423995389575228), ('w_1199', 0.002349901393776917), ('w_1152', 0.001714302651436481), ('w_396', 0.0016901185142811502), ('w_820', 0.0015057209501735704), ('w_1061', 0.0015045830073720221), ('w_229', 0.0014544627000234217), ('w_1175', 0.0012775915847480605), ('w_1172', 0.0012571979057146682), ('w_1076', 0.0010761281997124872), ('w_1296', 0.0008905395017672091), ('w_569', 0.0008784013934849722), ('w_394', 0.0008149485191978588), ('w_87', 0.000808438992170268)]
#
#
# 287787 [('Samelink(287787,31489)', 0.8029320070984987), ('w_281', 0.023688110838272932), ('w_1427', 0.019668549941292534), ('w_736', 0.018953185071942415), ('w_1329', 0.017960868618704346), ('w_1210', 0.01713570399728259), ('w_508', 0.016996932719129443), ('w_42', 0.013081378274253276), ('w_1098', 0.011899689361663471), ('w_1231', 0.010850296825607942), ('w_1267', 0.009578570378840186), ('w_1172', 0.008201475956962948), ('w_645', 0.006301492269176207), ('w_115', 0.006226167752466897), ('w_1226', 0.005987140457456778), ('w_496', 0.005464506391675288), ('w_1412', 0.0050739240467740235)]
#
#
# 2440 [('Samelink(2440,31489)', 0.9939974359096023), ('w_764', 0.0011754719076183648), ('w_1262', 0.0011573581976459578), ('w_1264', 0.000970357408615094), ('w_1349', 0.0007975605839280513), ('w_703', 0.0005589126466494667), ('w_950', 0.00035878291255669555), ('w_1235', 0.00033355929790865704), ('w_1096', 0.00033029886567374566), ('w_1006', 0.0003202622698016876)]
#
#
# 17798 [('Samelink(17798,31489)', 0.9414980965952612), ('w_206', 0.007612681581957556), ('w_1315', 0.0056256148463669515), ('w_875', 0.004801688128394716), ('w_764', 0.004682777868340996), ('w_1204', 0.0040523767068160466), ('w_1293', 0.004037911849662949), ('w_1264', 0.0038656544388628237), ('w_508', 0.003810181559585384), ('w_616', 0.0037456801692799936), ('w_1302', 0.003500384195507231), ('w_53', 0.0032066138270346193), ('w_1178', 0.0031619547969887816), ('w_1263', 0.0020759999501539774), ('w_1076', 0.0015737201110654644), ('w_720', 0.0014134906767211146), ('w_751', 0.0013351726980006752)]
#
#
# 144701 [('Samelink(144701,31489)', 0.9838258364804842), ('w_979', 0.0013776113214834628), ('w_1264', 0.0011165948267901375), ('w_133', 0.0010916472105130643), ('w_1300', 0.0009677705708187911), ('w_40', 0.0009654926590370934), ('w_916', 0.0009185822574119447), ('w_1178', 0.0009133310865470301), ('w_7', 0.0009049426400878312), ('w_285', 0.000776796072475706), ('w_331', 0.000769088733429076), ('w_506', 0.0007062003091966352), ('w_1133', 0.0006373734751121019), ('w_1387', 0.0006366571254117721), ('w_625', 0.0003929828418632859), ('w_762', 0.00039225263709209213), ('w_1407', 0.0003895719022392185), ('w_155', 0.0003870109576925693), ('w_369', 0.00038420987196425844), ('w_511', 0.0003762658825616061), ('w_1055', 0.0003727879875334891), ('w_122', 0.0003687986124405337), ('w_300', 0.000366766018336532), ('w_496', 0.00035383324594418094), ('w_39', 0.0003326331377775629), ('w_780', 0.0002749621357555668)]
#
#
# 2696 [('Samelink(2696,31489)', 0.9631649222688782), ('w_537', 0.005110640325958099), ('w_1264', 0.0032399257700339713), ('w_1207', 0.003210169544251387), ('w_133', 0.0031675374489189925), ('w_1349', 0.0026629745556534727), ('w_1178', 0.002650133112638013), ('w_913', 0.0024908224432423423), ('w_699', 0.0024613374451602946), ('w_108', 0.0011773966891580384), ('w_983', 0.00111722518974365), ('w_1121', 0.0011117004081943722), ('w_965', 0.0011083010595173113), ('w_76', 0.001100208601705973), ('w_1296', 0.001091512472037342), ('w_878', 0.0010877683518324209), ('w_858', 0.0010666709549944984), ('w_1118', 0.0010126471184224758), ('w_137', 0.0010067366250708515), ('w_59', 0.0009613696145887902)]
#
#
# 3085 [('Samelink(3085,31489)', 0.9345876690034549), ('w_1033', 0.007873949173624708), ('w_72', 0.007570004058352081), ('w_314', 0.00677464863292242), ('w_1291', 0.0065597182358671175), ('w_1229', 0.005380977170303367), ('w_1258', 0.004977125426978271), ('w_1210', 0.004182104596364464), ('w_235', 0.004166272428391671), ('w_1145', 0.002107920399219046), ('w_118', 0.001686544518018115), ('w_387', 0.0015981191192843709), ('w_868', 0.0015225662323517237), ('w_63', 0.0014810739741078847), ('w_211', 0.0014251270915726288), ('w_1245', 0.0014042520362782885), ('w_436', 0.0013955611561026018), ('w_401', 0.0013736563979194704), ('w_1181', 0.0013482659275866416), ('w_41', 0.0013371773627231483), ('w_1321', 0.0012472670585769836)]
#
#
# 644577 [('Samelink(644577,31489)', 0.9524286296244074), ('w_531', 0.003914498582103247), ('w_279', 0.003833320290089817), ('w_1329', 0.003550828989699271), ('w_1148', 0.003411026355623969), ('w_58', 0.0031007424027282285), ('w_1199', 0.0030306823996644524), ('w_1276', 0.0028222184881378652), ('w_1178', 0.002788579063083221), ('w_204', 0.00262770758319255), ('w_285', 0.0023717108679399894), ('w_152', 0.0021816590100769335), ('w_649', 0.0021431050341405382), ('w_703', 0.0019636430490556586), ('w_373', 0.0011510749648598938), ('w_510', 0.0011509370421325486), ('w_822', 0.0011411282993795421), ('w_549', 0.001133062683260506), ('w_858', 0.0011223950518227932), ('w_1428', 0.00110904768137967), ('w_1415', 0.0011046755733306656), ('w_1413', 0.001094908948166988), ('w_174', 0.0008244180157238121)]
#
#
# 85688 [('Samelink(85688,31489)', 0.9198692146317954), ('w_815', 0.010069054982959765), ('w_1124', 0.007254739410086173), ('w_399', 0.005565621197939489), ('w_234', 0.00543212409025579), ('w_1199', 0.005309580588057836), ('w_40', 0.00516444300150751), ('w_1349', 0.004909102280046552), ('w_1178', 0.004885429520180166), ('w_1394', 0.004391746566646923), ('w_370', 0.004253132900874602), ('w_229', 0.003286345094543008), ('w_1238', 0.0020880734462686633), ('w_930', 0.0020874305979647644), ('w_47', 0.0020454747531466894), ('w_457', 0.0019555711261391925), ('w_503', 0.00194973294822168), ('w_351', 0.001944905181883975), ('w_975', 0.0019241241481650735), ('w_158', 0.001912613991885842), ('w_137', 0.0018558844473558697), ('w_906', 0.0018456550940748127)]
#
#
# 77758 [('Samelink(77758,31489)', 0.8768579480798482), ('w_730', 0.015243544266539105), ('w_970', 0.01359312407581291), ('w_475', 0.012806797027572718), ('w_212', 0.009709346615047312), ('w_508', 0.008617997201320395), ('w_133', 0.008548115951150641), ('w_616', 0.008472105780546836), ('w_699', 0.006642320166828486), ('w_136', 0.006508956301758612), ('w_1080', 0.005189924791503367), ('w_1387', 0.0049853275643770385), ('w_1239', 0.0033971733139037587), ('w_1185', 0.00297726178104806), ('w_510', 0.0029517864877201465), ('w_448', 0.0028417745055704375), ('w_1074', 0.0028162256756479784), ('w_177', 0.0026770991681475224), ('w_104', 0.002585740917424679), ('w_473', 0.0025774303282318084)]
#
#
# 97390 [('Samelink(97390,31489)', 0.9686281936001075), ('w_275', 0.003646205090312614), ('w_27', 0.003364429432792393), ('w_1333', 0.0026324627483054522), ('w_1119', 0.0024986233259064704), ('w_508', 0.002379985002087705), ('w_26', 0.0020933219683732774), ('w_1394', 0.00177549201973131), ('w_1097', 0.0015271567685238164), ('w_1231', 0.0015193061089241856), ('w_1267', 0.0013412333989781663), ('w_409', 0.0009049300436543132), ('w_415', 0.0008623987390616992), ('w_1050', 0.0008451353212773628), ('w_155', 0.0008369109081101743), ('w_171', 0.0007934199544888942), ('w_496', 0.0007651641311354032), ('w_1123', 0.0007495187864688463), ('w_1161', 0.000727689809683383), ('w_335', 0.0007219361445341457), ('w_1299', 0.0007009589048879455), ('w_11', 0.0006855277926549286)]
#
#
# 54129 [('Samelink(54129,31489)', 0.6817492445973453), ('w_1354', 0.023850300594696665), ('w_1329', 0.0220279495874276), ('w_700', 0.020704482750612332), ('w_133', 0.020676705825396338), ('w_1250', 0.020453784364468246), ('w_1382', 0.019362991618480277), ('w_809', 0.018170407728460347), ('w_1340', 0.018115879013708803), ('w_1394', 0.015551124470973897), ('w_946', 0.01477113737331206), ('w_515', 0.014680802632642397), ('w_620', 0.01433449581844419), ('w_1231', 0.013307251255889375), ('w_1248', 0.013087212768235915), ('w_1133', 0.012072383567590115), ('w_66', 0.01163275878941778), ('w_1072', 0.010314211283436073), ('w_502', 0.007503087133003369), ('w_1066', 0.007483193416342483), ('w_919', 0.006992690883092358), ('w_496', 0.006701895875494829), ('w_1307', 0.006456008651529051)]
#
#
# 93555 [('Samelink(93555,31489)', 0.8315755996725805), ('w_873', 0.023783686132477458), ('w_537', 0.02034613795550046), ('w_1206', 0.01372765005922449), ('w_1260', 0.01318446759198844), ('w_133', 0.012610387310485955), ('w_1234', 0.011872267600459422), ('w_506', 0.008157818141237241), ('w_1263', 0.00692701355781651), ('w_912', 0.0059805131437620845), ('w_1076', 0.00525105048521337), ('w_20', 0.004826378454936748), ('w_775', 0.0046099281174328014), ('w_257', 0.004456787568303455), ('w_891', 0.0043963782924880705), ('w_511', 0.004346512742512881), ('w_1037', 0.004243295247552327), ('w_610', 0.004211834002050381), ('w_857', 0.004172536120554962), ('w_394', 0.003976604105627154), ('w_193', 0.0039102490551964205), ('w_386', 0.0034329046425990157)]
#
#
# 8865 [('Samelink(8865,31489)', 0.5561889899482277), ('w_753', 0.04886481429507735), ('w_955', 0.03463539385708767), ('w_1092', 0.029892951215147557), ('w_779', 0.027386481246736632), ('w_626', 0.02730805796139165), ('w_1132', 0.027009259105946187), ('w_1264', 0.025881153716938114), ('w_1210', 0.025718028339168003), ('w_508', 0.025509754219542033), ('w_1353', 0.020167720618523535), ('w_987', 0.019970303159151326), ('w_1425', 0.01923131549460121), ('w_895', 0.018974904132867468), ('w_379', 0.018651528554034513), ('w_1072', 0.012621907837760285), ('w_1076', 0.01053629928543324), ('w_135', 0.009565085450263055), ('w_389', 0.008837255113363744), ('w_1283', 0.008607811713412206), ('w_1188', 0.008315246553447819), ('w_496', 0.008201374758980211), ('w_177', 0.007924363422898354)]
#
#
# 85352 [('Samelink(85352,31489)', 0.5199510858904078), ('w_785', 0.06611097586509004), ('w_1354', 0.05456987209578551), ('w_508', 0.047695386449425926), ('w_648', 0.038194098181618244), ('w_204', 0.03729756077090809), ('w_724', 0.03639898301817331), ('w_132', 0.03589510671057487), ('w_895', 0.0354772287364739), ('w_390', 0.01748833673022068), ('w_1393', 0.016928622384546187), ('w_1230', 0.016910464623246683), ('w_369', 0.01665047540313361), ('w_1243', 0.015643957414344583), ('w_496', 0.015334045760678875), ('w_1269', 0.015113034603742699), ('w_1321', 0.014340765361629025)]

# %%
# GCN outcome
GCN_Result(WORDS,Store_Explanation_r)
# Out:
# The Cora dataset consists of 2708 scientific publications classified into one of seven classes. The citation network consists of 5429 links. Each publication in the dataset is described by a 0/1-valued word vector indicating the absence/presence of the corresponding word from the dictionary. The dictionary consists of 1433 unique words.
# 2400
# Using GCN (local pooling) filters...
# Epoch 1/200
# 1/1 - 2s - loss: 1.9437 - acc: 0.2500 - val_loss: 1.8863 - val_acc: 0.2550
# Epoch 2/200
# 1/1 - 0s - loss: 1.8546 - acc: 0.3200 - val_loss: 1.7998 - val_acc: 0.3600
# Epoch 3/200
# 1/1 - 0s - loss: 1.7497 - acc: 0.4300 - val_loss: 1.7037 - val_acc: 0.4200
# Epoch 4/200
# 1/1 - 0s - loss: 1.6188 - acc: 0.5500 - val_loss: 1.6117 - val_acc: 0.4400
# Epoch 5/200
# 1/1 - 0s - loss: 1.5107 - acc: 0.5300 - val_loss: 1.5218 - val_acc: 0.4400
# Epoch 6/200
# 1/1 - 0s - loss: 1.3803 - acc: 0.5100 - val_loss: 1.4331 - val_acc: 0.4650
# Epoch 7/200
# 1/1 - 0s - loss: 1.2473 - acc: 0.5800 - val_loss: 1.3472 - val_acc: 0.5150
# Epoch 8/200
# 1/1 - 1s - loss: 1.1673 - acc: 0.5900 - val_loss: 1.2637 - val_acc: 0.6100
# Epoch 9/200
# 1/1 - 0s - loss: 1.0532 - acc: 0.7000 - val_loss: 1.1845 - val_acc: 0.6700
# Epoch 10/200
# 1/1 - 0s - loss: 0.9870 - acc: 0.7900 - val_loss: 1.1049 - val_acc: 0.6750
# Epoch 11/200
# 1/1 - 0s - loss: 0.9049 - acc: 0.8100 - val_loss: 1.0281 - val_acc: 0.7050
# Epoch 12/200
# 1/1 - 0s - loss: 0.7834 - acc: 0.8500 - val_loss: 0.9541 - val_acc: 0.7250
# Epoch 13/200
# 1/1 - 0s - loss: 0.6764 - acc: 0.8600 - val_loss: 0.8820 - val_acc: 0.7450
# Epoch 14/200
# 1/1 - 0s - loss: 0.5655 - acc: 0.9000 - val_loss: 0.8179 - val_acc: 0.7550
# Epoch 15/200
# 1/1 - 0s - loss: 0.5154 - acc: 0.8700 - val_loss: 0.7607 - val_acc: 0.7750
# Epoch 16/200
# 1/1 - 0s - loss: 0.4335 - acc: 0.9100 - val_loss: 0.7132 - val_acc: 0.7850
# Epoch 17/200
# 1/1 - 0s - loss: 0.3672 - acc: 0.9400 - val_loss: 0.6832 - val_acc: 0.7900
# Epoch 18/200
# 1/1 - 0s - loss: 0.3187 - acc: 0.9600 - val_loss: 0.6665 - val_acc: 0.7850
# Epoch 19/200
# 1/1 - 0s - loss: 0.3258 - acc: 0.9500 - val_loss: 0.6497 - val_acc: 0.7750
# Epoch 20/200
# 1/1 - 0s - loss: 0.2589 - acc: 0.9400 - val_loss: 0.6434 - val_acc: 0.7650
# Epoch 21/200
# 1/1 - 0s - loss: 0.1992 - acc: 0.9800 - val_loss: 0.6402 - val_acc: 0.7850
# Epoch 22/200
# 1/1 - 0s - loss: 0.1977 - acc: 0.9400 - val_loss: 0.6338 - val_acc: 0.7950
# Epoch 23/200
# 1/1 - 0s - loss: 0.1377 - acc: 0.9600 - val_loss: 0.6361 - val_acc: 0.8000
# Epoch 24/200
# 1/1 - 0s - loss: 0.1610 - acc: 0.9800 - val_loss: 0.6359 - val_acc: 0.7900
# Epoch 25/200
# 1/1 - 0s - loss: 0.1096 - acc: 0.9800 - val_loss: 0.6399 - val_acc: 0.7900
# Epoch 26/200
# 1/1 - 0s - loss: 0.0790 - acc: 0.9800 - val_loss: 0.6507 - val_acc: 0.7850
# Epoch 27/200
# 1/1 - 0s - loss: 0.0926 - acc: 0.9700 - val_loss: 0.6582 - val_acc: 0.7900
# Epoch 28/200
# 1/1 - 0s - loss: 0.0952 - acc: 0.9600 - val_loss: 0.6678 - val_acc: 0.7850
# Epoch 29/200
# 1/1 - 0s - loss: 0.0772 - acc: 0.9900 - val_loss: 0.6713 - val_acc: 0.7900
# Epoch 30/200
# 1/1 - 0s - loss: 0.1062 - acc: 0.9700 - val_loss: 0.6833 - val_acc: 0.7950
# Epoch 31/200
# 1/1 - 0s - loss: 0.0550 - acc: 0.9900 - val_loss: 0.7036 - val_acc: 0.7900
# Epoch 32/200
# 1/1 - 0s - loss: 0.0640 - acc: 0.9900 - val_loss: 0.7291 - val_acc: 0.8050
# Epoch 33/200
# 1/1 - 0s - loss: 0.0825 - acc: 0.9800 - val_loss: 0.7480 - val_acc: 0.8050
# Epoch 34/200
# 1/1 - 0s - loss: 0.0779 - acc: 0.9800 - val_loss: 0.7533 - val_acc: 0.7950
# Epoch 35/200
# 1/1 - 0s - loss: 0.0579 - acc: 0.9900 - val_loss: 0.7481 - val_acc: 0.7850
# Epoch 36/200
# 1/1 - 0s - loss: 0.0337 - acc: 1.0000 - val_loss: 0.7606 - val_acc: 0.7800
# Epoch 37/200
# 1/1 - 0s - loss: 0.0341 - acc: 1.0000 - val_loss: 0.7795 - val_acc: 0.7850
# Epoch 38/200
# 1/1 - 0s - loss: 0.0383 - acc: 0.9800 - val_loss: 0.8025 - val_acc: 0.8050
# Epoch 39/200
# 1/1 - 0s - loss: 0.0278 - acc: 1.0000 - val_loss: 0.8171 - val_acc: 0.7950
# Epoch 40/200
# 1/1 - 0s - loss: 0.0243 - acc: 1.0000 - val_loss: 0.8214 - val_acc: 0.7950
# Epoch 41/200
# 1/1 - 0s - loss: 0.0290 - acc: 0.9900 - val_loss: 0.8214 - val_acc: 0.7950
# Epoch 42/200
# 1/1 - 0s - loss: 0.0342 - acc: 0.9900 - val_loss: 0.8213 - val_acc: 0.7900
# Epoch 43/200
# 1/1 - 0s - loss: 0.0261 - acc: 0.9900 - val_loss: 0.8201 - val_acc: 0.7900
# Epoch 44/200
# 1/1 - 0s - loss: 0.0130 - acc: 1.0000 - val_loss: 0.8242 - val_acc: 0.8000
# Epoch 45/200
# 1/1 - 0s - loss: 0.0144 - acc: 1.0000 - val_loss: 0.8316 - val_acc: 0.7900
# Epoch 46/200
# 1/1 - 0s - loss: 0.0151 - acc: 1.0000 - val_loss: 0.8420 - val_acc: 0.7900
# Epoch 47/200
# 1/1 - 0s - loss: 0.0158 - acc: 1.0000 - val_loss: 0.8593 - val_acc: 0.7900
# Epoch 48/200
# 1/1 - 0s - loss: 0.0085 - acc: 1.0000 - val_loss: 0.8744 - val_acc: 0.7950
# Epoch 49/200
# 1/1 - 0s - loss: 0.0139 - acc: 1.0000 - val_loss: 0.8842 - val_acc: 0.7950
# Epoch 50/200
# 1/1 - 0s - loss: 0.0213 - acc: 1.0000 - val_loss: 0.8898 - val_acc: 0.7950
# Epoch 51/200
# 1/1 - 0s - loss: 0.0099 - acc: 1.0000 - val_loss: 0.8893 - val_acc: 0.8000
# Epoch 52/200
# 1/1 - 0s - loss: 0.0174 - acc: 1.0000 - val_loss: 0.8860 - val_acc: 0.8000
# Epoch 53/200
# 1/1 - 0s - loss: 0.0353 - acc: 0.9700 - val_loss: 0.8764 - val_acc: 0.7950
# Epoch 54/200
# 1/1 - 0s - loss: 0.0072 - acc: 1.0000 - val_loss: 0.8726 - val_acc: 0.7950
# Epoch 55/200
# 1/1 - 0s - loss: 0.0109 - acc: 1.0000 - val_loss: 0.8766 - val_acc: 0.7850
# Epoch 56/200
# 1/1 - 0s - loss: 0.0034 - acc: 1.0000 - val_loss: 0.8862 - val_acc: 0.7750
# Epoch 57/200
# 1/1 - 0s - loss: 0.0108 - acc: 1.0000 - val_loss: 0.8971 - val_acc: 0.7750
# Epoch 58/200
# 1/1 - 1s - loss: 0.0365 - acc: 0.9800 - val_loss: 0.8991 - val_acc: 0.7800
# Epoch 59/200
# 1/1 - 0s - loss: 0.0195 - acc: 0.9900 - val_loss: 0.8951 - val_acc: 0.7750
# Epoch 60/200
# 1/1 - 0s - loss: 0.0147 - acc: 1.0000 - val_loss: 0.8894 - val_acc: 0.7800
# Epoch 61/200
# 1/1 - 0s - loss: 0.0135 - acc: 0.9900 - val_loss: 0.8845 - val_acc: 0.7850
# Epoch 62/200
# 1/1 - 0s - loss: 0.0068 - acc: 1.0000 - val_loss: 0.8835 - val_acc: 0.7900
# Epoch 63/200
# 1/1 - 1s - loss: 0.0281 - acc: 0.9900 - val_loss: 0.8937 - val_acc: 0.7800
# Epoch 64/200
# 1/1 - 0s - loss: 0.0046 - acc: 1.0000 - val_loss: 0.9131 - val_acc: 0.7800
# Epoch 65/200
# 1/1 - 0s - loss: 0.0095 - acc: 1.0000 - val_loss: 0.9380 - val_acc: 0.7650
# Epoch 66/200
# 1/1 - 0s - loss: 0.0130 - acc: 1.0000 - val_loss: 0.9632 - val_acc: 0.7700
# Epoch 67/200
