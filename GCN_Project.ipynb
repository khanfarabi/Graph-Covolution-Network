# %%
#Cora MLN
class MLN_EXP:
    @classmethod
    def cora_mln(cls):
                    pid=[]
                    cl=[]
                    words={}
                    label={}
                    ln1=[]
                    ln2=[]
                    f1=open("content.txt")
                    for j in f1:
                        wrds=[]
                        p=j.strip("\n").split()
                        for j in range(1,len(p)-1):
                            if int(p[j])==1:
                                ss="w_"+str(j)
                                wrds.append(ss)
                        words[p[0]]=wrds
                        label[p[0]]=p[-1]
                       # print(len(wrds))
                    f1.close()
                    f1=open("link.txt")
                    for z in f1:
                        p=z.strip("\n").split()
                        ln1.append(p[0])
                        ln2.append(p[1])
                    f1.close()
                    linked={}
                    for t in words:
                        zzv=[]
                        for hh in range(0,len(ln1)):
                            if int(t)==int(ln1[hh]):
                                if ln2[hh] not in zzv:
                                            zzv.append(ln2[hh])
                        if len(zzv)>0:
                              linked[t]=zzv
                    for x in linked:
                        pass#print(x,linked[x]) Neural_Networks Neural_Networks
                    WORDS={}
                    samelink={}
                    c1=0
                    c2=0
                    c3=0
                    c4=0
                    c5=0
                    c6=0
                    c7=0
                    #c2=0
                    lb=80
                    for x in words:
                        if x in linked:
                                    if label[x]=='Neural_Networks':
                                         if c1<lb:
                                            if len(linked[x])>=5:
                                                WORDS[x]=words[x]
                                                samelink[x]=linked[x]
                                                c1=c1+1
                                    elif label[x]=='Probabilistic_Methods':
                                          if c2<lb:
                                                if len(linked[x])>=5:
                                                    WORDS[x]=words[x]
                                                    samelink[x]=linked[x]
                                                    c2=c2+1
                                    elif label[x]=='Genetic_Algorithms':
                                          if c3<lb:
                                                if len(linked[x])>=5:
                                                    WORDS[x]=words[x]
                                                    samelink[x]=linked[x]
                                                    c3=c3+1
                                    elif label[x]=='Theory':
                                          if c4<lb:
                                                if len(linked[x])>=5:
                                                    WORDS[x]=words[x]
                                                    samelink[x]=linked[x]
                                                    c4=c4+1
                                    elif label[x]=='Case_Based':
                                          if c5<80:
                                                if len(linked[x])>=5:
                                                    WORDS[x]=words[x]
                                                    samelink[x]=linked[x]
                                                    c5=c5+1
                                    elif label[x]=='Reinforcement_Learning':
                                          if c6<80:
                                                if len(linked[x])>=5:
                                                    WORDS[x]=words[x]
                                                    samelink[x]=linked[x]
                                                    c6=c6+1
                                    elif label[x]=='Rule_Learning':
                                          if c7<80:
                                                if len(linked[x])>=5:
                                                    WORDS[x]=words[x]
                                                    samelink[x]=linked[x]
                                                    c7=c7+1
                    # Data Type

                    d_tt={}
                    #margs2={}
                    d_tt[0]="Neural_Networks"
                    d_tt[1]="Probabilistic_Methods"
                    d_tt[2]="Genetic_Algorithms"
                    d_tt[3]="Theory"
                    d_tt[4]="Case_Based"
                    d_tt[5]="Reinforcement_Learning"
                    d_tt[6]="Rule_Learning"
                    #d_tt[7]="Probabilistic_Methods"
                    #train and target data
                    w11=[]
                    trg=[]
                    w12=[]
                    trg1=[]
                    for tt in WORDS:
                        s=' '
                        #if qrat[tt]!=1:
                        for kk in WORDS[tt]:
                            #if qrat[tt]!=1:
                                w11.append(kk)
                                s=str(kk)+s+"\t"
                                #print(kk)
                                trg.append(label[tt])
                            #w12.append(s)
                            #trg1.append(qrat[tt])
                    #SVM Learner
                    from sklearn.feature_extraction.text import TfidfVectorizer
                    from sklearn import svm
                    #from sklearn import cross_validation
                    from sklearn.model_selection import cross_validate
                    from sklearn.preprocessing import MinMaxScaler
                    from sklearn.metrics import (precision_score,recall_score,f1_score)
                    from sklearn.feature_extraction.text import TfidfVectorizer
                    from collections import defaultdict
                    from sklearn import svm
                    #from sklearn import cross_validation
                    from sklearn.model_selection import cross_validate
                    from sklearn.preprocessing import MinMaxScaler
                    from sklearn.metrics import (precision_score,recall_score,f1_score)
                    from sklearn.multiclass import OneVsRestClassifier
                    from sklearn.svm import SVC
                    from sklearn.svm import LinearSVC
                    from sklearn.multiclass import OneVsOneClassifier
                    from sklearn.multiclass import OutputCodeClassifier

                    #OutputCodeClassifier(LinearSVC(random_state=0),code_size=2, random_state=0)

                    #Learn SVM Model
                    #ifile = open("processed_revs_1.txt",encoding="ISO-8859-1")
                    Y = trg
                    words =w11
                    unique_words = []

                    ss=set(words)
                    for w1 in ss:
                            if w1 not in unique_words:
                                unique_words.append(w1)

                    #######
                    #tf_transformer = TfidfVectorizer()
                    #f = tf_transformer.fit_transform(words)
                    #features = [((i, j), f[i,j]) for i, j in zip(*f.nonzero())]
                    #unique_word_ids = []
                    #for w in unique_words:
                       # i = tf_transformer.vocabulary_.get(w)
                        #unique_word_ids.append(i)

                    #clf =OneVsRestClassifier(SVC(kernel='linear'))#svm.LinearSVC(C=1)
                    #clf.fit(f,Y)
                    #p = clf.predict(f)
                    #print(f1_score(Y,p,average='weighted'))




                    #########
                    tf_transformer = TfidfVectorizer()
                    f = tf_transformer.fit_transform(words)
                    features = [((i, j), f[i,j]) for i, j in zip(*f.nonzero())]
                    unique_word_ids = []
                    for w in unique_words:
                        i = tf_transformer.vocabulary_.get(w)
                        unique_word_ids.append(i)

                    clf =svm.LinearSVC(C=100)#svm.SVC(C=1.0, kernel='linear', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=- 1, decision_function_shape='ovr', random_state=None)

                    #OneVsRestClassifier(LinearSVC(random_state=0)) #svm.LinearSVC(C=1)
                    clf.fit(f,Y)
                    #clf.fit(f,Y)
                    p = clf.predict(f)
                    #print(f1_score(Y,p,average='micro'))
                    from sklearn.metrics import accuracy_score
                    #print(accuracy_score(Y,p))

                    #Store learned weights

                    #Tunable parameter, normalization range of weights
                    rangelower=0
                    rangehigher=1

                    C = clf.coef_
                    scaler = MinMaxScaler(feature_range=(rangelower,rangehigher))
                    vals = []
                    for i, j in zip(*C.nonzero()):
                        vals.append([C[i,j]])
                    scaler.fit(vals)
                    V1 = scaler.transform(vals)
                    rows,cols = C.nonzero()
                    r_wts =  defaultdict(list)
                    ix= 0
                    for w in unique_words:
                        r_wts[w] = [0,0,0,0,0,0,0]  
                    for i, j in zip(*C.nonzero()):
                        #print(i,j)
                        for k in tf_transformer.vocabulary_.keys():
                            if tf_transformer.vocabulary_[k]==j:
                                if k not in r_wts:
                                    break
                                else:
                                    #if float(V1[ix][0])>0:
                                    r_wts[k][i] = V1[ix][0]
                                    break
                        ix = ix + 1


                    #print(r_wts)
                    #Sample 2 origin

                    import random
                    from collections import defaultdict

                    #Sampler
                    margs =defaultdict(list)
                    Relational_formula_filter={}
                    iter1=defaultdict(list)
                    users_s= defaultdict(list)
                    expns = defaultdict(dict)
                    Relational_formula_filter={}
                    same_user={}
                    Sample={}
                    Sample_r={}

                    for h in samelink:
                        for i,r in enumerate(samelink[h]):
                            if r in WORDS:
                                    Sample[r] = random.randint(0,6)
                                    #Sample_r[r] = random.randint(0,1)
                                    margs[r] = [0]*7
                                    #margs_r[r] = 0
                                    iter1[r] =0

                    #Tunable parameter (default value of prob)
                    C1 = 0.98
                    VR=0.98
                    iters =1000000

                    for t in range(0,iters,1):
                        h1 = random.choice(list(samelink.keys()))
                        if len(samelink[h1])==0:
                            continue
                        ix1 = random.randint(0,len(samelink[h1])-1)
                        r33 = samelink[h1][ix1]
                        if r33 in WORDS:
                            if random.random()<0.5:
                                #sample Topic
                                W0=0
                                W1=0
                                W2=0
                                W3=0
                                W4=0
                                W5=0
                                W6=0


                                try:
                                            for w in WORDS[r33]:
                                                if len(r_wts[w])!=7:
                                                    continue

                                                W0=W0+r_wts[w][0]
                                                W1=W1+r_wts[w][1]
                                                W2=W2+r_wts[w][2]
                                                W3=W3+r_wts[w][3]
                                                W4=W4+r_wts[w][4]
                                                W5=W5+r_wts[w][5]
                                                W6=W6+r_wts[w][6]
                                               # W2=W2+(r_wts[w][2])


                                                if r33 not in expns or w not in expns[r]:
                                                                         expns[r33][w] = r_wts[w][0]
                                                                         expns[r33][w] = r_wts[w][1]
                                                                         expns[r33][w] = r_wts[w][2]
                                                                         expns[r33][w] = r_wts[w][3]
                                                                         expns[r33][w] = r_wts[w][4]
                                                                         expns[r33][w] = r_wts[w][5]
                                                                         expns[r33][w] = r_wts[w][6]
                                                                    #expns[r][w] = (r_wts[w][2])


                                                else:
                                                                     expns[r33][w] =expns[r33][w]+ r_wts[w][0]
                                                                     expns[r33][w] = expns[r33][w]+r_wts[w][1]
                                                                     expns[r33][w] = expns[r33][w]+r_wts[w][2]
                                                                     expns[r33][w] =expns[r33][w]+ r_wts[w][3]
                                                                     expns[r33][w] =expns[r33][w]+ r_wts[w][4]
                                                                     expns[r33][w] =expns[r33][w]+ r_wts[w][5]
                                                                     expns[r33][w] =expns[r33][w]+ r_wts[w][6]
                                except:
                                    continue



                                if (W0+W1+W2+W3+W4+W5+W6)!= 0:
                                    W0 = W0/(W0+W1+W2+W3+W4+W5+W6)
                                    W1 = W1/(W0+W1+W2+W3+W4+W5+W6)
                                    W2 = W2/(W0+W1+W2+W3+W4+W5+W6)
                                    W3 = W3/(W0+W1+W2+W3+W4+W5+W6)
                                    W4 = W4/(W0+W1+W2+W3+W4+W5+W6)
                                    W5 = W5/(W0+W1+W2+W3+W4+W5+W6)
                                    W6 = W6/(W0+W1+W2+W3+W4+W5+W6)

                                   # W2=W2/(W0+W1+W2)


                                    sval = random.random()
                                    iter1[r33]=iter1[r33]+1
                                    #print(sval,W14,W15,W16,W17,W18,W19)
                                    if sval<W0:
                                        print(sval)
                                        Sample[r33]=0
                                        #Sample_r[r33]=0
                                        margs[r33][0]=margs[r33][0]+1
                                    elif sval<(W0+W1):
                                        #print(sval)
                                        Sample[r33]=1
                                        #Sample_r[r33]=1
                                        margs[r33][1]=margs[r33][1]+1
                                    elif sval<(W0+W1+W2):
                                        #print(sval)
                                        Sample[r33]=2
                                        #Sample_r[r33]=1
                                        margs[r33][2]=margs[r33][1]+1
                                    elif sval<(W0+W1+W2+W3):
                                        #print(sval)
                                        Sample[r33]=3
                                        #Sample_r[r33]=1
                                        margs[r33][3]=margs[r33][1]+1
                                    elif sval<(W0+W1+W2+W3+W4):
                                        #print(sval)
                                        Sample[r33]=4
                                        #Sample_r[r33]=1
                                        margs[r33][4]=margs[r33][1]+1
                                    elif sval<(W0+W1+W2+W3+W4+W5):
                                        #print(sval)
                                        Sample[r33]=5
                                        #Sample_r[r33]=1
                                        margs[r33][5]=margs[r33][1]+1
                                    elif sval<(W0+W1+W2+W3+W4+W5+W6):
                                        #print(sval)
                                        Sample[r33]=6
                                        #Sample_r[r33]=1
                                        margs[r33][6]=margs[r33][1]+1



                                    for r1 in samelink[h]:
                                        if r1==r33:
                                            continue
                                        if r33 in WORDS and r1 in WORDS:
                                                if Sample[r33]!=Sample[r1]:
                                                    if Sample[r1]==0:
                                                        #W0=W0+r_wts1[w][0]
                                                        #margs[r][0]=margs[r][0]+1
                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                            expns[r33][hhlll] =C1
                                                            if r33 not in Relational_formula_filter:
                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                        else:
                                                            expns[r33][hhlll] = expns[r33][hhlll] + C1
                                                    elif Sample[r1]==1:
                                                        #W1=W1+r_wts1[w][1]
                                                       # margs[r][1]=margs[r][1]+1
                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                            expns[r33][hhlll] =C1
                                                            if r33 not in Relational_formula_filter:
                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                        else:
                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                    elif Sample[r1]==2:
                                                        #W1=W1+r_wts1[w][1]
                                                       # margs[r][1]=margs[r][1]+1
                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                            expns[r33][hhlll] =C1
                                                            if r33 not in Relational_formula_filter:
                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                        else:
                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                    elif Sample[r1]==3:
                                                        #W1=W1+r_wts1[w][1]
                                                       # margs[r][1]=margs[r][1]+1
                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                            expns[r33][hhlll] =C1
                                                            if r33 not in Relational_formula_filter:
                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                        else:
                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                    elif Sample[r1]==4:
                                                        #W1=W1+r_wts1[w][1]
                                                       # margs[r][1]=margs[r][1]+1
                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                            expns[r33][hhlll] =C1
                                                            if r33 not in Relational_formula_filter:
                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                        else:
                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                    elif Sample[r1]==5:
                                                        #W1=W1+r_wts1[w][1]
                                                       # margs[r][1]=margs[r][1]+1
                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                            expns[r33][hhlll] =C1
                                                            if r33 not in Relational_formula_filter:
                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                        else:
                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                    elif Sample[r1]==6:
                                                        #W1=W1+r_wts1[w][1]
                                                       # margs[r][1]=margs[r][1]+1
                                                        hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                        if r33 not in expns or hhlll not in expns[r33]:
                                                            expns[r33][hhlll] =C1
                                                            if r33 not in Relational_formula_filter:
                                                                Relational_formula_filter[r33]=WORDS[r33]    
                                                        else:
                                                            expns[r33][hhlll] = expns[r33][hhlll] +C1 




                    #Computing Marginal Probability of original
                    margs1={}
                    for t in margs:
                        pass# print(t,margs[t])
                        gh=[]
                        if iter1[t]>0:
                            for kk in margs[t]:
                                vv=float(kk)/float(iter1[t])
                                if float(vv)>=1.0:
                                    gh.append(float(1.0))
                                elif float(vv)<1.0:
                                    gh.append(abs(float(vv)))
                            margs1[t]=gh
                    #d_tt={}
                    margs2={}
                    #d_tt[0]="Neural_Networks"
                    #d_tt[1]="Probabilistic_Methods"
                    for dd in margs1:
                        v=max(margs1[dd])
                        print(v)
                        if v>0:
                            margs2[dd]=v
                    #check the marginal
                    for t in margs:
                         print(t,margs[t])
                    for t in margs1:
                        s=0
                        for dd in margs1[t]:
                            s=s+dd
                        pass#print(t,s)

                    #predicting review original
                    sampled_doc=[]
                    pred_t=[]
                    for a in margs1:
                        for ss in range(0,len(margs1[a])):
                                if margs1[a][ss]==margs2[a]:
                                    #print(a,d_tt[ss])
                                    sampled_doc.append(a)
                                    pred_t.append(d_tt[ss])
                    ss=set(sampled_doc)
                    sampled_doc_up=[]
                    sampled_doc_up_map1={}
                    for kk in ss:
                        sampled_doc_up.append(kk)
                    for tt in sampled_doc_up:
                        ggf=[]
                        gvv=[]
                        c=0
                        for gg in range(0,len(sampled_doc)):
                            if tt==sampled_doc[gg]:
                                ggf.append(pred_t[gg])
                        for ggh in ggf:
                            if c<1:
                                gvv.append(ggh)
                                c=c+1

                        sampled_doc_up_map1[tt]=gvv

                    cx=0   
                    for s in sampled_doc_up_map1:
                        if len(sampled_doc_up_map1[s])>1:
                                cx=cx+1
                               #print(s,sampled_doc_up_map[s])


                    #print(doc_per_pred_topic)
                    print(cx)

                    ffd=open("Original_Prediction1.txt","w")

                    for s in sampled_doc_up_map1:
                        ccvb=str(s)+":"+str(sampled_doc_up_map1[s])
                        ffd.write(str(ccvb)+"\n")
                    ffd.close()

                    #Computing Prediction Probability
                    from sklearn import svm
                    #from sklearn import cross_validation
                    from sklearn.model_selection import cross_validate
                    from sklearn.preprocessing import MinMaxScaler
                    from sklearn.metrics import (precision_score,recall_score,f1_score)
                    from sklearn.feature_extraction.text import CountVectorizer
                    pred=[]
                    true=[]
                    #topicindex doc_per_pred_topic sampled_doc_up_map
                    f4=[]
                    f5=[]
                    f6=[]
                    #for d in range(0,2):
                    for t in margs2:
                       # if t in qrat and t in sampled_doc_up_map1:
                                        for tt in sampled_doc_up_map1[t]:
                                                        #print(tt,d_tt[0])
                                                        if str(tt)==str(d_tt[1]):
                                                            pred.append(1)
                                                        else:
                                                            pred.append(0)
                                                        if str(label[t])=='Probabilistic_Methods':
                                                            true.append(1)
                                                        else:
                                                            true.append(0)
                    #print(precision_score(true,pred))
                    #print(recall_score(true,pred))
                    #print(f1_score(true,pred))
                    f4.append(float(precision_score(true,pred)))
                    f5.append(float(recall_score(true,pred)))
                    f6.append(float(f1_score(true,pred)))
                    #Explanation Generation
                    import operator
                    correct_predictions_r = {}

                    for m in margs1.keys():
                                if m in WORDS and m in sampled_doc_up_map1:
                                              correct_predictions_r[m] = 1
                                #if len(WORDS[m])==0:#or ratings[m]==3:
                                   # continue
                                #else:
                                   # correct_predictions[m] = 1
                                #if margs[m] > 0.5 and spamindex[m] ==-1:
                                    #correct_predictions[m] = 1
                    fft_r=open("expn_n1_r1_or.txt","w")  
                    explanation_r={}
                    for e in expns: 
                        if e in correct_predictions_r:
                            sorted_expns_r = sorted(expns[e].items(), key=operator.itemgetter(1),reverse=True)
                            z = 0
                            for s in sorted_expns_r[:]:
                                z = z + s[1]
                            rex_r = {}
                            keys_r = []
                            for s in sorted_expns_r[:]:
                                #if 'same' in s[0]:
                                rex_r[s[0]] = s[1]/z
                                keys_r.append(s[0])
                            #if "Sameuser" not in keys or "Samehotel" not in keys:
                                #continue
                            sorted1 = sorted(rex_r.items(), key=operator.itemgetter(1),reverse=True)
                            #if sorted1[0][0]=="JNTM":
                            #print(str(e) +" "+str(sorted1))
                            gg=str(e) +":"+str(sorted1)
                            explanation_r[e]=sorted1
                            fft_r.write(str(gg)+"\n")
                    hhh="Explanation_Topic1"+"_original"+" before user feedback"+".txt"
                    f11_r=open(hhh,"w")
                    Store_Explanation_r={}
                    for t in explanation_r:
                        #for k in WORDS1:
                               #if str(t)==str(k):
                                    ggg=str(t)+":"+str(explanation_r[t])
                                    f11_r.write(str(ggg)+"\n")
                                    print(t,explanation_r[t])
                                    print("\n")
                                    Store_Explanation_r[t]=explanation_r[t]
                    return WORDS,Store_Explanation_r


WORDS,Store_Explanation_r=MLN_EXP.cora_mln()
# Out:
# C:\Users\khanfarabi\anaconda\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 0.47907140344706295
# 0.47907140344706295
# 0.0687439389055906
# 0.002640015532366813
# 0.06103377363890672
# 0.01961062269509528
# 0.11517486657803
# 0.05974372778718251
# 0.20062594399897393
# 0.10203998285838545
# 0.09305740214764069
# 0.008775545833786702
# 0.07311008542160147
# 0.0550851246124322
# 0.09636986047578744
# 0.11845281766090876
# 0.21134486895130888
# 0.02616676678498764
# 0.0973495235851165
# 0.08560782155697422
# 0.08524210708211588
# 0.10886615153980561
# 0.02849127930337325
# 0.07680091353865093
# 0.09791088627800515
# 0.07180211999653818
# 0.19394082224447895
# 0.05661458828084287
# 0.05884768851757338
# 0.09471321416839251
# 0.17236673204934816
# 0.04895851184623712
# 0.029922564622627434
# 0.05801505069745572
# 0.07762622292416732
# 0.07690738654114926
# 0.025522637245136703
# 0.0019384424913078124
# 0.06230844292437132
# 0.1156372166060714
# 0.00996341106436982
# 0.1119480210336925
# 0.07837744800193469
# 0.10283230403431431
# 0.046592051736166096
# 0.01229860424292728
# 0.1022277930899308
# 0.09833218477414185
# 0.014775457593402708
# 0.042532285900597766
# 0.038475408437522285
# 0.0026513680685786856
# 0.016318523448655586
# 0.021600389510875617
# 0.053767968570946345
# 0.09487781697713782
# 0.08808889695969702
# 0.008854730775901598
# 0.014381959258841115
# 0.02441993351064231
# 0.09307954888479342
# 0.04909880291659141
# 0.28837086737104345
# 0.01835712127046163
# 0.05199994983748191
# 0.09839961177716516
# 0.01926034103559182
# 0.16705956819236822
# 0.10227873539079957
# 0.023430831418119857
# 0.06178264540232703
# 0.07085657208435625
# 0.010700576545563334
# 0.005463804570535413
# 0.01133408568309957
# 0.0864105889020036
# 0.09115577501080874
# 0.10559634991200817
# 0.011558753314455661
# 0.07354122215913494
# 0.01205773445954006
# 0.011242010119692392
# 0.013828166417710008
# 0.022015754498022067
# 0.03611178356534539
# 0.08308317080124716
# 0.05285910967945173
# 0.10821158273921638
# 0.05843949816113869
# 0.08597093418735158
# 0.0916983463810187
# 0.025745115239711236
# 0.05855360092866657
# 0.05547245524117539
# 0.12453554561061064
# 0.10716878733803847
# 0.11531430769996576
# 0.10494348862141634
# 0.0685098471522182
# 0.07942731377159806
# 0.09526361856906351
# 0.14425211392704396
# 0.0905709155136818
# 0.07900083609868347
# 0.24791776881555938
# 0.10813885643706456
# 0.0493431450561963
# 0.062355554658718115
# 0.03732837065657524
# 0.19561152586150832
# 0.17747504700188732
# 0.0008338763174298158
# 0.11658854837259902
# 0.11751623225559582
# 0.05047624071420875
# 0.006576485327366877
# 0.028388000073516273
# 0.05941583415812379
# 0.03716524148114919
# 0.10979915461646883
# 0.06152081656451758
# 0.04677441290203965
# 0.03563254362351975
# 0.11775230701997819
# 0.05102438862031411
# 0.09039384097798953
# 0.10115043185788242
# 0.036402321927260894
# 0.07629775105709491
# 0.07368966179042802
# 0.2793675633231323
# 0.050220016387674926
# 0.0004820494279081933
# 0.08986264143992884
# 0.04362520211407095
# 0.01143842959626562
# 0.11478310942014458
# 0.011151726105478432
# 0.06298998352960761
# 0.15447158059912303
# 0.11535592131893546
# 0.027133339042256233
# 0.07355670003471826
# 0.04693173858139521
# 0.08430541604441277
# 0.12355812076849737
# 0.07706197881234655
# 0.11299121122562905
# 0.018895543138163995
# 0.2126547271736492
# 0.1424205471553217
# 0.10584109256251972
# 0.05554109496270965
# 0.04928934033561316
# 0.04251432075125339
# 0.009824259585609063
# 0.06778495397856255
# 0.058639617656487286
# 0.1145623092595911
# 0.12222212903536789
# 0.01735587077335543
# 0.07555134365578786
# 0.09173656190454238
# 0.052411060208499394
# 0.047374946851679756
# 0.08541712486384812
# 0.29723704385158023
# 0.03656767215429535
# 0.10819865656649097
# 0.08270994723651781
# 0.08015357995000594
# 0.06169085316930112
# 0.07008284987713975
# 0.015631498928454945
# 0.1655493517863328
# 0.059594266283261255
# 0.053880658325825115
# 0.07089471247881995
# 0.006200449311523748
# 0.14733839510812496
# 0.04048035160357011
# 0.0129641520943643
# 0.062252399450546614
# 0.006876934857458994
# 0.12991690507127673
# 0.11992671032552915
# 0.0749643071521009
# 0.06766689428123684
# 0.008403829575801991
# 0.10785865131344163
# 0.0010124481814378639
# 0.13448451939097572
# 0.10095182414079973
# 0.10347803567271607
# 0.04826732068369566
# 0.0938350393791395
# 0.11593382404491992
# 0.091926635971323
# 0.11662520211964789
# 0.057189802905856846
# 0.10336493449753026
# 0.04812139407737015
# 0.050185115010486614
# 0.01798866598764204
# 0.012548466788033119
# 0.07126925355968361
# 0.008601633685888288
# 0.07295491156693068
# 0.09686252401745077
# 0.17596939067398842
# 0.08280805370287647
# 0.021357992056193154
# 0.0886471320504022
# 0.007082020658434662
# 0.03621053514965289
# 0.046777469576693154
# 0.21531786689049548
# 0.022999613180103573
# 0.1467728368406186
# 0.20121665911210962
# 0.00748460764173986
# 0.006033512193976409
# 0.1985740841018565
# 0.06671050537158185
# 0.07944607726485997
# 0.11393228180173942
# 0.04336174505112733
# 0.11595265991830273
# 0.029796645783722764
# 0.07201425862909072
# 0.1350525520860163
# 0.023364035687006623
# 0.07521872337156732
# 0.06627246222669347
# 0.13430378859942993
# 0.04160484135666431
# 0.057698428437968685
# 0.04623930376098839
# 0.023460463888018035
# 0.056655706038926223
# 0.09628658800649648
# 0.09494850183228343
# 0.049090088393846876
# 0.2843693468960744
# 0.0128617405866438
# 0.022024308853102026
# 0.053546312928687056
# 0.019624676326249868
# 0.08300572987497601
# 0.012380087183665123
# 0.1377168557773336
# 0.040698377061521795
# 0.04040816957128823
# 0.095602247261525
# 0.010588564328161465
# 0.14022669373252217
# 0.08249089395216169
# 0.021923800740663357
# 0.17845510188270208
# 0.09385037257552498
# 0.12088542948756564
# 0.06656915047452239
# 0.1177313925790997
# 0.03955472831643436
# 0.04989499116656049
# 0.00957486468193014
# 0.1438242305706443
# 0.1096737842595733
# 0.12148035570602078
# 0.08819976267090124
# 0.00011139089005784975
# 0.03870914197020725
# 0.03637786702345647
# 0.04157935893245901
# 0.11569057475336664
# 0.2295052316591193
# 0.14543831652859796
# 0.0863548006203374
# 0.05838509212698517
# 0.0009088899205293988
# 0.1144488674183195
# 0.022089027796218574
# 0.05912991243835286
# 0.0794276271660107
# 0.03915719858015887
# 0.014532183058184267
# 0.09324038006086433
# 0.011283327758807915
# 0.034120094865890294
# 0.10750460090646774
# 0.12086915559475353
# 0.007891074292121991
# 0.10226118483614488
# 0.09165956780525641
# 0.10161456776888078
# 0.019781864796779902
# 0.02849405744188882
# 0.07254813694442486
# 0.10958337927186035
# 0.1216694978114291
# 0.12501833700985399
# 0.12376199925717357
# 0.0187970653016164
# 0.06384912621810024
# 0.034023708490794724
# 0.0029832012904678074
# 0.09013041937317146
# 0.09860983362634279
# 0.09757634086085265
# 0.10917574443632927
# 0.09896561581266305
# 0.08404527331918576
# 0.05389216100836669
# 0.08605184035280622
# 0.04234974518932455
# 0.05119439464282827
# 0.17637718902652544
# 0.0006378896909557952
# 0.12169132350890322
# 0.10738650858409682
# 0.09703607395961544
# 0.025141402262054635
# 0.1000819158925732
# 0.06164824471087749
# 0.025575715116692654
# 0.13489377185323204
# 0.07859926636665959
# 0.0031948283951622747
# 0.044833159787314836
# 0.05202100259540687
# 0.06392823142696602
# 0.08778160296839133
# 0.04432220833714995
# 0.09840502121824979
# 0.02748211803216216
# 0.16413426229863626
# 0.016060306356023624
# 0.09918349289824258
# 0.06826769799588284
# 0.09182911841290231
# 0.04116581735508262
# 0.06312884248473172
# 0.11081097933340722
# 0.028192119853300168
# 0.10933308316351731
# 0.053587850368724044
# 0.10795004883323023
# 0.12430780242627626
# 0.01649997149940796
# 0.0702004826594721
# 0.17840767682885295
# 0.1284070071377933
# 0.11324771001641531
# 0.07377219583830841
# 0.08323832585996704
# 0.03803471057650254
# 0.014435262332771037
# 0.07664296808385285
# 0.07677746441291688
# 0.16632144812450644
# 0.07788404598626153
# 0.045473712098589636
# 0.015264939411113065
# 0.07728419760887473
# 0.09518597420383756
# 0.05539638919466783
# 0.0839515699272515
# 0.0667898815405773
# 0.088432962437752
# 0.010996410575114357
# 0.1167752026407729
# 0.1072532680824988
# 0.17214969426344617
# 0.04629697937083521
# 0.1098633131118818
# 0.0051707521007418045
# 0.10318110194037966
# 0.0987297838600304
# 0.07040018998818232
# 0.0974768567515173
# 0.0828280595976989
# 0.03225259574868744
# 0.08639912514427162
# 0.0716280163934262
# 0.058040781826054766
# 0.08821353745016913
# 0.026566089491536715
# 0.030138793484447368
# 0.1345175856569677
# 0.023345730509831242
# 0.1049550472252262
# 0.06268391638382786
# 0.15430638011647957
# 0.12123768096044574
# 0.015918130860519852
# 0.1163565506654477
# 0.0607846707292754
# 0.030268382969631746
# 0.12020357182449393
# 0.06762009041431116
# 0.014477623490787628
# 0.016558499185130415
# 0.01258677668433339
# 0.20141495518339647
# 0.2955615746664674
# 0.04971592972844274
# 0.03905717872885539
# 0.19204349589185432
# 0.07381361556784805
# 0.10216361958392728
# 0.04127009179662533
# 0.1068532116890415
# 0.2674939199532078
# 0.07437562459781544
# 0.06118503000315467
# 0.134971737506966
# 0.1105475794719829
# 0.06932055222959466
# 0.04449138582732437
# 0.02216949185699979
# 0.06792267209166669
# 0.297081394938125
# 0.07534627083369316
# 0.03927504275206717
# 0.10492437355629336
# 0.08260318222733898
# 0.09586745076591008
# 0.09542203213465994
# 0.023517257665769842
# 0.12849081662831485
# 0.0543690116373462
# 0.14099421839726944
# 0.10558162932222304
# 0.0893043477199239
# 0.07835917050289498
# 0.06802550956143938
# 0.0904789571908563
# 0.0004803928304693006
# 0.08937844454487043
# 0.007917087590278094
# 0.02182102211266712
# 0.11582498737471913
# 0.03657362349772719
# 0.09412383540007596
# 0.021230071227622216
# 0.049401742406573024
# 0.09894091708609498
# 0.08136029672787137
# 0.0460696650458472
# 0.017731737466679
# 0.11380043053881561
# 0.08732883301649985
# 0.08625696776495417
# 0.08373612141061149
# 0.03517678234749444
# 0.006090758977347122
# 0.00890776500433288
# 0.006653368192133247
# 0.027239538779974648
# 0.11315924744895567
# 0.018292707107701145
# 0.10118638149595904
# 0.008841346558756902
# 0.08520434066438554
# 0.042319402709604104
# 0.06914529528030777
# 0.025546804100214704
# 0.16174218214961655
# 0.12811637704678303
# 0.022123724974283276
# 0.05610636050633333
# 0.09189260018629652
# 0.05804221371508167
# 0.10973708087904377
# 0.049732153122264866
# 0.08815251519769163
# 0.08337838859060487
# 0.01884649878449529
# 0.04731222704297422
# 0.11867137775129388
# 0.14164024124619767
# 0.2303125977978584
# 0.045988464589244105
# 0.016934672819728158
# 0.059371945682537564
# 0.0443379874972607
# 0.09961290453564764
# 0.24969431537909947
# 0.11118090572165507
# 0.12064560257911316
# 0.07699745808507263
# 0.10193388472931497
# 0.23904317109501727
# 0.0718735092888163
# 0.06651355745783383
# 0.11102845179090881
# 0.1045888385810737
# 0.10863510339948057
# 0.08928314163928763
# 0.11503805002755807
# 0.02106894390446279
# 0.03458576384759182
# 0.04391168461258588
# 0.0006707602087158149
# 0.021135361724797685
# 0.007253624287981153
# 0.014253483368041886
# 0.01070815466661601
# 0.07579278373499154
# 0.07749124049282363
# 0.05959417451899918
# 0.0319275244896271
# 0.10414283385401768
# 0.04118736512959886
# 0.23926689130562273
# 0.00023233671702427294
# 0.01032373541503262
# 0.033035511240937954
# 0.11908973501240305
# 0.1012681043749667
# 0.20678618006269556
# 0.05040805779482693
# 0.0807384649331161
# 0.03450632527454223
# 0.15800635937061658
# 0.09031339727695664
# 0.060003576636865064
# 0.030256802353732293
# 0.04374981330973482
# 0.03804972875563373
# 0.2318205583361902
# 0.22909021839978438
# 0.002221248977351209
# 0.12851614172095938
# 0.10008450665617252
# 0.045476365970376076
# 0.07967299580365417
# 0.03705233680487818
# 0.06647743133298512
# 0.102856752065271
# 0.08933243041212369
# 0.08931289073199677
# 0.010704385642214986
# 0.05980252820501908
# 0.0313795122886098
# 0.2678748081007908
# 0.03961784754580988
# 0.029014139103471392
# 0.13039851373471223
# 0.06376473198809252
# 0.06445906174603022
# 0.11085341444081298
# 0.0017594953372266353
# 0.04127188039352836
# 0.08525505896315011
# 0.09877685065993724
# 0.012099937377673231
# 0.06813035894671504
# 0.051363357783497876
# 0.11788378841455571
# 0.08865301002736248
# 0.10808003274496869
# 0.023304176117123987
# 0.09217915916600483
# 0.08521325747632269
# 0.09837142157772993
# 0.0670023663718905
# 0.003038700822933227
# 0.20661023109116217
# 0.028917284495167284
# 0.02331280922746015
# 0.11979088907289015
# 0.07049576815160163
# 0.04751948762435554
# 0.022376278205968103
# 0.0349902603494211
# 0.019585435147248642
# 0.09696815273972859
# 0.09512040236997032
# 0.10193236000583838
# 0.08824658473933267
# 0.0571161690316242
# 0.030781869490305813
# 0.02384758886690197
# 0.10801383865083103
# 0.0708427637290796
# 0.03408193873704368
# 0.0288510094349258
# 0.10818156691534664
# 0.05854876536901921
# 0.07890477092229098
# 0.00966775924056762
# 0.10957038160947485
# 0.10472400445299734
# 0.012240250296671085
# 0.0515219839946236
# 0.07710829239143513
# 0.10788806729774869
# 0.0544391305371873
# 0.0007723900756532176
# 0.05913208547605997
# 0.04684780367595631
# 0.04275536905141675
# 0.1716525431987882
# 0.11241866136364986
# 0.0019433984339729538
# 0.11814874899860539
# 0.10399683464100806
# 0.10294509396738538
# 0.07736146123397813
# 0.02746843856900827
# 0.005924948162288612
# 0.07282546340664997
# 0.04357263027808356
# 0.10851942421042016
# 0.11395875049381987
# 0.054160603220600456
# 0.0817475163318292
# 0.11101934247955236
# 0.1296906225276382
# 0.013134573752572543
# 0.13210164251007317
# 0.10009542049669473
# 0.0015054135455958573
# 0.04561184156646658
# 0.10321493789255698
# 0.137492415009264
# 0.020551514816707916
# 0.04649310180675936
# 0.024183675798967186
# 0.035736576314567836
# 0.05328860367081645
# 0.07245867456144439
# 0.10752201030940367
# 0.029228037950638885
# 0.023746180169866293
# 0.17323858318210295
# 0.10198690705537727
# 0.1369503566196456
# 0.015138224600508954
# 0.06365077966340771
# 0.054788058114465854
# 0.14368971112364204
# 0.09493195463367865
# 0.006736393343360181
# 0.043963305164282485
# 0.02780936252883881
# 0.22345195091137715
# 0.11949726847544329
# 0.10114663596900808
# 0.13170576827505687
# 0.021298575364300687
# 0.14127048121275831
# 0.07210379420559954
# 0.13052442602511571
# 0.04354752479503865
# 0.08513231329442417
# 0.06736613571747152
# 0.031849879861033936
# 0.01959375373355776
# 0.1164731871281196
# 0.07954628765240657
# 0.11877023246465879
# 0.038006509054834825
# 0.06873257689299483
# 0.12286393256241734
# 0.2778745342532586
# 0.06660630633114517
# 0.12134434746004896
# 0.10972960846585778
# 0.03390810465050287
# 0.04460010209850385
# 0.08426803966548435
# 0.08427090724341124
# 0.24060534432928715
# 0.12356335152424724
# 0.07734251221678645
# 0.07879296264041591
# 0.018341177029828293
# 0.022283696536914754
# 0.039420277957632144
# 0.11222225984214107
# 0.11135449758032823
# 0.06862028556927391
# 0.09748830895873328
# 0.061497738701157045
# 0.004103714000566638
# 0.004751111354062032
# 0.04468293952285973
# 0.13700076479184642
# 0.04413601680941803
# 0.1059266331881561
# 0.007390425393894007
# 0.05321841052726539
# 0.017301577637475973
# 0.00489306966689429
# 0.03974075991379089
# 0.12527829462883644
# 0.09522935503298935
# 0.0649076775774392
# 0.04904011530827945
# 0.016102865173823755
# 0.014892030062129136
# 0.07663624996443841
# 0.06628628488700361
# 0.06988750098704988
# 0.03737153571106544
# 0.1044390030632214
# 0.008430303178522114
# 0.059052714736002265
# 0.06820288506477468
# 0.07577510721871461
# 0.030245176292148512
# 0.08292067458754449
# 0.06161843439408743
# 0.10599153628365032
# 0.01631367527315364
# 0.14487856893097673
# 0.17485939037578957
# 0.0021057409941800387
# 0.03652547718406374
# 0.0031540025510577996
# 0.09893975053780113
# 0.21099935756964738
# 0.10750942777798767
# 0.08513289756468079
# 0.12044482225692565
# 0.10929857573770319
# 0.03970932105660918
# 0.011560693338267813
# 0.03228750842709793
# 0.0384303761348781
# 0.08827258127614779
# 0.05020939182768436
# 0.055146799049299866
# 0.19864500697062626
# 0.03281259581310547
# 0.0792802628391619
# 0.1683165404293827
# 0.14245792513410316
# 0.07380187792055914
# 0.03933670680883172
# 0.040766795588133564
# 0.012636371653942158
# 0.013834852891828064
# 0.07669720504455335
# 0.011317837557381027
# 0.04212902844977562
# 0.08617270984866543
# 0.09344433130532614
# 0.029175225054287823
# 0.06980864247032625
# 0.023633561286833027
# 0.0956223202129779
# 0.09811615697145859
# 0.08457638594192907
# 0.0982771290663722
# 0.058446262584961994
# 0.07419553494212461
# 0.1880763554313467
# 0.07233709568094082
# 0.2523399913079276
# 0.018163384727269638
# 0.10584438750880021
# 0.06915070581168992
# 0.01608718170800305
# 0.051950474071327246
# 0.2581301454602021
# 0.0005149414551299802
# 0.016784679157679894
# 0.030363190627798686
# 0.12788378462741756
# 0.06941564281480228
# 0.020431031527997523
# 0.26113610567167234
# 0.09776575417495881
# 0.11802919389662503
# 0.11378034991147046
# 0.0446421619347126
# 0.09403944036029921
# 0.04676301886234813
# 0.018177243936453258
# 0.034118933955843866
# 0.07247501690591729
# 0.01875668769515504
# 0.12910594558689248
# 0.10952465751990148
# 0.060160458817186124
# 0.026741015606697838
# 0.03309275386921817
# 0.11244015797627493
# 0.1579058480276383
# 0.2328732798583486
# 0.07816896729573519
# 0.041432034632589376
# 0.11161246461741514
# 0.06841634393123808
# 0.008603776621885051
# 0.10811929703563883
# 0.009046520081929077
# 0.06556739679445112
# 0.04203576035670742
# 0.0024366044361073813
# 0.0016379166127798994
# 0.01842023440784979
# 0.0034460240364990735
# 0.12238742332095442
# 0.0169017737513395
# 0.03957323960380277
# 0.11759984155617031
# 0.02724092283849433
# 0.05707443179765148
# 0.007279254765062304
# 0.017294673046311826
# 0.03263258130893798
# 0.08001309120621802
# 0.052825985789850316
# 0.10761429977433068
# 0.09219268965732008
# 0.07826152631107897
# 0.08694621025336136
# 0.03660694012242227
# 0.06604511206501518
# 0.013593434482606193
# 0.02955123485407296
# 0.06410427829174248
# 0.22378517032545608
# 0.11438549948043508
# 0.03084937978445612
# 0.15590463143938615
# 0.07883321584180225
# 0.09020198496069431
# 0.02463599165447594
# 0.04547990101223909
# 0.03910013611155161
# 0.08910510410650141
# 0.05691905585723178
# 0.08913202701989431
# 0.07427091425324883
# 0.03452029784982258
# 0.029003827615952993
# 0.10574520843694746
# 0.014791741852608453
# 0.05237598903040053
# 0.013246664715294898
# 0.09848468054196247
# 0.20897745108214283
# 0.1170553141285362
# 0.01949912513035601
# 0.1103687076491412
# 0.03440250415663981
# 0.12145793440614217
# 0.07781480449648925
# 0.07537950884606703
# 0.04176247270467548
# 0.051722371142400525
# 0.11023327291362572
# 0.12354927864959431
# 0.0007815181405625982
# 0.19308111223199953
# 0.05523812429451436
# 0.034548021494296144
# 0.017796401039694376
# 0.11627950734399173
# 0.27962346024317897
# 0.11657821150159742
# 0.00019734707398599838
# 0.10054163450818465
# 0.11048696326723106
# 0.0945805829213553
# 0.04361426408636959
# 0.06559270104944803
# 0.005876191132625497
# 0.04865832807249992
# 0.07036351408278985
# 0.09661678672133123
# 0.07456379775964472
# 0.0790213648436402
# 0.02227645516379495
# 0.03499265810203167
# 0.06870875534819954
# 0.05019680488977807
# 0.10865537058824137
# 0.21976581539883366
# 0.03368815408472203
# 0.016736826765107793
# 0.02560859258598369
# 0.1274800419663078
# 0.015488484619936238
# 0.28165350493609864
# 0.08209586884770226
# 0.12473163978161728
# 0.00256681190920649
# 0.23321400321220376
# 0.0745795885128967
# 0.027833310742464534
# 0.09035273996681414
# 0.09595305421222955
# 0.13509859027377358
# 0.11036516205630897
# 0.0008694068310910463
# 0.012109698907842636
# 0.026346015095716768
# 0.1236343882102433
# 0.06381178124365794
# 0.11472097060617703
# 0.09244068061511823
# 0.0943621146116147
# 0.10671544965705315
# 0.08499359925582561
# 0.06549823398790866
# 0.018540921034486235
# 0.012927577001651924
# 0.14185668626770986
# 0.012905638503730166
# 0.035094980004309106
# 0.10963450774792727
# 0.07629235405658408
# 0.06354803524380959
# 0.05814933149461565
# 0.11832829987324645
# 0.04848271633881063
# 0.0836264123018865
# 0.1404565916508299
# 0.0711826225555191
# 0.018053903946149363
# 0.14519905271478395
# 0.052497763932413344
# 0.10514563737051308
# 0.07417256539192996
# 0.08326907085480628
# 0.23490301891597887
# 0.03910337774134298
# 0.2515110799583653
# 0.025797540746983927
# 0.043372162755835886
# 0.09703877237107539
# 0.05102530360167146
# 0.0070543139664359655
# 0.03796975103481803
# 0.00614802577017981
# 0.10839721290790383
# 0.13955558365221143
# 0.07673859076477074
# 0.05087245649188976
# 0.08852309035012795
# 0.024812354468109143
# 0.014767118134316748
# 0.08747390492102924
# 0.11480861075172333
# 0.010812056832946615
# 0.0013433678570714536
# 0.15340645960424837
# 0.04202997758646354
# 0.025999875366858105
# 0.10755677240826034
# 0.1108700364444466
# 0.08006308173506482
# 0.1080929279468259
# 0.10325100974676615
# 0.07119461766855006
# 0.02655272478515247
# 0.038386934146213414
# 0.05208700750726958
# 0.07300530883047895
# 0.01587565775567823
# 0.022529706988265175
# 0.10903130250380588
# 0.02278503016740996
# 0.11778211897226343
# 0.10423830153906333
# 0.08130412656562713
# 0.10630639626903704
# 0.0739440835126538
# 0.13244558119633332
# 0.043873037115891744
# 0.07091748596814107
# 0.10329259022104964
# 0.0346399055195975
# 0.008260655632719605
# 0.1054182094345556
# 0.018116774164155802
# 0.08951647670247276
# 0.11273215238422463
# 0.10240758893690316
# 0.07274940934265961
# 0.17898021599320257
# 0.0013477719438405034
# 0.08047227258730649
# 0.08899703861318364
# 0.050967152530417836
# 0.04057458835922978
# 0.03155573322002836
# 0.08105980012677028
# 0.051105178546892005
# 0.016655861083170076
# 0.0026454782024356582
# 0.05600900703961753
# 0.020491189757949724
# 0.03517725981304787
# 0.10130438921455276
# 0.08233484743624497
# 0.009466332825726731
# 0.15458924484446535
# 0.09239407555357604
# 0.02069715275816386
# 0.08299799912785888
# 0.07965395467618774
# 0.1482707507970109
# 0.16119824202983712
# 0.2905453971086761
# 0.04248113625126204
# 0.041528268634421384
# 0.05987766757469837
# 0.013798874406175221
# 0.04070171452411153
# 0.05243005270894274
# 0.012781333353029112
# 0.06323563676779909
# 0.11084968822783248
# 0.037098228395220256
# 0.07982126665679179
# 0.10984099812804171
# 0.017206820385979538
# 0.009628569239723661
# 0.08168724410261552
# 0.1279504024345861
# 0.049016867193838576
# 0.13839310584009312
# 0.05387154127511462
# 0.030758690639745456
# 0.05112858148281518
# 0.2266685446725003
# 0.005326434863711316
# 0.009154883644702627
# 0.2889886203650244
# 0.08611804862093786
# 0.11498119256876027
# 0.08171996357826039
# 0.12231723133086003
# 0.028530020076271367
# 0.10247972818976447
# 0.1691016682038251
# 0.03479853254720933
# 0.012440877397278838
# 0.034300757887787525
# 0.023294529714080636
# 0.005428086318607472
# 0.08933992598486906
# 0.15064434594576592
# 0.011587310076437873
# 0.07065699822402927
# 0.11874670028390577
# 0.24296171589899873
# 0.024008057118743986
# 0.0047794060613640665
# 0.00744210943399104
# 0.10557556386347466
# 0.13918901984720045
# 0.12299425985385948
# 0.1587938189477438
# 0.055040404792284225
# 0.056690066284428076
# 0.1099293714081061
# 0.04170724840908291
# 0.0051737860066679575
# 0.009774799790172928
# 0.05667214208198934
# 0.02575060567286913
# 0.0021330655974280965
# 0.001957482597406024
# 0.027194971025216175
# 0.043154265216091336
# 0.016785221864021538
# 0.044604897430193136
# 0.05761374475062364
# 0.04771236307486526
# 0.11180931783423775
# 0.022965529294813103
# 0.20083347315838762
# 0.002474788353183377
# 0.09163703891927877
# 0.14724893719298915
# 0.026941049968018382
# 0.08005738836597809
# 0.0709871722190446
# 0.05484829219989662
# 0.205115772295261
# 0.04680563216899469
# 0.00650755295667349
# 0.09948756460686703
# 0.024674245884498514
# 0.07557237777280035
# 0.19754801782508125
# 0.12336746214067673
# 0.09438823428092524
# 0.04454580807197228
# 0.04269045218718637
# 0.059586414057602344
# 0.04008162971425
# 0.06865993870237175
# 0.020686149559462796
# 0.06478993383195875
# 0.09025270040555045
# 0.03921874306321238
# 0.010714973020587104
# 0.11339961572635304
# 0.03513159063756388
# 0.07778146956722864
# 0.15634249860894534
# 0.013270345443537002
# 0.04274175299168392
# 0.10290472049242694
# 0.03616986829556146
# 0.02902118927367181
# 0.09553687925809506
# 0.08147631528470667
# 0.06676358159879547
# 0.01471937607690954
# 0.06710408502046683
# 0.08635480367302195
# 0.10254028649859093
# 0.03292464912388915
# 0.018313367702778693
# 0.05917158911604026
# 0.12939616926564868
# 0.11477771586745678
# 0.12408822111041762
# 0.036546356610638986
# 0.1209003639611177
# 0.10361154809562889
# 0.06924685306874812
# 0.019187953510503286
# 0.08325978824168867
# 0.09243424973893244
# 0.05323841918649308
# 0.012306415358525502
# 0.1046282965663804
# 0.04151464593542753
# 0.08551514119962922
# 0.09515314846188094
# 0.11366945806554274
# 0.018507156732949892
# 0.014265232671839878
# 0.12824267053283844
# 0.043537599062230425
# 0.039689903043399366
# 0.04630612968285297
# 0.09018282808125466
# 0.11456612832308832
# 0.1390595566620123
# 0.10933580290504752
# 0.04162616713011347
# 0.07808865000974707
# 0.05228143970746291
# 0.20216167164869936
# 0.10648729646404287
# 0.03791253201582867
# 0.053304082323109014
# 0.12608508849495326
# 0.07026660712234467
# 0.036292638122931264
# 0.08632428524281988
# 0.04499460686175971
# 0.05578566005644048
# 0.21870526900604914
# 0.07719366014167739
# 0.014084336472058867
# 0.05836540760547848
# 0.08492048367534943
# 0.11012429948068803
# 0.04547694336164099
# 0.09695765177243743
# 0.09147897803740113
# 0.1703033221145005
# 0.08257988510589087
# 0.12331381902614647
# 0.10428331478728614
# 0.2352928782828676
# 0.13073694558298588
# 0.07990686251205814
# 0.19518627996733562
# 0.0628434794944207
# 0.030924702625689027
# 0.17848249294959884
# 0.02727958445357037
# 0.08037366891185604
# 0.07897671807403495
# 0.11336260178831514
# 0.05722749611579725
# 0.09380225900997963
# 0.1161236523322946
# 0.050201188655677464
# 0.1657189236698524
# 0.05340293304429289
# 0.018434604125864285
# 0.027587140556572076
# 0.021117546493879646
# 0.01975824602430387
# 0.11385744149894828
# 0.03516972393185469
# 0.02088410677072805
# 0.06478930058795918
# 0.004658855770839243
# 0.08812026006806484
# 0.04294781817222304
# 0.021761869141592283
# 0.09584677008705811
# 0.15832987302361512
# 0.12655223140509997
# 0.20458751736779646
# 0.09737362822852236
# 0.09596983493923605
# 0.07111150813367972
# 0.03277828636647662
# 0.05618983836398228
# 0.18881827502676996
# 0.03817913079444113
# 0.16852429104055433
# 0.08224865721638008
# 0.08362617855893728
# 0.20552686879394622
# 0.06741676380356099
# 0.019193696587673448
# 0.05983764750607945
# 0.15041182726247393
# 0.025294875555329388
# 0.002380889744877601
# 0.12685089936410499
# 0.005388706397356113
# 0.02348148620673096
# 0.07780537476275573
# 0.04421164086528906
# 0.016324085318144776
# 0.002118561956864773
# 0.09845974662426771
# 0.08563934666928186
# 0.023723595154820365
# 0.007489682721868007
# 0.0483289845678162
# 0.06710198709122417
# 0.05218925244499484
# 0.13763959465789144
# 0.11340796384037921
# 0.07154045837585599
# 0.29871263955604677
# 0.1246120041119525
# 0.08970145386517714
# 0.03443696504420102
# 0.05798999499095747
# 0.04538172952515973
# 0.1467772006320478
# 0.0636459319925251
# 0.07893595831675038
# 0.13882412212649753
# 0.23478376332797524
# 0.004112636032125971
# 0.04869967872686454
# 0.045897987707233634
# 0.024565176591593296
# 0.11541934924438169
# 0.09746778506142517
# 0.07852198978113523
# 0.11766672235816156
# 0.03196071014364421
# 0.07317778824471755
# 0.20483397189461616
# 0.024329142662779968
# 0.08617317653076284
# 0.03773852773431108
# 0.12307716922413359
# 0.01965846605525512
# 0.07021063035016373
# 0.007745707695441806
# 0.04317583884881815
# 0.09971419072232768
# 0.06651748691774473
# 0.11853348969999489
# 0.07874558265331733
# 0.11141827044043018
# 0.12741992577918693
# 0.0959274563985254
# 0.08051491203066163
# 0.006603045134680463
# 0.08575554475343472
# 0.05615228724271604
# 0.03268301039397037
# 0.04381384056907178
# 0.26758906519002945
# 0.1346400941575785
# 0.07311813007825296
# 0.10970045999665068
# 0.01776067195207298
# 0.008302960965983597
# 0.11707817154137934
# 0.08719975015112658
# 0.0570536257690647
# 0.0746636968486698
# 0.22801275670662158
# 0.09778915595784665
# 0.12667621268427853
# 0.08335210457044129
# 0.09036949179210085
# 0.06912552900703872
# 0.06094575070481856
# 0.04728860051186834
# 0.03854869405441108
# 0.04870925281691063
# 0.03440833185301173
# 0.12204028346715401
# 0.034001943028255655
# 0.12488261062423212
# 0.10520472487318788
# 0.13705807241303725
# 0.02158640971409631
# 0.05782862356645968
# 0.09429023173906514
# 0.07343643911162423
# 0.24820835720609735
# 0.06272716425802038
# 0.10738252165387685
# 0.10850132927522849
# 0.10573688643142076
# 0.09228358849512686
# 0.07309154215131819
# 0.03350241616910221
# 0.07190098873578388
# 0.024152905189507634
# 0.048180311892225824
# 0.08057149434691302
# 0.0213616491588432
# 0.0011419090147201105
# 0.026565524017790443
# 0.13441687392974355
# 0.11321029769699298
# 0.09432192290555008
# 0.0933452696529683
# 0.2418657805937212
# 0.0281068291067883
# 0.09247369664912475
# 0.1384756162870875
# 0.03044821467932468
# 0.06938585764453964
# 0.1406589447289901
# 0.07950185944255561
# 0.10168501069536562
# 0.044533392995201315
# 0.012379781287059854
# 0.08854972682883755
# 0.010658337039343713
# 0.010258490616545712
# 0.12172527721472493
# 0.03315233472231438
# 0.11633150109727064
# 0.13971039903081572
# 0.041964967613274395
# 0.07744191003442702
# 0.07086144790012738
# 0.03571009543413228
# 0.10442581376423998
# 0.09869118017965173
# 0.08017927357484622
# 0.10048442162486737
# 0.07706912266603205
# 0.04662199225235819
# 0.08429629623264445
# 0.02349792307365084
# 0.09067252723778485
# 0.032542001287339084
# 0.0743030131917064
# 0.20443131518405622
# 0.06250120558683481
# 0.240331879117331
# 0.0203425879048309
# 0.08041615844699035
# 0.05930439265644338
# 0.05578047900058758
# 0.033216277676395456
# 0.06187223532566
# 0.13132650680020186
# 0.10091509749521277
# 0.1374578909547084
# 0.09558051038435544
# 0.11660299714108657
# 0.06374475324952322
# 0.02817527826162347
# 0.001896804754531023
# 0.09787362414510636
# 0.033584493291954676
# 0.07477027989669405
# 0.006726049673621115
# 0.07136624138443126
# 0.08323810634206685
# 0.10970249401655363
# 0.050581752831670546
# 0.0306946209870389
# 0.008460458897373901
# 0.0830952790541396
# 0.02098763128749004
# 0.11818731319405085
# 0.1094880151178389
# 0.06915400015630291
# 0.09796329589188135
# 0.06524457930560423
# 0.11611553871390667
# 0.2070831433214767
# 0.0907768303754245
# 0.12613663981742007
# 0.05409025995477956
# 0.041999380751000626
# 0.2031391011363558
# 0.10094772660887819
# 0.02721281983723678
# 0.11607805839989338
# 0.09237250242150274
# 0.18576985996798678
# 0.03358302783500677
# 0.030242988713550023
# 0.039601830335090904
# 0.09774607659243639
# 0.10810146665953191
# 0.06409715434283458
# 0.09398615442610125
# 0.04593630672701221
# 0.12128787689202103
# 0.03906477891570648
# 0.11807607436916145
# 0.20376097687839956
# 0.11220743467037131
# 0.11558943671077915
# 0.24952475711465838
# 0.05167817353678239
# 0.09905573685059876
# 0.013806673070312914
# 0.0329083378508056
# 0.06811765160608141
# 0.10248472021195398
# 0.09898662698178218
# 0.11067083875587069
# 0.008040128301487703
# 0.09377115667753944
# 0.15813612915184294
# 0.12137522721430571
# 0.0970510994662287
# 0.09373083238920854
# 0.13360562231610118
# 0.12020832382884039
# 0.03360726686205018
# 0.06967694347271125
# 0.021402708714290508
# 0.14158713938742884
# 0.09545402544763815
# 0.12276023767856337
# 0.19665496249881054
# 0.07811570775347565
# 0.05600815397638648
# 0.05620565780583264
# 0.049000366915909144
# 0.07816327283712998
# 0.014021216601332598
# 0.044864147322483894
# 0.0709876292272208
# 0.11385537986728944
# 0.010437322223696976
# 0.036790800012811764
# 0.07386979162713692
# 0.09859292469588354
# 0.08812639267860423
# 0.0611972800065258
# 0.1477296071977483
# 0.03758615541875787
# 0.11628292723467559
# 0.12968241842541572
# 0.2444148719554895
# 0.0844901796407912
# 0.02808750348165212
# 0.015667964585635463
# 0.04569229161273369
# 0.05583741688850474
# 0.10663226679358273
# 0.15612663155266582
# 0.00037024380378958277
# 0.022036334400630464
# 0.01538629602995889
# 0.0687411842774922
# 0.04728366060576117
# 0.03571309633244879
# 0.10265545781446794
# 0.19539838636362794
# 0.01225642247134806
# 0.19181068816544966
# 0.06473826104051861
# 0.10455671068661854
# 0.09161993968575566
# 0.06846013177897048
# 0.06874026151152435
# 0.06673752771452413
# 0.07140613940777163
# 0.06939847248006681
# 0.0190888366002403
# 0.06832044150679328
# 0.2737492016090577
# 0.1060456877654552
# 0.08807318742530057
# 0.11778562055724617
# 0.026250067442464498
# 0.14148345198699708
# 0.06756965535138193
# 0.07880515197663895
# 0.023846877506198627
# 0.10978118879765053
# 0.17082543374955483
# 0.24860576492826647
# 0.07538284918822535
# 0.27355614159204755
# 0.10827566920789355
# 0.027208428899357928
# 0.0023904009551979355
# 0.17709985069011047
# 0.10765242870517744
# 0.2859508775178601
# 0.009428718570843375
# 0.0866499735392775
# 0.02301033417740106
# 0.10800264492257994
# 0.05509201389174456
# 0.04346879074452514
# 0.040739009395332704
# 0.06884878329962396
# 0.01107194146115864
# 0.10814055665300992
# 0.09088990076711267
# 0.0969548115274601
# 0.10133340442867111
# 0.1084525125344139
# 0.08338235077759115
# 0.0006230892693751544
# 0.024432748230698187
# 0.02932605532996757
# 0.04073012333209414
# 0.033607384007864005
# 0.10240875822060558
# 0.08302137507375495
# 0.04925862486620036
# 0.02033432133411406
# 0.0021023633834355016
# 0.036112595844214335
# 0.021212925765939916
# 0.10155557098498447
# 0.005734967892736198
# 0.10958148986831628
# 0.2977481418525538
# 0.1477366148320326
# 0.025858319891665205
# 0.023794871116387672
# 0.10652070489902787
# 0.053962017623015224
# 0.08803587536622148
# 0.061022357229915
# 0.07168630703305601
# 0.11289212598293175
# 0.07078323307850709
# 0.017682596359107183
# 0.05401925783697625
# 0.0012302725067263598
# 0.04378581335356779
# 0.019340966248245994
# 0.07371830942407687
# 0.003908443336901435
# 0.0738493406911448
# 0.07199393172208268
# 0.05934953372175755
# 0.1404880807035752
# 0.12506695706087967
# 0.03482808741315657
# 0.018195954350299637
# 0.05311177687878288
# 0.04584126788958365
# 0.03435237001218838
# 0.023297011716569282
# 0.13678944854959774
# 0.07682782620452089
# 0.03123714717054149
# 0.04944385030940568
# 0.1150924358980141
# 0.11772516889047557
# 0.007009447372086086
# 0.02846138146421806
# 0.08184352331605205
# 0.054858443338573926
# 0.06989678074311334
# 0.07041586185456594
# 0.0808821584890086
# 0.07545924734916043
# 0.08009125405913109
# 0.023500242296389362
# 0.09919595943348769
# 0.07481012142966514
# 0.005209263776184914
# 0.13724520422788944
# 0.02140801982828211
# 0.014983484068286201
# 0.0472687260368454
# 0.03175533374701012
# 0.013387180400251442
# 0.08981614814545502
# 0.039640979775848795
# 0.0011201608248387895
# 0.07827774398412168
# 0.07593893540768604
# 0.09612577098723118
# 0.12319036969175734
# 0.09763921047307911
# 0.032045124481181686
# 0.04710383170107191
# 0.1180425102742686
# 0.0844848043426617
# 0.09863103359238834
# 0.07484290811833572
# 0.0818853842688223
# 0.011377194416454683
# 0.05715425869544333
# 0.08135941005896641
# 0.010184812437080804
# 0.08807698881966597
# 0.048174180273685585
# 0.0683745630108108
# 0.0494690816788973
# 0.008076805214910165
# 0.10203238766037825
# 0.007576816781801776
# 0.20154840628913462
# 0.0881768460558614
# 0.04942607556676393
# 0.058341097170558576
# 0.01704576673439473
# 0.16509665058098832
# 0.21811754240959058
# 0.07746971795320456
# 0.011842736612344584
# 0.06405656446807162
# 0.21968523035741572
# 0.10039028775735659
# 0.11235545552434156
# 0.09722062781974161
# 0.017509283575124046
# 0.05868185381259805
# 0.038614998064029016
# 0.07095460386135066
# 0.1381145162151829
# 0.17038446634187976
# 0.01760916704799209
# 0.2675670804070166
# 0.02879482464120664
# 0.08435318619823573
# 0.0261616253076854
# 0.09823605177258232
# 0.22907525549027874
# 0.11942730925748501
# 0.037252958087888866
# 0.04811262897354429
# 0.04582521879536017
# 0.16118543093429138
# 0.026824067841093036
# 0.08987756418524995
# 0.07199149933493176
# 0.0703356471490546
# 0.013845533652156461
# 0.03700740564945282
# 0.0887847310008627
# 0.008409042786309162
# 0.15402742766782906
# 0.08606664894749894
# 0.021394701349255696
# 0.13355108474441912
# 0.11416874030959301
# 0.016933652518113185
# 0.10650037587774375
# 0.11272225766213273
# 0.11022354233374321
# 0.02559697067634259
# 0.09308887145375588
# 0.11313832148514824
# 0.01258881155277558
# 0.07149481108653344
# 0.041606256721177015
# 0.043759056344067515
# 0.04431296702498333
# 0.05298623792677515
# 0.2732672446723087
# 0.07099486997033777
# 0.030092347677512565
# 0.14121274188922228
# 0.09713235748935256
# 0.003963593539702437
# 0.13265623251704772
# 0.026084798177462454
# 0.017957324153661136
# 0.20247343649394323
# 0.10032740377435323
# 0.018210521880026476
# 0.0509225079462402
# 0.054389840522818034
# 0.04153149900661668
# 0.11558451265778658
# 0.09894575450440324
# 0.08978340173092958
# 0.275899333639014
# 0.12233894308375748
# 0.054520067855417964
# 0.11546810899801963
# 0.01666977398535996
# 0.10177283918149949
# 0.033461315142401915
# 0.09312236077069791
# 0.07817518978724725
# 0.060253675135402585
# 0.04533559921008423
# 0.07145204058505938
# 0.11665125986165137
# 0.11928080958121334
# 0.08792143139917141
# 0.0990181611809039
# 0.10277270780718539
# 0.04011169224254696
# 0.24823539218380863
# 0.21332228479700377
# 0.07893613138681566
# 0.15704134909870715
# 0.14614054335208326
# 0.1248627318661486
# 0.08269747642418357
# 0.09942836279501643
# 0.01943862253155282
# 0.04373083959509905
# 0.07572310242638092
# 0.061143370390863816
# 0.06161644998988269
# 0.06906370732975653
# 0.003471036763669888
# 0.016027898792748907
# 0.06053176265107685
# 0.25952522190205973
# 0.13986168836205914
# 0.1275627149561882
# 0.013037601849479108
# 0.013067698854851373
# 0.13319232382475
# 0.006772142554537619
# 0.12590303851723805
# 0.023041628375279566
# 0.06341812933681368
# 0.13289392442308579
# 0.08439879079433876
# 0.01781929684106265
# 0.13715146779215193
# 0.020211121434981383
# 0.06749973613667815
# 0.1268978999646322
# 0.10313319756411687
# 0.031223246814320094
# 0.1009689426556254
# 0.09301018758432633
# 0.08321699302827457
# 0.0005953903032622776
# 0.07266320265691317
# 0.17803130781514886
# 0.07491058035807785
# 0.10311950403491865
# 0.27150180175523386
# 0.08401675068907644
# 0.02200362632337749
# 0.04287342755563672
# 0.04597537844889299
# 0.05101666180573372
# 0.03441080102743621
# 0.1076686026177388
# 0.017472869969365812
# 0.05848347464009729
# 0.12581676831180355
# 0.11549507055015806
# 0.2816278223144624
# 0.08803972847839314
# 0.21348693065167734
# 0.1117640271151854
# 0.05267752367087841
# 0.102535463378711
# 0.00822823581501475
# 0.03925609294542176
# 0.04256296317811714
# 0.16749376326182108
# 0.11312077936492737
# 0.027311079988187603
# 0.1113467377795112
# 0.051373382214575325
# 0.026293252859987626
# 0.07402343758584884
# 0.1654515160018435
# 0.25273030781066264
# 0.033570827013767346
# 0.09904784364415797
# 0.0747477481148634
# 0.12542123727600263
# 0.08488698978544174
# 0.026869347974795565
# 0.1246037395553049
# 0.06000413918665881
# 0.013351535950073878
# 0.24891120799423228
# 0.035809339861060385
# 0.12374545556477867
# 0.028189468779119653
# 0.05435128236931719
# 0.08832256196299981
# 0.14004356345690006
# 0.07427799570316185
# 0.1056717629779208
# 0.08364662009411106
# 0.010167786777652732
# 0.10404966000756977
# 0.25085024800791766
# 0.10392892719138025
# 0.037431790351169836
# 0.10036631217319358
# 0.02716744317905362
# 0.08863840356209385
# 0.07585132656714677
# 0.07489554711461743
# 0.0662764728645624
# 0.24422439770302973
# 0.06219190340460168
# 0.025991797376956227
# 0.017478700913114098
# 0.055114159134312835
# 0.05942149074363512
# 0.04952426677431576
# 0.014031265963742379
# 0.09934612343885252
# 0.16087295265024326
# 0.020626603983321168
# 0.2790757820727269
# 0.09619822242558218
# 0.01319448666841816
# 0.08493317177016801
# 0.00515460377164112
# 0.06327100779809736
# 0.09109831928700696
# 0.06464346042165825
# 0.04484701514889611
# 0.028267767716953496
# 0.009141364265539353
# 0.11466917006184563
# 0.08106945039970004
# 0.06897106345117066
# 0.06917774312037694
# 0.11385864714360427
# 0.25644314545274616
# 0.11865126288963868
# 0.02629721444438704
# 0.10235270259933238
# 0.07432278550665339
# 0.0887855629353198
# 0.009478795438747745
# 0.07758058921176658
# 0.10300645220617
# 0.13066804344537242
# 0.04151689752513621
# 0.034091755299823334
# 0.19530854034451406
# 0.07155833692682856
# 0.07889489227915525
# 0.12185964433498742
# 0.03838767219683725
# 0.052799220322562124
# 0.14206995346911544
# 0.12137649740829637
# 0.04581655759071257
# 0.11382849027624053
# 0.03790386215672881
# 0.01983314245663481
# 0.013266103873525337
# 0.028808516049851685
# 0.08639870169480057
# 0.017585793113585324
# 0.10506620709605818
# 0.03133312079717143
# 0.05785778557413468
# 0.00781000773174001
# 0.10730370404064093
# 0.08727002802490258
# 0.028678384958035652
# 0.09552364697531968
# 0.08795517604182912
# 0.0020645744479147465
# 0.015200996356251273
# 0.023610546989903503
# 0.07783495439401944
# 0.04274848507369522
# 0.08123264262066954
# 0.11690017275563869
# 0.034596128894362255
# 0.12328260366762134
# 0.06131530871981705
# 0.03853288743723149
# 0.2893555409157885
# 0.004609368566563465
# 0.010443140983040111
# 0.16168713129629964
# 0.014611555936647758
# 0.005940073847865879
# 0.02816131783784981
# 0.050911991564885795
# 0.02449104244681033
# 0.11941589795374707
# 0.0987844818199537
# 0.012288224764060107
# 0.12195697199791933
# 0.10915447721551041
# 0.07017164225867567
# 0.05163167924979517
# 0.07097171711348704
# 0.12234589174793509
# 0.0887829695321285
# 0.04240584756202603
# 0.12079082927730811
# 0.023511315871239225
# 0.09068313976143827
# 0.03490688243258411
# 0.04042362433364344
# 0.08579550276505998
# 0.12007830403362385
# 0.12785013056183803
# 0.1971924488468716
# 0.03847109819772332
# 0.04288695707595891
# 0.15749611252872953
# 0.13717662117046248
# 0.06765445619066801
# 0.021677438647347502
# 0.06786539710066619
# 0.1845391096336867
# 0.1820419813095051
# 0.10970012374183646
# 0.035934102905803234
# 0.06101172219903017
# 0.010568870400386787
# 0.08902002466240722
# 0.07171528518833303
# 0.07049438998245428
# 0.016299818312487502
# 0.10554160303580096
# 0.051286523187808575
# 0.11109329112008548
# 0.12290792341280354
# 0.03737812268331997
# 0.018929058340640403
# 0.01835772185495199
# 0.06210622430418644
# 0.11463904686557147
# 0.023283985518472217
# 0.015669762787712704
# 0.12341506423448634
# 0.04116755226940649
# 0.0828378619652016
# 0.08129158019336302
# 0.011881376180515435
# 0.13784562958639412
# 0.06267790881796442
# 0.1797474315574702
# 0.07620665604913102
# 0.029937010387059093
# 0.011547736613601978
# 0.1667149512381294
# 0.11174696961873354
# 0.15249892407858123
# 0.10379324819161695
# 0.11412956106254557
# 0.15687591572846882
# 0.03765006526351833
# 0.09040564374040005
# 0.0502377909715046
# 0.1603983464021106
# 0.12073893683452797
# 0.012540168935810891
# 0.01653536872342798
# 0.11734577595574569
# 0.05059415977067905
# 0.15003581758425755
# 0.1562345048617172
# 0.08497939688547962
# 0.0994630526720135
# 0.2190483069664061
# 0.06520344246351428
# 0.11276250602637539
# 0.008588090418905958
# 0.09797589526061679
# 0.10278776010285395
# 0.03281533235352152
# 0.002803407335353336
# 0.015159086918829834
# 0.05718144958638194
# 0.0018298065536550556
# 0.01706213613894647
# 0.08167341884940804
# 0.08872024208312146
# 0.23817459741399627
# 0.035759547196903774
# 0.023452671315960516
# 0.05073271420036185
# 0.01841694519823245
# 0.02704151801339183
# 0.08251466358025272
# 0.0891848925824692
# 0.10156215247008515
# 0.0361098597364331
# 0.07562955348288114
# 0.013363315556786826
# 0.0593238562869175
# 0.1927829434581816
# 0.08068396456896354
# 0.059262064405983916
# 0.11937833011050969
# 0.12220012664905111
# 0.15025816266199477
# 0.010015455189894329
# 0.10176910098908998
# 0.10004144923860991
# 0.04990739268863542
# 0.03720155605334641
# 0.16928468058317503
# 0.014522938232436111
# 0.03828780021735534
# 0.021019703215534924
# 0.1935555158754403
# 0.013689675274557889
# 0.07385718591269486
# 0.007538527421162233
# 0.016872092529996885
# 0.005003571469058277
# 0.03454849945548155
# 0.1021380324065565
# 0.020251684210705
# 0.04162438135671487
# 0.0724072801844694
# 0.05368926331851942
# 0.058454053902363357
# 0.05902930645655646
# 0.10087634914666077
# 0.047443334792966696
# 0.0568032144970001
# 0.016678800624568946
# 0.02631636002337523
# 0.01214642824002321
# 0.04414699554231216
# 0.07302586917693488
# 0.16305670553343343
# 0.03481882982952489
# 0.0272461073679241
# 0.10681911632173646
# 0.051689734128506526
# 0.05743847217758191
# 0.0613056429384482
# 0.10559386740503329
# 0.04548244957347314
# 0.108267025266222
# 0.016907342732719877
# 0.027830104469977246
# 0.02574073157265011
# 0.12838804153460348
# 0.03771145069667803
# 0.07545183033393243
# 0.09638730380652327
# 0.055024162343408234
# 0.023793381703242855
# 0.0174863847337563
# 0.02567036861177774
# 0.0034713590898971525
# 0.008064087571454492
# 0.09246679928828838
# 0.07176287433262407
# 0.06628161046691095
# 0.05143892453045007
# 0.00530042306632561
# 0.002105957516753687
# 0.2620697297929312
# 0.11459508024659393
# 0.06251058237753715
# 0.12347528381527861
# 0.11559246764817588
# 0.052411219576248724
# 0.19397745328563276
# 0.10742517635682836
# 0.09824071124162981
# 0.05213238598918668
# 0.05801451721825823
# 0.24121641205704625
# 0.11216023869097724
# 0.0027904265590282806
# 0.0804439033927522
# 0.08809095967143421
# 0.002313904453365323
# 0.10593894144846272
# 0.0341390980304247
# 0.02361971946098862
# 0.07472180429449704
# 0.14568280129591993
# 0.0595444616532077
# 0.006315507264705311
# 0.052418394468041085
# 0.1380516640440218
# 0.08811251229714745
# 0.06946338544341046
# 0.06325164779679626
# 0.0887246749215157
# 0.01623668268134182
# 0.06011572281737876
# 0.047615918545864666
# 0.09253621515101351
# 0.21356187972072238
# 0.0486914324544967
# 0.06034053920750493
# 0.0946579399828561
# 0.10002433110930198
# 0.10445955977959542
# 0.09592092686968956
# 0.05264792983300548
# 0.07970465013152417
# 0.009505498849361582
# 0.09396902837211774
# 0.013710387616222564
# 0.12016025144580944
# 0.06102849143999223
# 0.14837287508304398
# 0.10787312781465164
# 0.1387278756581154
# 0.03486597662936575
# 0.033100787271944876
# 0.09718442353628476
# 0.17876948047418917
# 0.07998464127112104
# 0.04761965662079182
# 0.008948012326794097
# 0.10484644106269092
# 0.10778617846429994
# 0.02042919894190376
# 0.006744847322216918
# 0.1372529447020665
# 0.012796471115606112
# 0.08343968616875452
# 0.10882307380436018
# 0.005825178310474022
# 0.11554233452364215
# 0.05156973787371433
# 0.06824891202130745
# 0.005591326004065755
# 0.06497899299791798
# 0.058504101317921275
# 0.08036722007854458
# 0.034386708411941025
# 0.025822349952406287
# 0.03419855000678318
# 0.02296750134851344
# 0.03662650886459862
# 0.03526780969728649
# 0.0877764892926326
# 0.07309353885443448
# 0.09723914044106619
# 0.10032517528058205
# 0.07273562115935872
# 0.12834442787470124
# 0.019298337459520143
# 0.00650730737435079
# 0.0374080856675697
# 0.2828746933226688
# 0.0916590735216446
# 0.08126634696107049
# 0.003585695435400771
# 0.05884041805093276
# 0.0073511644101914575
# 0.07988900109865593
# 0.0871927445743319
# 0.13960592962129692
# 0.13321260237434784
# 0.1601789379513031
# 0.02697433538769467
# 0.05498755845456049
# 0.011416970325002218
# 0.12591276063269485
# 0.07945089748147594
# 0.003097648717565793
# 0.12542620817869832
# 0.045157933346458345
# 0.07597126158555811
# 0.0153373225957677
# 0.04397927869500995
# 0.21852792744960492
# 0.13980214478072206
# 0.033521575898790124
# 0.09038908776918608
# 0.032968666775076705
# 0.02059633601325561
# 0.23222940908602652
# 0.05729316185143929
# 0.099947294465077
# 0.2856078462989067
# 0.021623218402643696
# 0.02506123580605768
# 0.0299861442674475
# 0.06648233414423277
# 0.041031831229324744
# 0.06734408735487707
# 0.007579810379924945
# 0.0578227214272129
# 0.058422987062515586
# 0.2374319634710833
# 0.20452798878675305
# 0.07243142123388047
# 0.1096237737827297
# 0.19464845705387568
# 0.10204147307449496
# 0.13199357367386788
# 0.09772191339447367
# 0.09503182073053817
# 0.0308930154555892
# 0.005464843422676613
# 0.018640225773822627
# 0.09693599985673484
# 0.11038794573226318
# 0.02998717916284932
# 0.0290915088918966
# 0.13578068095882545
# 0.10437974343496126
# 0.030893157437446583
# 0.08295403101523213
# 0.10279820189524624
# 0.08917604089527364
# 0.08819458251299239
# 0.04864865469249635
# 0.07493893504717786
# 0.0015605398809451776
# 0.07081292813240314
# 0.08213278022209758
# 0.12780618197241989
# 0.15211864252492124
# 0.03507715821595492
# 0.020448581821153167
# 0.13399490000874015
# 0.12210463447784292
# 0.181387730504042
# 0.04361051797150095
# 0.023440581311719222
# 0.18582725895880836
# 0.07124464213393544
# 0.1268745631866477
# 0.014307215902835457
# 0.012142851050960024
# 0.07862488407987056
# 0.08691689701183203
# 0.059713665019903384
# 0.13555857119537218
# 0.0019564818535743322
# 0.03022327550353987
# 0.012734784378229502
# 0.23117909091058786
# 0.1603968540860642
# 0.019912511957133172
# 0.06666355817698755
# 0.07609899456489555
# 0.14146017160381696
# 0.006704304829454055
# 0.10158351628700746
# 0.0010652471312198042
# 0.04495328397986076
# 0.000600595982869101
# 0.10347208322918833
# 0.07273002040337961
# 0.12269288641572818
# 0.12855349548832662
# 0.0025670424115893375
# 0.03299159760047066
# 0.1963808314089831
# 0.061227452770007074
# 0.17316899969227106
# 0.081643242527493
# 0.05842455286377779
# 0.05063787334740055
# 0.1267727090178291
# 0.08500869716939097
# 0.21096303238011094
# 0.0906319155979497
# 0.03656302556213442
# 0.1253991570923031
# 0.0013132776874934526
# 0.27136215304050715
# 0.0597363510797958
# 0.1182814674118311
# 0.07802491633565511
# 0.00028045666280829273
# 0.01238866058679089
# 0.08710209215480191
# 0.017622556884184792
# 0.020055012355885582
# 0.06634695705178473
# 0.08082246362324874
# 0.09939728401580161
# 0.06573892424217997
# 0.09199105027143306
# 0.07945697937531615
# 0.10849679489484931
# 0.29716861285278895
# 0.046031211859802634
# 0.03304591638390053
# 0.08169515942372207
# 0.06482598997892486
# 0.0006114540552846215
# 0.11236075201050888
# 0.08961586152919454
# 0.11046289299316059
# 0.02051330897939052
# 0.011951686823548857
# 0.09955183387184785
# 0.0972411959944296
# 0.25222861314485967
# 0.042122526503404756
# 0.002339953474536971
# 0.03102246786645224
# 0.09522902622913998
# 0.0760937037261058
# 0.11477363018322584
# 0.11430527703185289
# 0.011285247233558393
# 0.10857515238210214
# 0.0796110982382412
# 0.0697353961613072
# 0.042523120968173234
# 0.10712080179978556
# 0.05220952672590473
# 0.05750576335626123
# 0.07593254774514291
# 0.11738361668561137
# 0.027045508337682156
# 0.1549950329612263
# 0.018301933325352238
# 0.060411519476207154
# 0.037438248701669785
# 0.06106989567476673
# 0.07162151508185044
# 0.12603741587351203
# 0.04161010474565552
# 0.004876412868279778
# 0.028823052388866066
# 0.10851015859214252
# 0.07207299794639688
# 0.016774852957301745
# 0.007231987558013575
# 0.020028473970142846
# 0.0055867300744575354
# 0.13007917788173684
# 0.012695154685471222
# 0.06384183447903535
# 0.05314236446177656
# 0.09929797303226406
# 0.15927477896880782
# 0.05852159595303752
# 0.03914227433998185
# 0.12847766555513462
# 0.08093663007260521
# 0.12192488289396097
# 0.07045382618371099
# 0.004892663989178092
# 0.05369785598186849
# 0.299727811014211
# 0.03541882552428055
# 0.08632034553970835
# ...
#
#
# 10531 [('Samelink(10531,31489)', 0.9536708535335765), ('w_1274', 0.004288029271338287), ('w_1293', 0.004105394843212944), ('w_1206', 0.003602709199457187), ('w_1382', 0.0034804288662801442), ('w_1210', 0.0031883815790514814), ('w_1178', 0.0029961244436607624), ('w_1255', 0.0029515563224062737), ('w_648', 0.00289469349496362), ('w_136', 0.002650955669494149), ('w_817', 0.0023985409122977567), ('w_649', 0.002199455682771237), ('w_285', 0.0021985011897290036), ('w_846', 0.0014614026464753731), ('w_695', 0.001433032400699555), ('w_903', 0.0014161006475023154), ('w_457', 0.0012950361416944054), ('w_1095', 0.0012793221863624648), ('w_737', 0.0012551258856935486), ('w_437', 0.0012343550833332317)]
#
#
# 44455 [('Samelink(44455,31489)', 0.9835045138213607), ('w_1178', 0.0018385896948198452), ('w_912', 0.00109864827860805), ('w_1294', 0.0008888382746296001), ('w_402', 0.0008842100295545746), ('w_300', 0.0008619505676298808), ('w_878', 0.0008519220311120161), ('w_1236', 0.0008360796303865243), ('w_549', 0.000836053744124786), ('w_910', 0.0008356829160003815), ('w_1113', 0.0008247643547239407), ('w_248', 0.00082252558574259), ('w_1238', 0.0007918804037969943), ('w_599', 0.000787474992606115), ('w_1280', 0.000786454827043451), ('w_303', 0.0007623323997521973), ('w_1010', 0.0007498680872668276), ('w_742', 0.000731164599179133), ('w_787', 0.0007012480376880778), ('w_989', 0.0006057977239743379)]
#
#
# 2698 [('Samelink(2698,31489)', 0.9640973269409678), ('w_1361', 0.005299443184267637), ('w_1297', 0.004339896102675934), ('w_1427', 0.004238177675459064), ('w_616', 0.0035214125593785697), ('w_913', 0.00236746395855449), ('w_1076', 0.0013606227484720267), ('w_542', 0.0012683793602428896), ('w_20', 0.0012313416840872861), ('w_1188', 0.0012063785286357098), ('w_1428', 0.0011994545208517675), ('w_1369', 0.0011678411299846313), ('w_68', 0.0011371825865360379), ('w_565', 0.0011361054838663238), ('w_178', 0.0011293175101930104), ('w_1307', 0.0011198241673404414), ('w_423', 0.0011194686284125013), ('w_1224', 0.0010628479988677166), ('w_775', 0.0010540189732279697), ('w_883', 0.0009434962579779981)]
#
#
# 85688 [('Samelink(85688,31489)', 0.9088035393541749), ('w_815', 0.010501313389632266), ('w_1124', 0.008815641569069234), ('w_40', 0.006233614987473721), ('w_1349', 0.006169080887668791), ('w_399', 0.005683284266735365), ('w_1178', 0.005409788016903225), ('w_234', 0.0053472913389571225), ('w_1199', 0.005198104656832887), ('w_370', 0.005061412942686959), ('w_1394', 0.004914371469999041), ('w_229', 0.0042122703461527295), ('w_47', 0.0025898595913978694), ('w_137', 0.00251748585246277), ('w_158', 0.0024775313870872427), ('w_975', 0.0024318499784692703), ('w_930', 0.0024296810712334904), ('w_351', 0.002365703767817017), ('w_457', 0.002338311085715445), ('w_1238', 0.002329995175841137), ('w_906', 0.0021116793896926536), ('w_503', 0.002058189473996958)]
#
#
# 103482 [('Samelink(103482,31489)', 0.6554891809160643), ('w_1264', 0.029339950078275952), ('w_226', 0.029176111063780905), ('w_204', 0.027062686977927266), ('w_1173', 0.026423998655401817), ('w_1178', 0.02471201232862648), ('w_234', 0.024426526340806505), ('w_620', 0.021568914845858808), ('w_42', 0.020963575964614962), ('w_66', 0.017655825539271593), ('w_1175', 0.01314757032135326), ('w_1182', 0.012925659831775578), ('w_8', 0.011562845488082315), ('w_1341', 0.011329567746764635), ('w_1268', 0.011154144950023263), ('w_193', 0.01110656728693969), ('w_231', 0.01097872135117973), ('w_585', 0.010822348428045973), ('w_918', 0.010516741118921875), ('w_1352', 0.010214745200868694), ('w_551', 0.00942230556541614)]
#
#
# 3085 [('Samelink(3085,31489)', 0.9192222372638366), ('w_72', 0.009693864306243902), ('w_1033', 0.009600655636230557), ('w_1291', 0.008323997038127792), ('w_314', 0.008292528573353504), ('w_1229', 0.006876589927047397), ('w_1258', 0.005574757086059222), ('w_235', 0.0050238239923537905), ('w_1210', 0.004425423071263422), ('w_1145', 0.002671592739748368), ('w_1245', 0.00220716173864048), ('w_211', 0.0020032146230775953), ('w_401', 0.001985411443916587), ('w_1321', 0.0019510271784864235), ('w_868', 0.0018804783433855792), ('w_387', 0.0018270324234094621), ('w_1181', 0.0018026500594170128), ('w_118', 0.0017597319567431216), ('w_436', 0.0017174208067238699), ('w_41', 0.001683655801972857), ('w_63', 0.0014767459899623708)]
#
#
# 28350 [('Samelink(28350,31489)', 0.9410590373109061), ('w_936', 0.006517379014205854), ('w_508', 0.006182271842619465), ('w_40', 0.005218823072174317), ('w_1173', 0.004842875148305195), ('w_1178', 0.004529109766150073), ('w_42', 0.0038421127090803695), ('w_1133', 0.0035207118287158296), ('w_1072', 0.0027730328188390993), ('w_293', 0.002757904495100554), ('w_1182', 0.002368958521043369), ('w_1350', 0.002272320681283924), ('w_871', 0.002174644527127677), ('w_1396', 0.002117410215701202), ('w_1268', 0.002044283005139296), ('w_613', 0.002022272903826341), ('w_587', 0.001964518945100552), ('w_598', 0.0019202192756373824), ('w_1352', 0.001872113919043208)]
#
#
# 23507 [('Samelink(23507,31489)', 0.8690831039384449), ('w_1120', 0.013665653474334948), ('w_1353', 0.013245748026031373), ('w_1259', 0.011833464342987803), ('w_515', 0.011227061741096798), ('w_648', 0.011172463827393987), ('w_1139', 0.010692546620905853), ('w_1072', 0.007080246583060164), ('w_1175', 0.006152386496068955), ('w_20', 0.0056152427994414205), ('w_874', 0.005564179939337595), ('w_694', 0.005243461582196409), ('w_394', 0.005213476412140258), ('w_33', 0.005141374601663334), ('w_1393', 0.0049687180359092075), ('w_1225', 0.004905998502971977), ('w_386', 0.0047193699850724335), ('w_622', 0.004475503090942649)]
#
#
# 4329 [('Samelink(4329,31489)', 0.8779473765122003), ('w_730', 0.012811995240206419), ('w_982', 0.012524284762509094), ('w_1361', 0.01121694458305643), ('w_27', 0.009483654712935942), ('w_1331', 0.0070714799871723615), ('w_1264', 0.006372529496847615), ('w_1353', 0.00614795762070533), ('w_541', 0.005812216383936018), ('w_447', 0.005735207228681346), ('w_1210', 0.0057117743173268395), ('w_1385', 0.005658335929410085), ('w_1178', 0.005367358399400786), ('w_136', 0.004749011413462369), ('w_1263', 0.003931899688474097), ('w_277', 0.002623391863968988), ('w_695', 0.002567182584415747), ('w_1410', 0.0025292804609402123), ('w_1185', 0.0024705096728026813), ('w_930', 0.002410624790620786), ('w_177', 0.002397029580243582), ('w_78', 0.0023699829885823476), ('w_1110', 0.002089971782100517)]
#
#
# 123825 [('Samelink(123825,31489)', 0.9003121862879284), ('w_1361', 0.010133317519796438), ('w_1135', 0.008097806365059471), ('w_716', 0.007675543974623603), ('w_923', 0.005904351492201781), ('w_89', 0.005769941039676935), ('w_1264', 0.00575690325629031), ('w_1302', 0.005698581142642195), ('w_541', 0.005250719897569316), ('w_1210', 0.005159981163348164), ('w_913', 0.004526940505735832), ('w_195', 0.0042267375965794884), ('w_129', 0.003669521311115948), ('w_1145', 0.003115039622483751), ('w_655', 0.0024864330540142806), ('w_20', 0.0023545070352408545), ('w_679', 0.0023421876572057966), ('w_86', 0.00231752379987886), ('w_1389', 0.002309405873842855), ('w_174', 0.0023021394585076233), ('w_878', 0.0022467393955911416), ('w_1330', 0.0022046687657713633), ('w_122', 0.0021111524084957258), ('w_775', 0.0020154398407961935), ('w_97', 0.002012231535603652)]
#
#
# 66990 [('Samelink(66990,31489)', 0.9229540511400536), ('w_725', 0.006658373537217674), ('w_1329', 0.006085878279140879), ('w_1132', 0.005670972245724814), ('w_1302', 0.005576353567360726), ('w_1210', 0.005049305896942871), ('w_894', 0.004814212511718574), ('w_1255', 0.004674255691917099), ('w_648', 0.004584204422078671), ('w_131', 0.0037264924541246416), ('w_1209', 0.0031489361274637004), ('w_1175', 0.0025244026579404042), ('w_576', 0.00250814760448913), ('w_452', 0.0023231095780214604), ('w_20', 0.0023040057475172907), ('w_421', 0.002211095751091991), ('w_137', 0.002208045555924485), ('w_694', 0.0021514591717153165), ('w_712', 0.0019883447654416085), ('w_784', 0.001984951420232745), ('w_775', 0.001972211128472906), ('w_208', 0.001793957301440492), ('w_6', 0.0015825976227316664), ('w_352', 0.0015046358212373922)]
#
#
# 89547 [('Samelink(89547,31489)', 0.9035309156857124), ('w_30', 0.012427929042348922), ('w_176', 0.012269557714943891), ('w_95', 0.012197307427875946), ('w_940', 0.007386861541014238), ('w_656', 0.006792463137822889), ('w_979', 0.0046742759313584), ('w_1119', 0.004071754143776078), ('w_1293', 0.004058661628457698), ('w_964', 0.003804253853363444), ('w_1264', 0.003516729945286645), ('w_1022', 0.0034933749285499345), ('w_1353', 0.003392798209530936), ('w_1349', 0.0033777536970018857), ('w_1178', 0.002962018460580835), ('w_699', 0.0026541118626232617), ('w_1080', 0.00262320111941041), ('w_195', 0.0025819948703356167), ('w_1061', 0.002293081680006376), ('w_759', 0.0018909551199996902)]
#
#
# 93555 [('Samelink(93555,31489)', 0.7712903256611903), ('w_873', 0.03092984371088958), ('w_537', 0.026623522735944573), ('w_1260', 0.0187282340916873), ('w_1206', 0.016137554682435273), ('w_1234', 0.015938551116817877), ('w_133', 0.015427311511191187), ('w_506', 0.012425584585505875), ('w_1263', 0.009831283047773568), ('w_912', 0.008019406424760516), ('w_1076', 0.0072009506059589916), ('w_891', 0.006667960536881765), ('w_20', 0.006516744377622909), ('w_857', 0.006431824626451641), ('w_610', 0.006401295897263261), ('w_511', 0.006236975225159654), ('w_1037', 0.00610572364805291), ('w_394', 0.006050476232312583), ('w_193', 0.006031705186428532), ('w_257', 0.005949399954650574), ('w_775', 0.0055782828653142035), ('w_386', 0.005477043275707055)]
#
#
# 19697 [('Samelink(19697,31489)', 0.8841093341317727), ('w_1361', 0.010998417260721495), ('w_970', 0.010623987954441033), ('w_1157', 0.010509610846161362), ('w_974', 0.008544227648537382), ('w_64', 0.007568068099319446), ('w_1329', 0.0067502248151382685), ('w_736', 0.0065992713883739895), ('w_1264', 0.006248380554402983), ('w_624', 0.0062297533684079545), ('w_40', 0.006064233860406909), ('w_761', 0.006030252145295411), ('w_331', 0.00470903504798526), ('w_129', 0.003982795017319634), ('w_62', 0.0038254335567581466), ('w_759', 0.003359770976128155), ('w_20', 0.002555515581772021), ('w_262', 0.002303513609129141), ('w_82', 0.0022776355494873507), ('w_230', 0.0022746986821810125), ('w_856', 0.0022483383018100165), ('w_775', 0.00218750160445026)]
#
#
# 3220 [('Samelink(3220,31489)', 0.9244572804650262), ('w_275', 0.0067632838219582134), ('w_726', 0.006079149177078931), ('w_282', 0.005685152239932535), ('w_716', 0.005339006916810301), ('w_1262', 0.005206949316215713), ('w_232', 0.004825088441846347), ('w_360', 0.004738890096791979), ('w_508', 0.00460388263068269), ('w_9', 0.004588153389771909), ('w_1026', 0.004283545836640963), ('w_1264', 0.004004425797879552), ('w_757', 0.0032930607064433413), ('w_94', 0.0032326737896432585), ('w_1267', 0.0021915498276196244), ('w_274', 0.0016019040622300422), ('w_87', 0.001564591000902558), ('w_1169', 0.0015536196915014377), ('w_284', 0.0015219785396159982), ('w_83', 0.0015098752899080662), ('w_261', 0.001479676553689117), ('w_262', 0.001476262407811158)]
#
#
# 27627 [('Samelink(27627,31489)', 0.8771410551063475), ('w_1348', 0.011489623257242317), ('w_238', 0.01130659364691142), ('w_1254', 0.0087199698944691), ('w_275', 0.007801205500103932), ('w_537', 0.007717741896641355), ('w_698', 0.007314774642677168), ('w_750', 0.007232704314494335), ('w_180', 0.0063560981637881845), ('w_933', 0.006310015521612898), ('w_702', 0.005903539451033317), ('w_476', 0.005711447785414253), ('w_412', 0.005300883637157831), ('w_1331', 0.005125577659734286), ('w_1354', 0.004949483996653511), ('w_1264', 0.0046189616437139445), ('w_40', 0.004482835729330379), ('w_133', 0.004472135771939326), ('w_541', 0.004212833311426287), ('w_1255', 0.003832519069308532)]
#
#
# 77758 [('Samelink(77758,31489)', 0.8333626760712575), ('w_730', 0.021427167191004976), ('w_970', 0.018120907418588513), ('w_475', 0.0159087398852253), ('w_212', 0.014572263259734902), ('w_616', 0.012465486490118442), ('w_508', 0.012253039593679573), ('w_133', 0.010318830253019046), ('w_699', 0.008043407053480379), ('w_1080', 0.007949730636337646), ('w_136', 0.007942389896377263), ('w_1387', 0.006520119870116135), ('w_104', 0.0044449552551139035), ('w_1185', 0.004131754876087917), ('w_177', 0.004008864553467958), ('w_1074', 0.0039756208779670316), ('w_510', 0.003902251767222507), ('w_473', 0.0036510927929934212), ('w_448', 0.003505254289480646), ('w_1239', 0.0034954479687270236)]
#
#
# 6163 [('Samelink(6163,31489)', 0.8511059977868066), ('w_1277', 0.015454176336956678), ('w_337', 0.014171643167704653), ('w_360', 0.012880888933512798), ('w_1329', 0.011758724476472443), ('w_1264', 0.010884524201119933), ('w_40', 0.010563745220085541), ('w_133', 0.010538530906965543), ('w_1133', 0.007126492359971923), ('w_1072', 0.0056130686516926275), ('w_293', 0.00558244646822888), ('w_1076', 0.004919032098715403), ('w_14', 0.004254605427344218), ('w_670', 0.004103342587575801), ('w_248', 0.0041013117785378105), ('w_976', 0.003980804639896379), ('w_599', 0.0039265410322326015), ('w_1280', 0.003921454239662575), ('w_582', 0.0038290915470265883), ('w_43', 0.003827240739487923), ('w_775', 0.003810573627249647), ('w_742', 0.0036457637727535827)]
#
#
# 85352 [('Samelink(85352,31489)', 0.708379952078114), ('w_785', 0.037583162341213436), ('w_508', 0.03124620714153436), ('w_1354', 0.029122515376751246), ('w_204', 0.025068298559302243), ('w_724', 0.023263205222220373), ('w_648', 0.02211590896054356), ('w_895', 0.022100401465744178), ('w_132', 0.021854682344939348), ('w_496', 0.010945121006145192), ('w_1321', 0.01073942484955841), ('w_1269', 0.010613649556010784), ('w_1230', 0.010234736363113197), ('w_390', 0.009910748437410787), ('w_1393', 0.009835584829851314), ('w_1243', 0.009355034383794553), ('w_369', 0.00763136708375316)]
#
#
# 287787 [('Samelink(287787,31489)', 0.6059682351096632), ('w_1427', 0.0458180484046351), ('w_281', 0.04541783960953856), ('w_508', 0.03742044437569584), ('w_1329', 0.03516217351780586), ('w_736', 0.034375851472192), ('w_1210', 0.02917320425242697), ('w_1098', 0.025735410122155536), ('w_1231', 0.024567451697275935), ('w_42', 0.023255781786259706), ('w_1267', 0.017812958105069075), ('w_1172', 0.01647264766954991), ('w_496', 0.013107872259199394), ('w_645', 0.01243122706771496), ('w_1226', 0.01213910014674924), ('w_115', 0.010746513878337314), ('w_1412', 0.01039524052573118)]
#
#
# 8865 [('Samelink(8865,31489)', 0.6920393755965929), ('w_753', 0.03219952240129848), ('w_955', 0.023556206623429145), ('w_1092', 0.021793118969897315), ('w_779', 0.02057213315030047), ('w_508', 0.019425276366790725), ('w_626', 0.017368148741456303), ('w_1132', 0.017008587099690737), ('w_1264', 0.016895973258680152), ('w_1353', 0.016300548723442033), ('w_1210', 0.01514406267917791), ('w_379', 0.014003411027555193), ('w_895', 0.013739472581248025), ('w_987', 0.01300454921680999), ('w_1425', 0.012541275678516456), ('w_1072', 0.008713128482766052), ('w_1076', 0.007635780238325273), ('w_496', 0.0068044098744298506), ('w_1188', 0.006770165601920963), ('w_1283', 0.006520232779512765), ('w_135', 0.006510352384344401), ('w_177', 0.006355427261356048), ('w_389', 0.005098841262458927)]
#
#
# 54129 [('Samelink(54129,31489)', 0.6761522751703003), ('w_1329', 0.021797057123239677), ('w_1354', 0.021620347293119076), ('w_700', 0.020326733872785302), ('w_1250', 0.02004500703288508), ('w_1382', 0.019740982019397335), ('w_133', 0.01953519368820744), ('w_1340', 0.019154592915818332), ('w_809', 0.018137626128288), ('w_515', 0.016498928096419407), ('w_1394', 0.015437734663712236), ('w_1231', 0.015229381305077255), ('w_946', 0.01487441423804578), ('w_620', 0.014832556885836552), ('w_1133', 0.013210324076343979), ('w_66', 0.012141595372283293), ('w_1248', 0.012033369950821075), ('w_1072', 0.010404902188363378), ('w_496', 0.008125579616209305), ('w_502', 0.008030714757421842), ('w_1066', 0.007653696213767814), ('w_919', 0.007512355186931502), ('w_1307', 0.00750463220472585)]

# %%
# GCN Prediction and Explanations.


import pandas as pd
import os

import stellargraph as sg
from stellargraph.mapper import FullBatchNodeGenerator
from stellargraph.layer import GCN

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from sklearn import preprocessing, model_selection
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import f1_score
def GCN_Result():
        class gcn:
            @classmethod
            def data(cls,dataset):
                display(HTML(dataset.description))
                G, node_subjects = dataset.load()
                return G, node_subjects
            @classmethod
            def update_inp_mlev(cls,node_subjects,WORDS):
                rm1=[]
                for t in node_subjects.index:
                    #print(t)
                    if str(t) not in WORDS:
                        rm1.append(t)
                print(len(rm1))
                node_subjects1=node_subjects.drop(labels=rm1)
                return node_subjects1
            @classmethod
            def dis_graph_info(cls,G):
                return  G.info()
            @classmethod
            def updated_nodes(cls,node_subjects1):
                return node_subjects1.value_counts().to_frame()
            @classmethod
            def train_val(cls,node_subjects1):
                train_subjects, test_subjects = model_selection.train_test_split(node_subjects1, train_size=100, test_size=None, stratify=node_subjects1)
                val_subjects, test_subjects = model_selection.train_test_split(test_subjects, train_size=200, test_size=None, stratify=test_subjects)
                return train_subjects,val_subjects, test_subjects
            @classmethod
            def encoding(cls,train_subjects,val_subjects,test_subjects):
                target_encoding = preprocessing.LabelBinarizer()
                train_targets = target_encoding.fit_transform(train_subjects)
                val_targets = target_encoding.transform(val_subjects)
                test_targets = target_encoding.transform(test_subjects)
                return target_encoding,train_targets, val_targets,test_targets
            @classmethod
            def gcn_model(cls,G,target_encoding,train_targets, val_targets,test_targets,node_subjects1):
                generator = FullBatchNodeGenerator(G, method="gcn")
                train_gen = generator.flow(train_subjects.index, train_targets)
                gcn = GCN(layer_sizes=[16, 16], activations=["relu", "relu"], generator=generator, dropout=0.5)
                x_inp, x_out = gcn.in_out_tensors()
                predictions = layers.Dense(units=train_targets.shape[1], activation="softmax")(x_out)
                model = Model(inputs=x_inp, outputs=predictions)
                model.compile(optimizer=optimizers.Adam(lr=0.01),loss=losses.categorical_crossentropy,metrics=["acc"],)
                val_gen = generator.flow(val_subjects.index, val_targets)
                es_callback = EarlyStopping(monitor="val_acc", patience=50, restore_best_weights=True)
                history = model.fit(train_gen,epochs=200,validation_data=val_gen,verbose=2,shuffle=False,  callbacks=[es_callback],)
                # this should be False, since shuffling data means shuffling the whole graph
                sg.utils.plot_history(history)
                test_gen = generator.flow(test_subjects.index, test_targets)
                '''
                test_metrics = model.evaluate(test_gen)
                print("\nTest Set Metrics:")
                for name, val in zip(model.metrics_names, test_metrics):
                    print("\t{}: {:0.4f}".format(name, val))
                '''
                all_nodes = node_subjects1.index
                all_gen = generator.flow(all_nodes)
                all_predictions = model.predict(all_gen)
                node_predictions = target_encoding.inverse_transform(all_predictions.squeeze())
                #mapping categories to numbers
                d_tt1={}
                #margs2={}
                d_tt1["Neural_Networks"]=0
                d_tt1["Probabilistic_Methods"]=1
                d_tt1["Genetic_Algorithms"]=2
                d_tt1["Theory"]=3
                d_tt1["Case_Based"]=4
                d_tt1["Reinforcement_Learning"]=5
                d_tt1["Rule_Learning"]=6
                # mapping and computing f-score
                gcnp={}
                gcnr={}
                for t in range(0,len(node_predictions)):#node_predictions:
                    if str(node_subjects1.index[t]) in WORDS:
                        #print(node_subjects1.index[t],node_subjects1[node_subjects1.index[t]],node_predictions[t])
                        gcnp[node_subjects1.index[t]]=node_predictions[t]
                        gcnr[node_subjects1.index[t]]=node_subjects1[node_subjects1.index[t]]
                p=[]
                tr=[]
                for k in gcnp:
                    p.append(d_tt1[gcnp[k]])
                for k in gcnr:
                    #print(d_tt1[gcnr[k]])
                    tr.append(d_tt1[gcnr[k]])

                rs=f1_score(tr, p, average='micro')
                return rs,gcnp,x_inp, x_out,all_gen


        dataset = sg.datasets.Cora()
        G, node_subjects=gcn.data(dataset)
        node_subjects1=gcn.update_inp_mlev(node_subjects,WORDS)
        train_subjects,val_subjects, test_subjects=gcn.train_val(node_subjects1)
        target_encoding,train_targets, val_targets,test_targets=gcn.encoding(train_subjects,val_subjects,test_subjects)
        rs,gcnp,x_inp, x_out,all_gen=gcn.gcn_model(G,target_encoding,train_targets, val_targets,test_targets,node_subjects1)
        print(rs)


        #Embedding Representation
        def embed(x_inp,x_out,all_gen):
            embedding_model = Model(inputs=x_inp, outputs=x_out)
            emb = embedding_model.predict(all_gen)
            emb.shape
            from sklearn.decomposition import PCA
            from sklearn.manifold import TSNE

            transform = TSNE  # or PCA
            X = emb.squeeze(0)
            X.shape
            trans = transform(n_components=2)
            X_reduced = trans.fit_transform(X)
            X_reduced.shape
            fig, ax = plt.subplots(figsize=(7, 7))
            ax.scatter(
                X_reduced[:, 0],
                X_reduced[:, 1],
                c=node_subjects1.astype("category").cat.codes,
                cmap="jet",
                alpha=0.7,
            )
            ax.set(
                aspect="equal",
                xlabel="$X_1$",
                ylabel="$X_2$",
                title=f"{transform.__name__} visualization of GCN embeddings for cora dataset",
            )
        embed(x_inp,x_out,all_gen)
        #MLN explanation of the GCN Prediction Store_Explanation_r
        def gcn_exp(gcnp,Store_Explanation_r):
            for k in gcnp:
                if str(k) in Store_Explanation_r:
                    pass
                          #print(k,gcnp[k],Store_Explanation_r[str(k)])
                          #print("\n")



        gcn_exp(gcnp,Store_Explanation_r)

GCN_Result()
# Out:
# The Cora dataset consists of 2708 scientific publications classified into one of seven classes. The citation network consists of 5429 links. Each publication in the dataset is described by a 0/1-valued word vector indicating the absence/presence of the corresponding word from the dictionary. The dictionary consists of 1433 unique words.
# 2400
# Using GCN (local pooling) filters...
# Epoch 1/200
# 1/1 - 2s - loss: 1.9601 - acc: 0.1000 - val_loss: 1.9355 - val_acc: 0.2000
# Epoch 2/200
# 1/1 - 0s - loss: 1.9329 - acc: 0.2300 - val_loss: 1.9153 - val_acc: 0.3050
# Epoch 3/200
# 1/1 - 0s - loss: 1.9061 - acc: 0.3100 - val_loss: 1.8889 - val_acc: 0.3800
# Epoch 4/200
# 1/1 - 0s - loss: 1.8746 - acc: 0.3800 - val_loss: 1.8536 - val_acc: 0.4650
# Epoch 5/200
# 1/1 - 0s - loss: 1.8215 - acc: 0.5000 - val_loss: 1.8107 - val_acc: 0.4800
# Epoch 6/200
# 1/1 - 0s - loss: 1.7661 - acc: 0.5100 - val_loss: 1.7594 - val_acc: 0.5250
# Epoch 7/200
# 1/1 - 0s - loss: 1.7010 - acc: 0.6000 - val_loss: 1.6972 - val_acc: 0.5400
# Epoch 8/200
# 1/1 - 0s - loss: 1.6281 - acc: 0.5800 - val_loss: 1.6229 - val_acc: 0.5750
# Epoch 9/200
# 1/1 - 0s - loss: 1.5376 - acc: 0.6200 - val_loss: 1.5419 - val_acc: 0.5950
# Epoch 10/200
# 1/1 - 0s - loss: 1.4417 - acc: 0.6400 - val_loss: 1.4584 - val_acc: 0.6050
# Epoch 11/200
# 1/1 - 0s - loss: 1.3395 - acc: 0.6400 - val_loss: 1.3748 - val_acc: 0.6550
# Epoch 12/200
# 1/1 - 0s - loss: 1.2711 - acc: 0.6700 - val_loss: 1.2875 - val_acc: 0.6750
# Epoch 13/200
# 1/1 - 0s - loss: 1.1689 - acc: 0.7900 - val_loss: 1.2018 - val_acc: 0.6950
# Epoch 14/200
# 1/1 - 0s - loss: 1.0316 - acc: 0.7800 - val_loss: 1.1238 - val_acc: 0.6950
# Epoch 15/200
# 1/1 - 0s - loss: 0.9524 - acc: 0.7500 - val_loss: 1.0510 - val_acc: 0.6950
# Epoch 16/200
# 1/1 - 0s - loss: 0.8508 - acc: 0.8200 - val_loss: 0.9842 - val_acc: 0.7050
# Epoch 17/200
# 1/1 - 0s - loss: 0.7987 - acc: 0.7800 - val_loss: 0.9245 - val_acc: 0.7250
# Epoch 18/200
# 1/1 - 0s - loss: 0.6605 - acc: 0.8200 - val_loss: 0.8723 - val_acc: 0.7500
# Epoch 19/200
# 1/1 - 0s - loss: 0.6515 - acc: 0.8400 - val_loss: 0.8257 - val_acc: 0.7550
# Epoch 20/200
# 1/1 - 0s - loss: 0.5897 - acc: 0.8500 - val_loss: 0.7845 - val_acc: 0.7600
# Epoch 21/200
# 1/1 - 0s - loss: 0.4890 - acc: 0.8700 - val_loss: 0.7483 - val_acc: 0.7600
# Epoch 22/200
# 1/1 - 0s - loss: 0.3806 - acc: 0.9100 - val_loss: 0.7166 - val_acc: 0.7650
# Epoch 23/200
# 1/1 - 0s - loss: 0.3124 - acc: 0.8900 - val_loss: 0.6868 - val_acc: 0.7750
# Epoch 24/200
# 1/1 - 0s - loss: 0.3052 - acc: 0.9400 - val_loss: 0.6596 - val_acc: 0.7850
# Epoch 25/200
# 1/1 - 0s - loss: 0.3341 - acc: 0.9200 - val_loss: 0.6385 - val_acc: 0.8000
# Epoch 26/200
# 1/1 - 0s - loss: 0.2643 - acc: 0.9000 - val_loss: 0.6278 - val_acc: 0.8100
# Epoch 27/200
# 1/1 - 0s - loss: 0.2345 - acc: 0.9200 - val_loss: 0.6236 - val_acc: 0.8150
# Epoch 28/200
# 1/1 - 0s - loss: 0.2407 - acc: 0.9300 - val_loss: 0.6157 - val_acc: 0.8100
# Epoch 29/200
# 1/1 - 0s - loss: 0.2073 - acc: 0.9300 - val_loss: 0.6136 - val_acc: 0.8050
# Epoch 30/200
# 1/1 - 0s - loss: 0.2368 - acc: 0.9400 - val_loss: 0.6228 - val_acc: 0.7950
# Epoch 31/200
# 1/1 - 0s - loss: 0.2127 - acc: 0.9300 - val_loss: 0.6454 - val_acc: 0.7850
# Epoch 32/200
# 1/1 - 0s - loss: 0.1949 - acc: 0.9500 - val_loss: 0.6645 - val_acc: 0.7850
# Epoch 33/200
# 1/1 - 0s - loss: 0.1451 - acc: 0.9600 - val_loss: 0.6743 - val_acc: 0.7650
# Epoch 34/200
# 1/1 - 0s - loss: 0.1486 - acc: 0.9500 - val_loss: 0.6757 - val_acc: 0.7800
# Epoch 35/200
# 1/1 - 0s - loss: 0.1342 - acc: 0.9700 - val_loss: 0.6780 - val_acc: 0.7850
# Epoch 36/200
# 1/1 - 0s - loss: 0.1035 - acc: 0.9600 - val_loss: 0.6759 - val_acc: 0.7950
# Epoch 37/200
# 1/1 - 0s - loss: 0.0573 - acc: 1.0000 - val_loss: 0.6783 - val_acc: 0.7950
# Epoch 38/200
# 1/1 - 0s - loss: 0.0968 - acc: 0.9700 - val_loss: 0.6778 - val_acc: 0.7850
# Epoch 39/200
# 1/1 - 0s - loss: 0.0687 - acc: 0.9900 - val_loss: 0.6836 - val_acc: 0.8000
# Epoch 40/200
# 1/1 - 0s - loss: 0.0705 - acc: 0.9900 - val_loss: 0.6930 - val_acc: 0.8000
# Epoch 41/200
# 1/1 - 0s - loss: 0.0890 - acc: 0.9600 - val_loss: 0.7082 - val_acc: 0.7950
# Epoch 42/200
# 1/1 - 0s - loss: 0.0836 - acc: 0.9800 - val_loss: 0.7258 - val_acc: 0.7900
# Epoch 43/200
# 1/1 - 2s - loss: 0.1472 - acc: 0.9500 - val_loss: 0.7473 - val_acc: 0.7900
# Epoch 44/200
# 1/1 - 0s - loss: 0.0656 - acc: 0.9900 - val_loss: 0.7660 - val_acc: 0.7850
# Epoch 45/200
# 1/1 - 0s - loss: 0.0624 - acc: 0.9700 - val_loss: 0.7757 - val_acc: 0.7900
# Epoch 46/200
# 1/1 - 0s - loss: 0.0536 - acc: 0.9800 - val_loss: 0.7789 - val_acc: 0.7850
# Epoch 47/200
# 1/1 - 0s - loss: 0.0558 - acc: 0.9800 - val_loss: 0.7787 - val_acc: 0.7800
# Epoch 48/200
# 1/1 - 0s - loss: 0.0464 - acc: 0.9900 - val_loss: 0.7763 - val_acc: 0.7800
# Epoch 49/200
# 1/1 - 0s - loss: 0.0379 - acc: 0.9900 - val_loss: 0.7718 - val_acc: 0.7800
# Epoch 50/200
# 1/1 - 0s - loss: 0.0383 - acc: 0.9900 - val_loss: 0.7677 - val_acc: 0.7800
# Epoch 51/200
# 1/1 - 0s - loss: 0.0581 - acc: 0.9700 - val_loss: 0.7644 - val_acc: 0.7900
# Epoch 52/200
# 1/1 - 0s - loss: 0.0529 - acc: 0.9700 - val_loss: 0.7633 - val_acc: 0.7900
# Epoch 53/200
# 1/1 - 0s - loss: 0.0416 - acc: 0.9800 - val_loss: 0.7696 - val_acc: 0.8000
# Epoch 54/200
# 1/1 - 0s - loss: 0.0211 - acc: 1.0000 - val_loss: 0.7806 - val_acc: 0.8000
# Epoch 55/200
# 1/1 - 0s - loss: 0.0661 - acc: 0.9600 - val_loss: 0.7866 - val_acc: 0.8050
# Epoch 56/200
# 1/1 - 0s - loss: 0.0368 - acc: 0.9900 - val_loss: 0.7942 - val_acc: 0.8050
# Epoch 57/200
# 1/1 - 0s - loss: 0.0317 - acc: 1.0000 - val_loss: 0.8003 - val_acc: 0.8050
# Epoch 58/200
# 1/1 - 0s - loss: 0.0346 - acc: 0.9900 - val_loss: 0.8065 - val_acc: 0.8000
# Epoch 59/200
# 1/1 - 0s - loss: 0.0347 - acc: 0.9900 - val_loss: 0.8136 - val_acc: 0.8050
# Epoch 60/200
# 1/1 - 0s - loss: 0.0300 - acc: 1.0000 - val_loss: 0.8130 - val_acc: 0.8150
# Epoch 61/200
# 1/1 - 0s - loss: 0.0415 - acc: 0.9700 - val_loss: 0.8180 - val_acc: 0.8150
# Epoch 62/200
# 1/1 - 0s - loss: 0.0342 - acc: 0.9800 - val_loss: 0.8146 - val_acc: 0.8150
# Epoch 63/200
# 1/1 - 0s - loss: 0.0424 - acc: 0.9900 - val_loss: 0.8083 - val_acc: 0.8050
# Epoch 64/200
# 1/1 - 0s - loss: 0.0401 - acc: 0.9900 - val_loss: 0.8089 - val_acc: 0.8100
# Epoch 65/200
# 1/1 - 0s - loss: 0.0154 - acc: 1.0000 - val_loss: 0.8114 - val_acc: 0.8100
# Epoch 66/200
# 1/1 - 0s - loss: 0.0203 - acc: 1.0000 - val_loss: 0.8178 - val_acc: 0.8100
# Epoch 67/200
# 1/1 - 0s - loss: 0.0320 - acc: 1.0000 - val_loss: 0.8220 - val_acc: 0.8000
# Epoch 68/200
# 1/1 - 0s - loss: 0.0265 - acc: 0.9900 - val_loss: 0.8256 - val_acc: 0.7950
# Epoch 69/200
# 1/1 - 0s - loss: 0.0088 - acc: 1.0000 - val_loss: 0.8311 - val_acc: 0.7950
# Epoch 70/200
# 1/1 - 0s - loss: 0.0190 - acc: 0.9900 - val_loss: 0.8370 - val_acc: 0.7950
# Epoch 71/200
# 1/1 - 0s - loss: 0.0148 - acc: 1.0000 - val_loss: 0.8433 - val_acc: 0.7950
# Epoch 72/200
# 1/1 - 0s - loss: 0.0109 - acc: 1.0000 - val_loss: 0.8484 - val_acc: 0.7950
# Epoch 73/200
# 1/1 - 0s - loss: 0.0194 - acc: 1.0000 - val_loss: 0.8504 - val_acc: 0.8000
# Epoch 74/200
# 1/1 - 0s - loss: 0.0146 - acc: 1.0000 - val_loss: 0.8549 - val_acc: 0.8050
# Epoch 75/200
# 1/1 - 0s - loss: 0.0217 - acc: 0.9900 - val_loss: 0.8606 - val_acc: 0.8050
# Epoch 76/200
# 1/1 - 0s - loss: 0.0249 - acc: 0.9900 - val_loss: 0.8688 - val_acc: 0.8050
# Epoch 77/200
# 1/1 - 0s - loss: 0.0193 - acc: 0.9900 - val_loss: 0.8717 - val_acc: 0.8050
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000021DEAB27DC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 0.853896103896104
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000021DEBCEB280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
