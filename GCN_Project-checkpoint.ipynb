# %%
import pandas as pd
import os

import stellargraph as sg
from stellargraph.mapper import FullBatchNodeGenerator
from stellargraph.layer import GCN

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from sklearn import preprocessing, model_selection
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import f1_score
class gcn:
    @classmethod
    def data(cls,dataset):
        display(HTML(dataset.description))
        G, node_subjects = dataset.load()
        return G, node_subjects
    @classmethod
    def update_inp_mlev(cls,node_subjects,WORDS):
        rm1=[]
        for t in node_subjects.index:
            #print(t)
            if str(t) not in WORDS:
                rm1.append(t)
        print(len(rm1))
        node_subjects1=node_subjects.drop(labels=rm1)
        return node_subjects1
    @classmethod
    def dis_graph_info(cls,G):
        return  G.info()
    @classmethod
    def updated_nodes(cls,node_subjects1):
        return node_subjects1.value_counts().to_frame()
    @classmethod
    def train_val(cls,node_subjects1):
        train_subjects, test_subjects = model_selection.train_test_split(node_subjects1, train_size=100, test_size=None, stratify=node_subjects1)
        val_subjects, test_subjects = model_selection.train_test_split(test_subjects, train_size=200, test_size=None, stratify=test_subjects)
        return train_subjects,val_subjects, test_subjects
    @classmethod
    def encoding(cls,train_subjects,val_subjects,test_subjects):
        target_encoding = preprocessing.LabelBinarizer()
        train_targets = target_encoding.fit_transform(train_subjects)
        val_targets = target_encoding.transform(val_subjects)
        test_targets = target_encoding.transform(test_subjects)
        return target_encoding,train_targets, val_targets,test_targets
    @classmethod
    def gcn_model(cls,G,target_encoding,train_targets, val_targets,test_targets,node_subjects1):
        generator = FullBatchNodeGenerator(G, method="gcn")
        train_gen = generator.flow(train_subjects.index, train_targets)
        gcn = GCN(layer_sizes=[16, 16], activations=["relu", "relu"], generator=generator, dropout=0.5)
        x_inp, x_out = gcn.in_out_tensors()
        predictions = layers.Dense(units=train_targets.shape[1], activation="softmax")(x_out)
        model = Model(inputs=x_inp, outputs=predictions)
        model.compile(optimizer=optimizers.Adam(lr=0.01),loss=losses.categorical_crossentropy,metrics=["acc"],)
        val_gen = generator.flow(val_subjects.index, val_targets)
        es_callback = EarlyStopping(monitor="val_acc", patience=50, restore_best_weights=True)
        history = model.fit(train_gen,epochs=200,validation_data=val_gen,verbose=2,shuffle=False,  callbacks=[es_callback],)
        # this should be False, since shuffling data means shuffling the whole graph
        sg.utils.plot_history(history)
        test_gen = generator.flow(test_subjects.index, test_targets)
        '''
        test_metrics = model.evaluate(test_gen)
        print("\nTest Set Metrics:")
        for name, val in zip(model.metrics_names, test_metrics):
            print("\t{}: {:0.4f}".format(name, val))
        '''
        all_nodes = node_subjects1.index
        all_gen = generator.flow(all_nodes)
        all_predictions = model.predict(all_gen)
        node_predictions = target_encoding.inverse_transform(all_predictions.squeeze())
        #mapping categories to numbers
        d_tt1={}
        #margs2={}
        d_tt1["Neural_Networks"]=0
        d_tt1["Probabilistic_Methods"]=1
        d_tt1["Genetic_Algorithms"]=2
        d_tt1["Theory"]=3
        d_tt1["Case_Based"]=4
        d_tt1["Reinforcement_Learning"]=5
        d_tt1["Rule_Learning"]=6
        # mapping and computing f-score
        gcnp={}
        gcnr={}
        for t in range(0,len(node_predictions)):#node_predictions:
            if str(node_subjects1.index[t]) in WORDS:
                #print(node_subjects1.index[t],node_subjects1[node_subjects1.index[t]],node_predictions[t])
                gcnp[node_subjects1.index[t]]=node_predictions[t]
                gcnr[node_subjects1.index[t]]=node_subjects1[node_subjects1.index[t]]
        p=[]
        tr=[]
        for k in gcnp:
            p.append(d_tt1[gcnp[k]])
        for k in gcnr:
            #print(d_tt1[gcnr[k]])
            tr.append(d_tt1[gcnr[k]])
       
        rs=f1_score(tr, p, average='micro')
        return rs,gcnp,x_inp, x_out,all_gen
dataset = sg.datasets.Cora()
G, node_subjects=gcn.data(dataset)
node_subjects1=gcn.update_inp_mlev(node_subjects,WORDS)
train_subjects,val_subjects, test_subjects=gcn.train_val(node_subjects1)
target_encoding,train_targets, val_targets,test_targets=gcn.encoding(train_subjects,val_subjects,test_subjects)
rs,gcnp,x_inp, x_out,all_gen=gcn.gcn_model(G,target_encoding,train_targets, val_targets,test_targets,node_subjects1)
print(rs)


#Embedding Representation
def embed(x_inp,x_out,all_gen):
    embedding_model = Model(inputs=x_inp, outputs=x_out)
    emb = embedding_model.predict(all_gen)
    emb.shape
    from sklearn.decomposition import PCA
    from sklearn.manifold import TSNE

    transform = TSNE  # or PCA
    X = emb.squeeze(0)
    X.shape
    trans = transform(n_components=2)
    X_reduced = trans.fit_transform(X)
    X_reduced.shape
    fig, ax = plt.subplots(figsize=(7, 7))
    ax.scatter(
        X_reduced[:, 0],
        X_reduced[:, 1],
        c=node_subjects1.astype("category").cat.codes,
        cmap="jet",
        alpha=0.7,
    )
    ax.set(
        aspect="equal",
        xlabel="$X_1$",
        ylabel="$X_2$",
        title=f"{transform.__name__} visualization of GCN embeddings for cora dataset",
    )
embed(x_inp,x_out,all_gen)
#MLN explanation of the GCN Prediction Store_Explanation_r
def gcn_exp(gcnp,Store_Explanation_r):
    for k in gcnp:
        if str(k) in Store_Explanation_r:
                  print(k,gcnp[k],Store_Explanation_r[str(k)])
                  print("\n")


gcn_exp(gcnp,Store_Explanation_r)
# Out:
# The Cora dataset consists of 2708 scientific publications classified into one of seven classes. The citation network consists of 5429 links. Each publication in the dataset is described by a 0/1-valued word vector indicating the absence/presence of the corresponding word from the dictionary. The dictionary consists of 1433 unique words.
# 2400
# Using GCN (local pooling) filters...
# Epoch 1/200
# 1/1 - 1s - loss: 1.9627 - acc: 0.1600 - val_loss: 1.9086 - val_acc: 0.3150
# Epoch 2/200
# 1/1 - 0s - loss: 1.9013 - acc: 0.3200 - val_loss: 1.8554 - val_acc: 0.3300
# Epoch 3/200
# 1/1 - 0s - loss: 1.8397 - acc: 0.3600 - val_loss: 1.7934 - val_acc: 0.3400
# Epoch 4/200
# 1/1 - 0s - loss: 1.7651 - acc: 0.4000 - val_loss: 1.7168 - val_acc: 0.3500
# Epoch 5/200
# 1/1 - 0s - loss: 1.6651 - acc: 0.3900 - val_loss: 1.6316 - val_acc: 0.3600
# Epoch 6/200
# 1/1 - 0s - loss: 1.5613 - acc: 0.4200 - val_loss: 1.5418 - val_acc: 0.3750
# Epoch 7/200
# 1/1 - 0s - loss: 1.4568 - acc: 0.4300 - val_loss: 1.4477 - val_acc: 0.4050
# Epoch 8/200
# 1/1 - 0s - loss: 1.3491 - acc: 0.4300 - val_loss: 1.3528 - val_acc: 0.5050
# Epoch 9/200
# 1/1 - 0s - loss: 1.2137 - acc: 0.4900 - val_loss: 1.2593 - val_acc: 0.6000
# Epoch 10/200
# 1/1 - 0s - loss: 1.1552 - acc: 0.6300 - val_loss: 1.1700 - val_acc: 0.6250
# Epoch 11/200
# 1/1 - 0s - loss: 1.0604 - acc: 0.6500 - val_loss: 1.0831 - val_acc: 0.6750
# Epoch 12/200
# 1/1 - 0s - loss: 0.9080 - acc: 0.7500 - val_loss: 1.0033 - val_acc: 0.7150
# Epoch 13/200
# 1/1 - 0s - loss: 0.8236 - acc: 0.7700 - val_loss: 0.9296 - val_acc: 0.7900
# Epoch 14/200
# 1/1 - 0s - loss: 0.7646 - acc: 0.8100 - val_loss: 0.8618 - val_acc: 0.8050
# Epoch 15/200
# 1/1 - 0s - loss: 0.6119 - acc: 0.8700 - val_loss: 0.8041 - val_acc: 0.7700
# Epoch 16/200
# 1/1 - 0s - loss: 0.5652 - acc: 0.8800 - val_loss: 0.7550 - val_acc: 0.7600
# Epoch 17/200
# 1/1 - 0s - loss: 0.5040 - acc: 0.9100 - val_loss: 0.7096 - val_acc: 0.7650
# Epoch 18/200
# 1/1 - 0s - loss: 0.4698 - acc: 0.8600 - val_loss: 0.6700 - val_acc: 0.7650
# Epoch 19/200
# 1/1 - 0s - loss: 0.3626 - acc: 0.8900 - val_loss: 0.6400 - val_acc: 0.7900
# Epoch 20/200
# 1/1 - 0s - loss: 0.2747 - acc: 0.9200 - val_loss: 0.6200 - val_acc: 0.7900
# Epoch 21/200
# 1/1 - 0s - loss: 0.2542 - acc: 0.9500 - val_loss: 0.6083 - val_acc: 0.7950
# Epoch 22/200
# 1/1 - 0s - loss: 0.2372 - acc: 0.9500 - val_loss: 0.5953 - val_acc: 0.8000
# Epoch 23/200
# 1/1 - 0s - loss: 0.1751 - acc: 0.9800 - val_loss: 0.5838 - val_acc: 0.7950
# Epoch 24/200
# 1/1 - 0s - loss: 0.1465 - acc: 0.9700 - val_loss: 0.5764 - val_acc: 0.8050
# Epoch 25/200
# 1/1 - 0s - loss: 0.1165 - acc: 0.9800 - val_loss: 0.5703 - val_acc: 0.8150
# Epoch 26/200
# 1/1 - 0s - loss: 0.0952 - acc: 0.9800 - val_loss: 0.5722 - val_acc: 0.8100
# Epoch 27/200
# 1/1 - 0s - loss: 0.1004 - acc: 0.9800 - val_loss: 0.5737 - val_acc: 0.8150
# Epoch 28/200
# 1/1 - 0s - loss: 0.0881 - acc: 0.9900 - val_loss: 0.5798 - val_acc: 0.8150
# Epoch 29/200
# 1/1 - 0s - loss: 0.1276 - acc: 0.9600 - val_loss: 0.5896 - val_acc: 0.8100
# Epoch 30/200
# 1/1 - 0s - loss: 0.0857 - acc: 0.9600 - val_loss: 0.6075 - val_acc: 0.8100
# Epoch 31/200
# 1/1 - 0s - loss: 0.0580 - acc: 0.9900 - val_loss: 0.6327 - val_acc: 0.8100
# Epoch 32/200
# 1/1 - 0s - loss: 0.0737 - acc: 0.9800 - val_loss: 0.6510 - val_acc: 0.8000
# Epoch 33/200
# 1/1 - 0s - loss: 0.0539 - acc: 0.9900 - val_loss: 0.6675 - val_acc: 0.7950
# Epoch 34/200
# 1/1 - 0s - loss: 0.0521 - acc: 0.9800 - val_loss: 0.6736 - val_acc: 0.7950
# Epoch 35/200
# 1/1 - 0s - loss: 0.0539 - acc: 0.9900 - val_loss: 0.6734 - val_acc: 0.8000
# Epoch 36/200
# 1/1 - 0s - loss: 0.0508 - acc: 1.0000 - val_loss: 0.6743 - val_acc: 0.8100
# Epoch 37/200
# 1/1 - 0s - loss: 0.0329 - acc: 0.9900 - val_loss: 0.6766 - val_acc: 0.8050
# Epoch 38/200
# 1/1 - 0s - loss: 0.0313 - acc: 0.9900 - val_loss: 0.6807 - val_acc: 0.8050
# Epoch 39/200
# 1/1 - 0s - loss: 0.0208 - acc: 1.0000 - val_loss: 0.6877 - val_acc: 0.8000
# Epoch 40/200
# 1/1 - 0s - loss: 0.0358 - acc: 0.9900 - val_loss: 0.6971 - val_acc: 0.8100
# Epoch 41/200
# 1/1 - 0s - loss: 0.0282 - acc: 0.9900 - val_loss: 0.7124 - val_acc: 0.8100
# Epoch 42/200
# 1/1 - 0s - loss: 0.0166 - acc: 1.0000 - val_loss: 0.7259 - val_acc: 0.8100
# Epoch 43/200
# 1/1 - 0s - loss: 0.0430 - acc: 0.9800 - val_loss: 0.7268 - val_acc: 0.8100
# Epoch 44/200
# 1/1 - 0s - loss: 0.0258 - acc: 1.0000 - val_loss: 0.7293 - val_acc: 0.8100
# Epoch 45/200
# 1/1 - 0s - loss: 0.0102 - acc: 1.0000 - val_loss: 0.7330 - val_acc: 0.8100
# Epoch 46/200
# 1/1 - 0s - loss: 0.0182 - acc: 1.0000 - val_loss: 0.7427 - val_acc: 0.8150
# Epoch 47/200
# 1/1 - 0s - loss: 0.0153 - acc: 1.0000 - val_loss: 0.7554 - val_acc: 0.8050
# Epoch 48/200
# 1/1 - 0s - loss: 0.0247 - acc: 1.0000 - val_loss: 0.7701 - val_acc: 0.8050
# Epoch 49/200
# 1/1 - 0s - loss: 0.0168 - acc: 1.0000 - val_loss: 0.7825 - val_acc: 0.8050
# Epoch 50/200
# 1/1 - 0s - loss: 0.0157 - acc: 1.0000 - val_loss: 0.7965 - val_acc: 0.8050
# Epoch 51/200
# 1/1 - 0s - loss: 0.0269 - acc: 1.0000 - val_loss: 0.8104 - val_acc: 0.8000
# Epoch 52/200
# 1/1 - 0s - loss: 0.0220 - acc: 0.9900 - val_loss: 0.8189 - val_acc: 0.7950
# Epoch 53/200
# 1/1 - 0s - loss: 0.0250 - acc: 0.9900 - val_loss: 0.8255 - val_acc: 0.8000
# Epoch 54/200
# 1/1 - 0s - loss: 0.0241 - acc: 1.0000 - val_loss: 0.8350 - val_acc: 0.8000
# Epoch 55/200
# 1/1 - 0s - loss: 0.0177 - acc: 1.0000 - val_loss: 0.8414 - val_acc: 0.8100
# Epoch 56/200
# 1/1 - 0s - loss: 0.0381 - acc: 0.9900 - val_loss: 0.8495 - val_acc: 0.8100
# Epoch 57/200
# 1/1 - 0s - loss: 0.0191 - acc: 1.0000 - val_loss: 0.8548 - val_acc: 0.8150
# Epoch 58/200
# 1/1 - 0s - loss: 0.0293 - acc: 0.9900 - val_loss: 0.8684 - val_acc: 0.8100
# Epoch 59/200
# 1/1 - 0s - loss: 0.0162 - acc: 0.9900 - val_loss: 0.8773 - val_acc: 0.8150
# Epoch 60/200
# 1/1 - 0s - loss: 0.0086 - acc: 1.0000 - val_loss: 0.8833 - val_acc: 0.8100
# Epoch 61/200
# 1/1 - 0s - loss: 0.0108 - acc: 1.0000 - val_loss: 0.8794 - val_acc: 0.8150
# Epoch 62/200
# 1/1 - 0s - loss: 0.0147 - acc: 1.0000 - val_loss: 0.8716 - val_acc: 0.8150
# Epoch 63/200
# 1/1 - 0s - loss: 0.0069 - acc: 1.0000 - val_loss: 0.8654 - val_acc: 0.8200
# Epoch 64/200
# 1/1 - 0s - loss: 0.0050 - acc: 1.0000 - val_loss: 0.8591 - val_acc: 0.8200
# Epoch 65/200
# 1/1 - 0s - loss: 0.0058 - acc: 1.0000 - val_loss: 0.8527 - val_acc: 0.8300
# Epoch 66/200
# 1/1 - 0s - loss: 0.0150 - acc: 1.0000 - val_loss: 0.8400 - val_acc: 0.8200
# Epoch 67/200
# 1/1 - 0s - loss: 0.0053 - acc: 1.0000 - val_loss: 0.8286 - val_acc: 0.8200
# Epoch 68/200
# 1/1 - 0s - loss: 0.0093 - acc: 1.0000 - val_loss: 0.8210 - val_acc: 0.8250
# Epoch 69/200
# 1/1 - 0s - loss: 0.0069 - acc: 1.0000 - val_loss: 0.8169 - val_acc: 0.8150
# Epoch 70/200
# 1/1 - 0s - loss: 0.0131 - acc: 1.0000 - val_loss: 0.8175 - val_acc: 0.8200
# Epoch 71/200
# 1/1 - 0s - loss: 0.0061 - acc: 1.0000 - val_loss: 0.8200 - val_acc: 0.8150
# Epoch 72/200
# 1/1 - 0s - loss: 0.0194 - acc: 0.9800 - val_loss: 0.8247 - val_acc: 0.8100
# Epoch 73/200
# 1/1 - 0s - loss: 0.0053 - acc: 1.0000 - val_loss: 0.8297 - val_acc: 0.8100
# Epoch 74/200
# 1/1 - 0s - loss: 0.0149 - acc: 0.9900 - val_loss: 0.8288 - val_acc: 0.8150
# Epoch 75/200
# 1/1 - 0s - loss: 0.0126 - acc: 1.0000 - val_loss: 0.8314 - val_acc: 0.8200
# Epoch 76/200
# 1/1 - 0s - loss: 0.0038 - acc: 1.0000 - val_loss: 0.8361 - val_acc: 0.8150
# Epoch 77/200
# 1/1 - 0s - loss: 0.0144 - acc: 1.0000 - val_loss: 0.8424 - val_acc: 0.8150
# Epoch 78/200
# 1/1 - 0s - loss: 0.0139 - acc: 0.9900 - val_loss: 0.8442 - val_acc: 0.8150
# Epoch 79/200
# 1/1 - 0s - loss: 0.0280 - acc: 0.9900 - val_loss: 0.8392 - val_acc: 0.8150
# Epoch 80/200
# 1/1 - 0s - loss: 0.0071 - acc: 1.0000 - val_loss: 0.8362 - val_acc: 0.8100
# Epoch 81/200
# 1/1 - 0s - loss: 0.0198 - acc: 0.9900 - val_loss: 0.8403 - val_acc: 0.8100
# Epoch 82/200
# 1/1 - 0s - loss: 0.0038 - acc: 1.0000 - val_loss: 0.8440 - val_acc: 0.8100
# Epoch 83/200
# 1/1 - 0s - loss: 0.0090 - acc: 1.0000 - val_loss: 0.8515 - val_acc: 0.8050
# Epoch 84/200
# 1/1 - 0s - loss: 0.0192 - acc: 0.9900 - val_loss: 0.8607 - val_acc: 0.8050
# Epoch 85/200
# 1/1 - 0s - loss: 0.0123 - acc: 1.0000 - val_loss: 0.8698 - val_acc: 0.8050
# Epoch 86/200
# 1/1 - 0s - loss: 0.0189 - acc: 0.9900 - val_loss: 0.8753 - val_acc: 0.8050
# Epoch 87/200
# 1/1 - 0s - loss: 0.0089 - acc: 1.0000 - val_loss: 0.8797 - val_acc: 0.8050
# Epoch 88/200
# 1/1 - 0s - loss: 0.0044 - acc: 1.0000 - val_loss: 0.8839 - val_acc: 0.8050
# Epoch 89/200
# 1/1 - 0s - loss: 0.0061 - acc: 1.0000 - val_loss: 0.8886 - val_acc: 0.8050
# Epoch 90/200
# 1/1 - 0s - loss: 0.0065 - acc: 1.0000 - val_loss: 0.8958 - val_acc: 0.8000
# Epoch 91/200
# 1/1 - 0s - loss: 0.0045 - acc: 1.0000 - val_loss: 0.9021 - val_acc: 0.8050
# Epoch 92/200
# 1/1 - 0s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.9091 - val_acc: 0.8050
# Epoch 93/200
# 1/1 - 0s - loss: 0.0068 - acc: 1.0000 - val_loss: 0.9158 - val_acc: 0.8100
# Epoch 94/200
# 1/1 - 0s - loss: 0.0037 - acc: 1.0000 - val_loss: 0.9212 - val_acc: 0.8150
# Epoch 95/200
# 1/1 - 0s - loss: 0.0049 - acc: 1.0000 - val_loss: 0.9244 - val_acc: 0.8100
# Epoch 96/200
# 1/1 - 0s - loss: 0.0039 - acc: 1.0000 - val_loss: 0.9274 - val_acc: 0.8050
# Epoch 97/200
# 1/1 - 0s - loss: 0.0064 - acc: 1.0000 - val_loss: 0.9324 - val_acc: 0.8050
# Epoch 98/200
# 1/1 - 0s - loss: 0.0142 - acc: 0.9900 - val_loss: 0.9429 - val_acc: 0.8000
# Epoch 99/200
# 1/1 - 0s - loss: 0.0122 - acc: 1.0000 - val_loss: 0.9492 - val_acc: 0.8000
# Epoch 100/200
# 1/1 - 0s - loss: 0.0041 - acc: 1.0000 - val_loss: 0.9593 - val_acc: 0.7950
# Epoch 101/200
# 1/1 - 0s - loss: 0.0075 - acc: 1.0000 - val_loss: 0.9684 - val_acc: 0.7950
# Epoch 102/200
# 1/1 - 0s - loss: 0.0112 - acc: 1.0000 - val_loss: 0.9673 - val_acc: 0.7950
# Epoch 103/200
# 1/1 - 0s - loss: 0.0096 - acc: 1.0000 - val_loss: 0.9566 - val_acc: 0.8100
# Epoch 104/200
# 1/1 - 0s - loss: 0.0138 - acc: 0.9900 - val_loss: 0.9452 - val_acc: 0.8100
# Epoch 105/200
# 1/1 - 0s - loss: 0.0034 - acc: 1.0000 - val_loss: 0.9372 - val_acc: 0.8150
# Epoch 106/200
# 1/1 - 0s - loss: 0.0082 - acc: 1.0000 - val_loss: 0.9296 - val_acc: 0.8150
# Epoch 107/200
# 1/1 - 0s - loss: 0.0088 - acc: 1.0000 - val_loss: 0.9269 - val_acc: 0.8150
# Epoch 108/200
# 1/1 - 0s - loss: 0.0013 - acc: 1.0000 - val_loss: 0.9249 - val_acc: 0.8100
# Epoch 109/200
# 1/1 - 0s - loss: 0.0021 - acc: 1.0000 - val_loss: 0.9239 - val_acc: 0.8050
# Epoch 110/200
# 1/1 - 0s - loss: 0.0131 - acc: 1.0000 - val_loss: 0.9302 - val_acc: 0.8050
# Epoch 111/200
# 1/1 - 0s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.9359 - val_acc: 0.8000
# Epoch 112/200
# 1/1 - 0s - loss: 0.0091 - acc: 1.0000 - val_loss: 0.9406 - val_acc: 0.8000
# Epoch 113/200
# 1/1 - 0s - loss: 0.0037 - acc: 1.0000 - val_loss: 0.9463 - val_acc: 0.8000
# Epoch 114/200
# 1/1 - 0s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.9517 - val_acc: 0.7950
# Epoch 115/200
# 1/1 - 0s - loss: 0.0045 - acc: 1.0000 - val_loss: 0.9543 - val_acc: 0.8000
# 0.8798701298701299
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020103820160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 31353 Theory [('Samelink(31353,31489)', 0.9739344722966202), ('w_1274', 0.0024940665862935407), ('w_1206', 0.0024462622476532254), ('w_1382', 0.0020849393662717396), ('w_1210', 0.002027957517541779), ('w_522', 0.0019809393968322074), ('w_620', 0.0017690641801565992), ('w_94', 0.001748489252391418), ('w_699', 0.0015528420510225276), ('w_1152', 0.0014270647773108678), ('w_1390', 0.0014131044196030564), ('w_649', 0.001253356559953539), ('w_255', 0.0008317890437645391), ('w_846', 0.0008223373356802291), ('w_737', 0.000811344207064992), ('w_510', 0.0007919074681040664), ('w_903', 0.0007445961397441673), ('w_1397', 0.000662949795897321), ('w_1313', 0.0006117932762346572), ('w_457', 0.0005907240818593414)]
#
#
# 66990 Probabilistic_Methods [('Samelink(66990,31489)', 0.9109121666553079), ('w_1329', 0.007469805106612583), ('w_1132', 0.007211072695022187), ('w_725', 0.006839245670542419), ('w_1302', 0.006288744242838369), ('w_648', 0.006278962172959948), ('w_1210', 0.006151558237126294), ('w_894', 0.005961726812517536), ('w_1255', 0.0051695753175578195), ('w_131', 0.003997175468917714), ('w_1209', 0.0031173728141489663), ('w_1175', 0.0029942203559281074), ('w_20', 0.002616451261855234), ('w_712', 0.0025162312531056092), ('w_6', 0.0024496310186920786), ('w_421', 0.0024251734443129364), ('w_208', 0.0023097768316055517), ('w_137', 0.002306369588554007), ('w_352', 0.002293232825276264), ('w_694', 0.0022762409785716878), ('w_576', 0.0022757868876076676), ('w_452', 0.002122942505858334), ('w_775', 0.002079696762569462), ('w_784', 0.0019368410925114216)]
#
#
# 16819 Probabilistic_Methods [('Samelink(16819,31489)', 0.9848593249277919), ('w_677', 0.0013305222757053988), ('w_914', 0.0013041823746815894), ('w_972', 0.001189081359866421), ('w_1335', 0.0011175809724170908), ('w_813', 0.0009147851239816572), ('w_1382', 0.0009035685526180715), ('w_648', 0.0008970760413539978), ('w_620', 0.0007666749386630544), ('w_79', 0.000737523251459606), ('w_42', 0.0006531540453373125), ('w_1390', 0.0006124095193243705), ('w_152', 0.0006073054934755714), ('w_136', 0.0006046692291746867), ('w_649', 0.0005431781811557877), ('w_822', 0.00039868687613767335), ('w_683', 0.0003384378269395369), ('w_1415', 0.0003381297658948304), ('w_1321', 0.00033685972652077676), ('w_1292', 0.0003268201769104728), ('w_56', 0.0003254870424382585), ('w_884', 0.0003210844064253286), ('w_598', 0.0003076512338377866), ('w_1413', 0.00026580665788879254)]
#
#
# 4329 Probabilistic_Methods [('Samelink(4329,31489)', 0.8732805179702345), ('w_730', 0.013640737519010524), ('w_982', 0.0130021412711792), ('w_1361', 0.01153035705385119), ('w_27', 0.010152812729992213), ('w_1264', 0.007371955392204146), ('w_1331', 0.0066447854678825585), ('w_1178', 0.00656674449248321), ('w_1210', 0.006417785765635048), ('w_541', 0.006397151985775492), ('w_447', 0.0062062440498132565), ('w_1353', 0.006049976110618717), ('w_1385', 0.005535026803889105), ('w_136', 0.0044154660826381895), ('w_1263', 0.004367078074032766), ('w_277', 0.0026291264167373823), ('w_1185', 0.0025635866411629284), ('w_1410', 0.0024681268627552897), ('w_930', 0.002454541644702477), ('w_695', 0.0022769474009652273), ('w_1110', 0.0021134593827010183), ('w_177', 0.002055395213694413), ('w_78', 0.0018600356680407598)]
#
#
# 4330 Probabilistic_Methods [('Samelink(4330,31489)', 0.9875438744672868), ('w_1361', 0.0014440622849811334), ('w_1377', 0.0012057080084125586), ('w_282', 0.0011381853199795874), ('w_472', 0.0009932003880555212), ('w_1329', 0.0009760060644055542), ('w_1264', 0.0009232639283177827), ('w_508', 0.0008501997968103728), ('w_1210', 0.0008037636938699042), ('w_447', 0.0007772702026370014), ('w_699', 0.0006154557243582258), ('w_239', 0.0005027144163872329), ('w_778', 0.0003119439143383903), ('w_694', 0.00029741405129401913), ('w_752', 0.0002882947207295405), ('w_695', 0.0002851649650798519), ('w_1055', 0.0002741358595575352), ('w_667', 0.0002717015466794026), ('w_1110', 0.0002646897204608835), ('w_78', 0.00023295092635836545)]
#
#
# 5062 Case_Based [('Samelink(5062,31489)', 0.9955173706712184), ('w_1254', 0.0018475847468288388), ('w_1300', 0.00093587736642911), ('w_1210', 0.0009045373610375417), ('w_759', 0.0004853839570075253), ('w_41', 0.0003092458974786351)]
#
#
# 20534 Reinforcement_Learning [('Samelink(20534,31489)', 0.9874297955415131), ('w_1264', 0.0016011823920094974), ('w_1360', 0.0015404909417693685), ('w_1356', 0.0014880951958985767), ('w_508', 0.0014744699782901734), ('w_1382', 0.0014331046298927603), ('w_1256', 0.000562009124156431), ('w_510', 0.0005443257858457433), ('w_582', 0.000529173595474509), ('w_153', 0.0005191935915530324), ('w_341', 0.0005080595038598345), ('w_1156', 0.0005039736767174369), ('w_1059', 0.0005007210966130782), ('w_1032', 0.00047725317235929976), ('w_169', 0.00044678605498522656), ('w_735', 0.0004413657190618384)]
#
#
# 5086 Probabilistic_Methods [('Samelink(5086,31489)', 0.9938197302972118), ('w_999', 0.0007584078400151111), ('w_337', 0.0006539262024120115), ('w_1329', 0.0006230124780286998), ('w_1250', 0.0005499365723292916), ('w_1210', 0.0005130652656060901), ('w_894', 0.0004972325437927023), ('w_1425', 0.0004157191210969034), ('w_699', 0.00039286292363654773), ('w_1248', 0.0003411539271995894), ('w_239', 0.00032089693467726287), ('w_1286', 0.00019886044286108578), ('w_416', 0.00019675448149907213), ('w_525', 0.00019223946885049193), ('w_130', 0.00018114148619062306), ('w_807', 0.00017682551420851193), ('w_1235', 0.00016823450038412464)]
#
#
# 40151 Theory [('Samelink(40151,31489)', 0.9395121427562276), ('w_1088', 0.0046388604287375635), ('w_1029', 0.0046206027620498274), ('w_1431', 0.004606293176902815), ('w_1367', 0.004595262597140974), ('w_681', 0.004523880802322107), ('w_1368', 0.004522204055249612), ('w_470', 0.0032560483360368907), ('w_730', 0.002626103231812318), ('w_707', 0.0025602832056285892), ('w_1308', 0.002554753955904663), ('w_1386', 0.002511352254390683), ('w_970', 0.002391060854138985), ('w_314', 0.0022968696959062293), ('w_275', 0.0020324070782129656), ('w_133', 0.0016367126420464412), ('w_337', 0.0015747632939491698), ('w_1380', 0.0014970627869982582), ('w_1354', 0.0014607836080995262), ('w_616', 0.0014596767006303023), ('w_756', 0.0012685650015514375), ('w_1210', 0.0012355466789625486), ('w_1171', 0.000982575605351059), ('w_1152', 0.000869448758674279), ('w_1072', 0.0007667397330752732)]
#
#
# 153063 Probabilistic_Methods [('Samelink(153063,31489)', 0.9822842940476741), ('w_750', 0.00179811698098593), ('w_869', 0.001687995031510147), ('w_24', 0.001341365113871288), ('w_626', 0.001225727987360598), ('w_1210', 0.0011469217477736852), ('w_894', 0.0011115287983936995), ('w_1346', 0.001037076909178731), ('w_724', 0.0010062353770721934), ('w_620', 0.0010005032964834916), ('w_1255', 0.0009638368247377434), ('w_1072', 0.0007117420083914749), ('w_293', 0.0006710314263354928), ('w_1209', 0.0005812157730845359), ('w_1172', 0.0005498790025212205), ('w_395', 0.00044381560696758125), ('w_1350', 0.000432778280275992), ('w_408', 0.000422809530094554), ('w_1037', 0.0004162580410746609), ('w_827', 0.00040099440951651527), ('w_1055', 0.00039117514459674013), ('w_17', 0.00037469866209989447)]
#
#
# 50336 Probabilistic_Methods [('Samelink(50336,31489)', 0.9814554563865351), ('w_940', 0.002152791840817686), ('w_467', 0.0020023490710903745), ('w_572', 0.0016758587703560401), ('w_765', 0.0016195925672242244), ('w_1232', 0.0015252024151731272), ('w_1154', 0.001493528967506722), ('w_371', 0.0014707605273214764), ('w_1282', 0.0014019645644916005), ('w_475', 0.001368602877808109), ('w_620', 0.0008489168427749671), ('w_1171', 0.0007739042542793029), ('w_20', 0.0004139119105036794), ('w_939', 0.00041330519598081034), ('w_961', 0.00037609373993003974), ('w_289', 0.00037536779826391443), ('w_182', 0.00035034852612610395), ('w_78', 0.0002820437438169059)]
#
#
# 15429 Theory [('Samelink(15429,31489)', 0.9153163536994442), ('w_30', 0.008674857712625038), ('w_455', 0.008648885395313194), ('w_652', 0.008637456152525633), ('w_368', 0.0059026753908472986), ('w_940', 0.005162702883675495), ('w_1337', 0.005005640123986281), ('w_1115', 0.005005109469103856), ('w_259', 0.004774722260782412), ('w_57', 0.004749833383158748), ('w_726', 0.00360304357272388), ('w_371', 0.0035270942000201104), ('w_126', 0.0034552633601992204), ('w_1124', 0.003274868903963244), ('w_212', 0.0032476940237118014), ('w_1329', 0.0028338681376999415), ('w_1411', 0.0028152692951037713), ('w_3', 0.0026839325554883233), ('w_1264', 0.0026807294796277682)]
#
#
# 35061 Genetic_Algorithms [('Samelink(35061,31489)', 0.9973576205856467), ('w_1264', 0.0008202256143606334), ('w_508', 0.0007553156029161441), ('w_20', 0.00030371298063363276), ('w_300', 0.00026297269389712947), ('w_496', 0.0002518602360784902), ('w_394', 0.0002482922864672281)]
#
#
# 8703 Rule_Learning [('Samelink(8703,31489)', 0.9931257512934463), ('w_71', 0.0006416653101891588), ('w_755', 0.0005211611573439961), ('w_726', 0.0004819050556480154), ('w_1426', 0.0004552323639846773), ('w_1229', 0.0004449161298036765), ('w_1258', 0.00044484077083010743), ('w_1132', 0.00036589983144540513), ('w_1077', 0.0003627121727285285), ('w_1349', 0.0003315756693847602), ('w_1382', 0.0003209091143972308), ('w_1178', 0.0003193834283446783), ('w_26', 0.00028220417261976097), ('w_378', 0.0002798079543198661), ('w_370', 0.00026148637016352734), ('w_55', 0.0002394574134931493), ('w_676', 0.00022885077639723348), ('w_1317', 0.00012648588948149756), ('w_1307', 0.00011491932178874198), ('w_391', 0.00011440740584802938), ('w_1013', 0.00011363636455098895), ('w_643', 0.00011255128886325062), ('w_140', 0.00010871885563116359), ('w_1235', 0.0001023504895546044), ('w_1190', 9.917139974133541e-05)]
#
#
# 126927 Probabilistic_Methods [('Samelink(126927,31489)', 0.9854049462821866), ('w_940', 0.0018589987736682089), ('w_1044', 0.0017550044060116437), ('w_1335', 0.0010685871480834684), ('w_279', 0.0010071721555891748), ('w_508', 0.000888894236651822), ('w_403', 0.0008627249958308198), ('w_1178', 0.0008598493781715386), ('w_809', 0.0008305954088857106), ('w_1231', 0.0006873664598913995), ('w_649', 0.0005193656995135437), ('w_759', 0.00045093753538586823), ('w_822', 0.00038120877365050977), ('w_34', 0.00034946869039455616), ('w_548', 0.0003482202107808002), ('w_179', 0.0003369435885522033), ('w_686', 0.00032945738326963333), ('w_1350', 0.00031709482008611037), ('w_215', 0.00031702954251359587), ('w_1245', 0.000312892506338088), ('w_598', 0.00029416405852012616), ('w_1296', 0.00028862011494810443), ('w_1190', 0.0002669908919255584), ('w_432', 0.0002634669391506187)]
#
#
# 287787 Genetic_Algorithms [('Samelink(287787,31489)', 0.7184053290437256), ('w_281', 0.03405689087825863), ('w_1427', 0.030221832344435387), ('w_1329', 0.027246708807676507), ('w_736', 0.024014442729510747), ('w_508', 0.023734633561059804), ('w_1210', 0.022438298403805592), ('w_1231', 0.018353579509229726), ('w_1098', 0.017560467599794058), ('w_42', 0.016675505551203253), ('w_1267', 0.01274424754086434), ('w_1172', 0.010757795088033123), ('w_1412', 0.009302526724096788), ('w_645', 0.009261790345846236), ('w_1226', 0.008962238956121433), ('w_115', 0.00834939155339359), ('w_496', 0.007914321362945075)]
#
#
# 137868 Probabilistic_Methods [('Samelink(137868,31489)', 0.9797106033165849), ('w_126', 0.0019075688248201455), ('w_156', 0.0018726466481557948), ('w_972', 0.0017431694603466201), ('w_435', 0.0016288174724317945), ('w_725', 0.0014324439348506782), ('w_1356', 0.0013754409831334983), ('w_1382', 0.0013246134027619112), ('w_1255', 0.0010827402854212968), ('w_649', 0.0007962883355801327), ('w_1172', 0.0006177146720857072), ('w_822', 0.0005844669760883817), ('w_509', 0.0005436776409841371), ('w_977', 0.0005227392679749298), ('w_1415', 0.0004956914652234012), ('w_1114', 0.0004923007527153258), ('w_45', 0.00048118229541592266), ('w_971', 0.00047998396004031836), ('w_695', 0.00045711171444935185), ('w_1216', 0.0004471633133828013), ('w_1055', 0.0004394323570544584), ('w_590', 0.0004135318791615207), ('w_918', 0.00039321501467227217), ('w_1413', 0.00038966723727011963), ('w_1324', 0.0003677887893945598)]
#
#
# 35 Genetic_Algorithms [('Samelink(35,31489)', 0.9919801736505477), ('w_661', 0.0009947332306074596), ('w_1250', 0.0007219473440631302), ('w_508', 0.000712456160815418), ('w_465', 0.0006827857544362826), ('w_1306', 0.000538181783316807), ('w_1152', 0.0004739694705412804), ('w_1248', 0.00044786105171229306), ('w_100', 0.00041196569305874253), ('w_1175', 0.0003278416699797952), ('w_20', 0.0002864791662407488), ('w_866', 0.0002759589461908221), ('w_749', 0.0002734355890853139), ('w_141', 0.0002486657558704842), ('w_192', 0.0002443842750933613), ('w_639', 0.0002440430756555416), ('w_496', 0.00023756874102131786), ('w_386', 0.00023011109069844097), ('w_775', 0.0002277091124380548), ('w_581', 0.00022392417858451915), ('w_1228', 0.0002158042600425429)]
#
#
# 210871 Genetic_Algorithms [('Samelink(210871,31489)', 0.9993875267846783), ('w_1175', 0.000363912051192391), ('w_581', 0.0002485611641292755)]
#
#
# 12631 Neural_Networks [('Samelink(12631,31489)', 0.9795213303575849), ('w_1427', 0.0016905208059459786), ('w_133', 0.0016626580017230694), ('w_646', 0.001611016993091888), ('w_1411', 0.0015140983421923274), ('w_1333', 0.0014968861366697484), ('w_923', 0.0013174065121549184), ('w_809', 0.0012405712009123742), ('w_1353', 0.0011831998110337933), ('w_620', 0.0010948998179905337), ('w_1255', 0.0010547738999831888), ('w_699', 0.0009610767648249532), ('w_136', 0.0008635370684247784), ('w_1180', 0.0007404980797127998), ('w_193', 0.000498692557896224), ('w_1242', 0.0004946554725445304), ('w_248', 0.00048383433473712137), ('w_1102', 0.0004605028524071552), ('w_827', 0.0004388278454833641), ('w_534', 0.0004327327296089732), ('w_358', 0.00041914403679349396), ('w_662', 0.00041149182792872053), ('w_172', 0.00040764455035510207)]
#
#
# 12638 Neural_Networks [('Samelink(12638,31489)', 0.9815125980129487), ('w_764', 0.0017925361761496849), ('w_40', 0.0017790115595359792), ('w_1064', 0.0017110850233089548), ('w_616', 0.0016943676350668541), ('w_1264', 0.0016474324340886672), ('w_1178', 0.001467489599127295), ('w_1231', 0.0011731160785678246), ('w_1072', 0.0008900183086306448), ('w_66', 0.0008728408496864798), ('w_1145', 0.0007726830188503315), ('w_1076', 0.0005867551125056894), ('w_1242', 0.0005652275211629567), ('w_451', 0.0005642563097026197), ('w_248', 0.0005528625414173945), ('w_976', 0.0005073712743624011), ('w_534', 0.0004944703165311508), ('w_775', 0.00048486965473030683), ('w_172', 0.00046580282944723715), ('w_43', 0.0004652057441791024)]
#
#
# 23507 Neural_Networks [('Samelink(23507,31489)', 0.8139088986212935), ('w_1120', 0.019912389429294363), ('w_648', 0.01887105583220993), ('w_1353', 0.017428576490676462), ('w_1259', 0.017235444623686126), ('w_515', 0.01554982931330067), ('w_1139', 0.014885499998744509), ('w_1072', 0.011473139769470965), ('w_1175', 0.008998955234033901), ('w_20', 0.007863592180465456), ('w_874', 0.007393284841649337), ('w_622', 0.006980079600831991), ('w_33', 0.006958604874877523), ('w_1393', 0.006914943642081893), ('w_694', 0.006841109949535045), ('w_394', 0.006428665901141829), ('w_386', 0.006316339848371336), ('w_1225', 0.006039589848335432)]
#
#
# 41714 Genetic_Algorithms [('Samelink(41714,31489)', 0.9911369888738306), ('w_1178', 0.0011312560889440223), ('w_79', 0.0009277804405336086), ('w_912', 0.0005601013040494737), ('w_1010', 0.0005084933835489379), ('w_1294', 0.0004434886006791091), ('w_1280', 0.00043171400197483087), ('w_248', 0.0004261898119751119), ('w_787', 0.0004250491916289116), ('w_1238', 0.0004243883478465894), ('w_303', 0.00042277688530040984), ('w_1113', 0.0004223276680830099), ('w_989', 0.00041957317868132924), ('w_1236', 0.0004191219695805614), ('w_141', 0.00040817506857865446), ('w_599', 0.00040074570561249897), ('w_549', 0.0003977897075067602), ('w_910', 0.0003820816752670217), ('w_742', 0.0003119580963785773)]
#
#
# 30895 Theory [('Samelink(30895,31489)', 0.9818107697476377), ('w_111', 0.0018561872788243287), ('w_942', 0.0018378018697726769), ('w_368', 0.001253505797925618), ('w_206', 0.0011206539744098986), ('w_730', 0.0010533812660218993), ('w_1355', 0.0010348356604175095), ('w_997', 0.0010180341360543177), ('w_845', 0.0010151717151704574), ('w_316', 0.0009891157160886689), ('w_815', 0.000850642460001453), ('w_275', 0.0008152381502696574), ('w_875', 0.0007728833961453843), ('w_726', 0.0007651506663556685), ('w_1229', 0.0007064210453942975), ('w_727', 0.0006862500369699431), ('w_1293', 0.0005747321820254821), ('w_1382', 0.0005095273847884143), ('w_1178', 0.0005071049580342681), ('w_757', 0.0004284623031811879), ('w_1171', 0.0003941302545112225)]
#
#
# 35922 Probabilistic_Methods [('Samelink(35922,31489)', 0.9911335040425583), ('w_940', 0.0011706263345505187), ('w_371', 0.0007997573069795627), ('w_475', 0.0007442069130544782), ('w_337', 0.000674454708360712), ('w_964', 0.0005846485083216885), ('w_1349', 0.0005621236333578193), ('w_1022', 0.0005568572039787081), ('w_648', 0.000540131358681756), ('w_1353', 0.0004988444093165283), ('w_1098', 0.00041413584504858963), ('w_699', 0.00040519594964949745), ('w_1061', 0.0003155913480647385), ('w_1172', 0.0002537055767065344), ('w_20', 0.00022507340163259123), ('w_1339', 0.00021567803561368427), ('w_289', 0.0002041142211051317), ('w_1090', 0.00019236537761426492), ('w_521', 0.00019190462011892776), ('w_641', 0.00018087041673742307), ('w_52', 0.00013621078854854729)]
#
#
# 2354 Theory [('Samelink(2354,31489)', 0.9757172994983337), ('w_696', 0.003183264774180158), ('w_730', 0.0018246041681916699), ('w_1343', 0.0017241019773885868), ('w_1291', 0.001496221512768713), ('w_701', 0.0012385013163169565), ('w_860', 0.001229371441731689), ('w_702', 0.0012182029147954924), ('w_1204', 0.0010801015027241637), ('w_40', 0.0010648407611923794), ('w_1119', 0.0010530962363549767), ('w_1370', 0.001045649858965768), ('w_1167', 0.0010252842389102885), ('w_1264', 0.0009860830851405786), ('w_188', 0.000944600728093183), ('w_811', 0.0009050103244504151), ('w_1302', 0.00087759637179596), ('w_235', 0.0008717904244548455), ('w_980', 0.0008685568763013563), ('w_699', 0.0006573315179207352), ('w_1394', 0.0006372837803604307), ('w_1076', 0.0003512066896277199)]
#
#
# 17798 Case_Based [('Samelink(17798,31489)', 0.9455934920120739), ('w_206', 0.007123479094443238), ('w_1315', 0.005117568831822675), ('w_875', 0.0049128623469907595), ('w_1204', 0.003963712227283432), ('w_764', 0.003937416640817739), ('w_616', 0.0037217833652346526), ('w_1293', 0.0036533067093418277), ('w_1264', 0.003618687291732476), ('w_508', 0.0033323160428859262), ('w_1178', 0.003223431719097571), ('w_1302', 0.003220567197373461), ('w_53', 0.0028996162604902425), ('w_1263', 0.0021436768249056006), ('w_1076', 0.0012888439155672952), ('w_751', 0.0011302761803804612), ('w_720', 0.0011189633395590176)]
#
#
# 10531 Theory [('Samelink(10531,31489)', 0.9446032158247247), ('w_1274', 0.004919907757149951), ('w_1206', 0.004825606771845692), ('w_1293', 0.004639170471284209), ('w_1382', 0.00411284502894998), ('w_1178', 0.004093291485546375), ('w_648', 0.0040832925477348285), ('w_1210', 0.004000440075079079), ('w_1255', 0.003361843532047728), ('w_817', 0.0029296841607364004), ('w_285', 0.002851810601675806), ('w_136', 0.002752321145046884), ('w_649', 0.0024724274386571793), ('w_846', 0.0016221795596964093), ('w_737', 0.001600494020486396), ('w_437', 0.0015561930473563836), ('w_1095', 0.001521859484585885), ('w_903', 0.001468823785220335), ('w_695', 0.001419304408763966), ('w_457', 0.00116528885341195)]
#
#
# 714289 Probabilistic_Methods [('Samelink(714289,31489)', 0.9838572406780828), ('w_1419', 0.0014428490897884273), ('w_40', 0.0011865279281184488), ('w_524', 0.0010808852760970937), ('w_725', 0.0010634874965807924), ('w_1120', 0.0010302419469689894), ('w_861', 0.0010295567665826858), ('w_325', 0.000991729872445011), ('w_1178', 0.0009787555253671569), ('w_1210', 0.0009565536295691427), ('w_1080', 0.0007839812286110204), ('w_699', 0.000732449613566715), ('w_1072', 0.0005936057998422733), ('w_1175', 0.00046559460851838146), ('w_304', 0.00037858664886093247), ('w_1424', 0.00037282801908532156), ('w_1051', 0.0003703086914295949), ('w_622', 0.000361140526278594), ('w_137', 0.00035863534343939465), ('w_237', 0.000348198399040361), ('w_93', 0.0003377649896628692), ('w_1296', 0.0003285325772268049), ('w_288', 0.0003244610808338049), ('w_662', 0.00031360349285641906), ('w_1225', 0.0003124807711468978)]
#
#
# 7419 Reinforcement_Learning [('Samelink(7419,31489)', 0.9985129066113041), ('w_1146', 0.0011444897762429053), ('w_1133', 0.0003426036124529023)]
#
#
# 6767 Case_Based [('Samelink(6767,31489)', 0.9728568182250344), ('w_346', 0.0030680629371171594), ('w_937', 0.002667809673870509), ('w_764', 0.0018754352462289853), ('w_1329', 0.0018220840421057905), ('w_1206', 0.001810041088580079), ('w_1167', 0.001792142456893109), ('w_1333', 0.0017895481670324026), ('w_1264', 0.0017236209197781323), ('w_508', 0.0015872191156038377), ('w_1302', 0.0015339919002192984), ('w_1144', 0.0014204973657415518), ('w_26', 0.0013566262896305375), ('w_1199', 0.001266168386406658), ('w_759', 0.000805198916356665), ('w_637', 0.0006372000745523358), ('w_1341', 0.0005329368711678568), ('w_1202', 0.0005213520587591741), ('w_177', 0.00048056750214223615), ('w_1313', 0.00045267876277945546)]
#
#
# 65074 Probabilistic_Methods [('Samelink(65074,31489)', 0.9883814388107056), ('w_701', 0.0013196283112377025), ('w_1119', 0.0011220784262745574), ('w_1132', 0.001072224957629469), ('w_811', 0.0009642922703212919), ('w_1331', 0.0009470369550998332), ('w_399', 0.0008397958805002523), ('w_1098', 0.0007158422620020487), ('w_62', 0.0006247335815281536), ('w_5', 0.0004985661973709816), ('w_1076', 0.0003742121906717481), ('w_19', 0.00034233940404741325), ('w_1398', 0.0003402392197165604), ('w_302', 0.00033882454878467893), ('w_1307', 0.0003367570967414518), ('w_675', 0.00032736288675099776), ('w_288', 0.0003102590544566364), ('w_833', 0.00030861548436089914), ('w_1195', 0.00030038367087533585), ('w_1235', 0.00029992566242112505), ('w_52', 0.00023544312850348596)]
#
#
# 33895 Genetic_Algorithms [('Samelink(33895,31489)', 0.9976039161165795), ('w_508', 0.0011615429171690456), ('w_1079', 0.0004502088571225998), ('w_1156', 0.00039701524157827097), ('w_496', 0.0003873168675504944)]
#
#
# 2440 Rule_Learning [('Samelink(2440,31489)', 0.9937685438347271), ('w_1262', 0.0012038748136923086), ('w_764', 0.0011580268071246177), ('w_1264', 0.0010642858688068837), ('w_1349', 0.0009842286262330025), ('w_703', 0.0004989755493904903), ('w_950', 0.0003634138748981567), ('w_1006', 0.00033528091554553346), ('w_1096', 0.0003195588723285816), ('w_1235', 0.00030381083725328835)]
#
#
# 1717 Probabilistic_Methods [('Samelink(1717,31489)', 0.9805551933983878), ('w_707', 0.0022074121012381283), ('w_922', 0.0021634684940611054), ('w_126', 0.001577176207669346), ('w_24', 0.0012458558291414577), ('w_1264', 0.0012236354551633858), ('w_508', 0.0011268008891513856), ('w_403', 0.001093627624425773), ('w_447', 0.0010301446303892664), ('w_1073', 0.0010273802547751205), ('w_204', 0.0008863553195204644), ('w_1080', 0.0008730737072792321), ('w_1098', 0.0008336825784336441), ('w_1205', 0.00041272450045958664), ('w_503', 0.00040791164368743664), ('w_1128', 0.0004037693913841388), ('w_137', 0.00039939105354950774), ('w_587', 0.00039763068674132917), ('w_695', 0.0003779395589275453), ('w_93', 0.0003761489700927609), ('w_598', 0.00037289511960992975), ('w_1110', 0.0003508029682946125), ('w_104', 0.0003482412340815161), ('w_78', 0.0003087383835352648)]
#
#
# 3187 Probabilistic_Methods [('Samelink(3187,31489)', 0.9898840557703547), ('w_346', 0.004726404675602026), ('w_1255', 0.0019425877232358733), ('w_431', 0.0009205551330502324), ('w_205', 0.0008767892524262599), ('w_264', 0.0008576631477845022), ('w_1036', 0.0007919442975464806)]
#
#
# 5348 Neural_Networks [('Samelink(5348,31489)', 0.951879368904546), ('w_750', 0.004603534591266032), ('w_701', 0.004236309703808878), ('w_716', 0.004119421653137187), ('w_1264', 0.003372909893035401), ('w_1382', 0.0030188520733442194), ('w_1178', 0.0030044996592294895), ('w_913', 0.002429782221857021), ('w_987', 0.0023791255736339365), ('w_699', 0.0022484109231857945), ('w_697', 0.002177672460825596), ('w_1186', 0.0012785281870585728), ('w_20', 0.0012489204178547475), ('w_390', 0.0011470148913537907), ('w_74', 0.0011440375422594338), ('w_1067', 0.0011365634652206165), ('w_734', 0.0011191248737536146), ('w_216', 0.001114066825757411), ('w_194', 0.0011075635683004568), ('w_137', 0.0011009079787795896), ('w_587', 0.0010960555870009583), ('w_487', 0.0010901155644644765), ('w_772', 0.0010568444601957965), ('w_14', 0.0010252617867209932), ('w_775', 0.0009927093951972604), ('w_318', 0.0008723977982126373)]
#
#
# 8224 Rule_Learning [('Samelink(8224,31489)', 0.9746911580276036), ('w_818', 0.003126310779797002), ('w_426', 0.0021606178693275783), ('w_206', 0.0019055402495676292), ('w_704', 0.0015680865427531803), ('w_815', 0.0014464174335146796), ('w_875', 0.0013141972930163946), ('w_332', 0.0012982823701085198), ('w_661', 0.0012445737493792567), ('w_221', 0.0011792610256233205), ('w_1204', 0.0010602983579587903), ('w_764', 0.0010532642531720646), ('w_1206', 0.001016538203175731), ('w_1250', 0.0009032740489692334), ('w_1349', 0.0008951889736765945), ('w_1382', 0.0008663913769480141), ('w_465', 0.0008542765037643011), ('w_399', 0.0007737169420052737), ('w_26', 0.0007618956605696819), ('w_94', 0.000726580367498689), ('w_506', 0.0005937826430813359), ('w_1248', 0.0005603473284893854)]
#
#
# 575077 Genetic_Algorithms [('Samelink(575077,31489)', 0.9594064621246912), ('w_368', 0.004850610255653371), ('w_631', 0.004035706586509691), ('w_1003', 0.003967458801735851), ('w_1423', 0.0036606917800732497), ('w_180', 0.0028496972928606576), ('w_1229', 0.0027335917977160287), ('w_1252', 0.0023955733794935614), ('w_360', 0.002371804164994665), ('w_1340', 0.00203739462949225), ('w_813', 0.0019961609250215076), ('w_1179', 0.0017142171956798919), ('w_1231', 0.0015686781439854323), ('w_119', 0.001351051807519018), ('w_1133', 0.0011771678827466724), ('w_1145', 0.0010332233834685445), ('w_929', 0.0007938110457527093), ('w_1317', 0.0007771370081952482), ('w_496', 0.0006764360565352181), ('w_1050', 0.0006031257378750955)]
#
#
# 9708 Genetic_Algorithms [('Samelink(9708,31489)', 0.9623445054302733), ('w_407', 0.004857794595156976), ('w_1337', 0.003967360780203542), ('w_698', 0.003027630799913116), ('w_661', 0.00273173565834011), ('w_1329', 0.0022460618476954682), ('w_1264', 0.002124687499775964), ('w_226', 0.002043906481984259), ('w_188', 0.002035306547188911), ('w_1250', 0.0019826112595201354), ('w_811', 0.001950002137247753), ('w_620', 0.001613549584655505), ('w_1425', 0.001498735402872996), ('w_55', 0.0014189869174197288), ('w_1248', 0.0012299156872411419), ('w_938', 0.001210194736522554), ('w_1145', 0.0009965264234636864), ('w_317', 0.0007145258999853467), ('w_613', 0.0006823463813835119), ('w_422', 0.0006773867681171053), ('w_634', 0.0006462291610390246)]
#
#
# 38205 Genetic_Algorithms [('Samelink(38205,31489)', 0.987912781943936), ('w_1167', 0.0020761985162421745), ('w_861', 0.0018710336342828645), ('w_1382', 0.0017872084029714292), ('w_234', 0.001554142261032046), ('w_1263', 0.0011828954515080627), ('w_938', 0.0011373609185306181), ('w_931', 0.000665932059023858), ('w_300', 0.0006401996494982793), ('w_1036', 0.0005955583866382118), ('w_795', 0.0005766887763365612)]
#
#
# 6898 Neural_Networks [('Samelink(6898,31489)', 0.9959325640271867), ('w_704', 0.0014117471938902071), ('w_1411', 0.0009152313472516828), ('w_1255', 0.0006375821904208262), ('w_1242', 0.0002990058055983535), ('w_1102', 0.00027836147380729844), ('w_163', 0.0002639327734418817), ('w_534', 0.00026157518840319203)]
#
#
# 3229 Neural_Networks [('Samelink(3229,31489)', 0.9968297246061688), ('w_147', 0.0012896422703967641), ('w_1349', 0.0008790225670640804), ('w_620', 0.0007218543557096701), ('w_775', 0.000279756200660559)]
#
#
# 3231 Theory [('Samelink(3231,31489)', 0.9801189340339466), ('w_1328', 0.0019204310387629057), ('w_818', 0.001908687330750414), ('w_876', 0.0013233694665027189), ('w_1334', 0.0012320032575382312), ('w_1337', 0.00110353548637772), ('w_1355', 0.001074287740327491), ('w_941', 0.0010664506144081956), ('w_223', 0.0010326428820178243), ('w_1361', 0.000924356985944591), ('w_815', 0.0008830723574145948), ('w_1153', 0.0007542999566763458), ('w_531', 0.0007459392611174899), ('w_716', 0.0007217905281718314), ('w_589', 0.0007115711457456039), ('w_1262', 0.0006685019882321121), ('w_764', 0.000643042959437434), ('w_417', 0.0006273953181920825), ('w_1354', 0.0006082875344116857), ('w_1264', 0.0005909893713638111), ('w_508', 0.0005442203773368457), ('w_1179', 0.0004598805554617014), ('w_229', 0.0003363098098614425)]
#
#
# 12182 Theory [('Samelink(12182,31489)', 0.9691167812847613), ('w_260', 0.0032546971179429622), ('w_1316', 0.0031562437300045824), ('w_238', 0.002280642945406522), ('w_4', 0.0017877020285311134), ('w_1423', 0.001650777801931881), ('w_134', 0.0015039301255657179), ('w_1315', 0.0014048778462363218), ('w_1377', 0.0012973053350164613), ('w_180', 0.0012850623095030465), ('w_1427', 0.0011648213342241973), ('w_1092', 0.0011325802501670505), ('w_360', 0.0010695578599147805), ('w_1329', 0.0010501529935334857), ('w_1208', 0.0010304796603178104), ('w_1077', 0.001004946863343874), ('w_725', 0.0009615049137055827), ('w_1356', 0.0009232426007184403), ('w_508', 0.0009147892562181638), ('w_1302', 0.0008841119009031338), ('w_1326', 0.0008703046992421492), ('w_522', 0.0008447744689719006), ('w_53', 0.0007960042709378648), ('w_251', 0.0006147084029014281)]
#
#
# 6125 Theory [('Samelink(6125,31489)', 0.9893825152314784), ('w_828', 0.0010932786359041332), ('w_962', 0.0007600871433333453), ('w_1337', 0.0006216267243227902), ('w_1115', 0.0006215608248078157), ('w_730', 0.0006159964332030146), ('w_346', 0.0005925780381044414), ('w_970', 0.0005608633125608341), ('w_726', 0.0004474449057917866), ('w_785', 0.00043954590933372237), ('w_339', 0.00043859244185478834), ('w_1258', 0.00041303102024686724), ('w_1309', 0.00039982639453925087), ('w_1092', 0.0003795474705847412), ('w_1204', 0.0003646482260504236), ('w_40', 0.0003594961155184559), ('w_1329', 0.00035192465378399394), ('w_1064', 0.00034576977080566035), ('w_1077', 0.0003367752881069386), ('w_1264', 0.0003329070895910684), ('w_1356', 0.0003093947592562007), ('w_508', 0.0003065618955164453), ('w_1353', 0.00027320837307445744), ('w_620', 0.00025281934223041365)]
#
#
# 6151 Reinforcement_Learning [('Samelink(6151,31489)', 0.966334201839322), ('w_962', 0.006269806877469698), ('w_1333', 0.0028511197399991345), ('w_1208', 0.0028485727713512586), ('w_1264', 0.002746084022317303), ('w_325', 0.0024785655519755207), ('w_1199', 0.002017267680832147), ('w_1152', 0.0016822911969750025), ('w_396', 0.0016657315411892318), ('w_229', 0.0015626930705671736), ('w_820', 0.0015389149315204757), ('w_1061', 0.0014257545348362914), ('w_1175', 0.001163630127439945), ('w_1172', 0.001146171714531276), ('w_1076', 0.0009780545812527958), ('w_569', 0.0008600453832711317), ('w_394', 0.0008312730897385765), ('w_1296', 0.0008210799646566526), ('w_87', 0.0007787413807545515)]
#
#
# 23070 Probabilistic_Methods [('Samelink(23070,31489)', 0.9671982702012275), ('w_98', 0.00286130826550496), ('w_936', 0.002808153155467702), ('w_1329', 0.002445506138114711), ('w_1333', 0.0024018381840784377), ('w_1213', 0.002384830618602483), ('w_1260', 0.002370820463391799), ('w_90', 0.0022471379683629816), ('w_1022', 0.002119296902726114), ('w_1331', 0.002085164750013473), ('w_403', 0.0020675666988912277), ('w_1139', 0.0016214911420757473), ('w_1287', 0.0008023692703164876), ('w_193', 0.0008001803198843831), ('w_1230', 0.0007807847840895762), ('w_39', 0.0007643504550222395), ('w_500', 0.0007523392138962398), ('w_760', 0.0007515477933755554), ('w_1398', 0.0007491310911412877), ('w_1396', 0.0007414780389001128), ('w_666', 0.0007280411395227728), ('w_52', 0.0005183934053942049)]
#
#
# 6184 Reinforcement_Learning [('Samelink(6184,31489)', 0.9714799517132621), ('w_1361', 0.0029870939915554217), ('w_531', 0.002410530475595832), ('w_1329', 0.0020189031186737035), ('w_624', 0.001993122305496567), ('w_835', 0.0019450817194619466), ('w_1264', 0.0019098041418164563), ('w_188', 0.0018294628617607995), ('w_58', 0.0017575457314005513), ('w_1178', 0.0017012034342010767), ('w_1210', 0.0016626136736342715), ('w_837', 0.0013960975904980123), ('w_912', 0.0008422905045655099), ('w_1076', 0.0006802023080935864), ('w_166', 0.0006473989689171168), ('w_778', 0.0006452670372418589), ('w_733', 0.0006435203504774111), ('w_787', 0.0006391966872668711), ('w_1116', 0.0006305888057401109), ('w_511', 0.0005731725742629059), ('w_1296', 0.0005710320239730066), ('w_1273', 0.0005696369302392265), ('w_2', 0.0004662830518660526)]
#
#
# 10796 Case_Based [('Samelink(10796,31489)', 0.9781667284173636), ('w_206', 0.002763324158170101), ('w_815', 0.0020975260101361902), ('w_875', 0.0019057866288670418), ('w_1204', 0.0015375944266096846), ('w_764', 0.001527393901224472), ('w_9', 0.0014634468632150107), ('w_1264', 0.0014037531214077413), ('w_1250', 0.0013098852157707828), ('w_508', 0.0012926646238279134), ('w_1178', 0.0012504264592483212), ('w_1248', 0.0008125891385039679), ('w_296', 0.0004962989499079969), ('w_1294', 0.0004902072007248324), ('w_187', 0.0004720669466570795), ('w_248', 0.00047108609868628723), ('w_787', 0.0004698253215070217), ('w_1238', 0.00046909486218934697), ('w_302', 0.0004526858740567252), ('w_494', 0.0004342561758471764), ('w_169', 0.0003916963628983265), ('w_604', 0.00032166324318041734)]
#
#
# 6196 Reinforcement_Learning [('Samelink(6196,31489)', 0.9737310096793486), ('w_259', 0.004080206453029025), ('w_1380', 0.0024164086890388473), ('w_1264', 0.0022907991552601876), ('w_1360', 0.0022039683709376614), ('w_781', 0.002192012976417792), ('w_508', 0.002109512693606739), ('w_809', 0.001971158644132598), ('w_60', 0.0018150241901678814), ('w_517', 0.0008252963231290968), ('w_1046', 0.0007575839374751463), ('w_582', 0.0007570845342469961), ('w_1065', 0.0007431214829127354), ('w_766', 0.0007177033555595197), ('w_1048', 0.0007083477985125344), ('w_625', 0.0006979360709533136), ('w_14', 0.000696333109814372), ('w_762', 0.0006921681560369526), ('w_1041', 0.0005943243794202425)]
#
#
# 93555 Neural_Networks [('Samelink(93555,31489)', 0.8012441973703046), ('w_873', 0.027036343845115884), ('w_537', 0.02376436317710921), ('w_133', 0.017680611388904137), ('w_1206', 0.016100084651947597), ('w_1260', 0.01571223768962482), ('w_1234', 0.014911387286413351), ('w_506', 0.009404418632374848), ('w_1263', 0.00908217236847733), ('w_912', 0.006761679106301151), ('w_20', 0.00567690346125393), ('w_610', 0.005605455794112062), ('w_1076', 0.0054604791455731124), ('w_193', 0.00530306852615761), ('w_857', 0.004984143559476856), ('w_1037', 0.004844097185627558), ('w_394', 0.00464099801565205), ('w_511', 0.004601273549554667), ('w_386', 0.004559907320314889), ('w_775', 0.004512309448263058), ('w_257', 0.004355160411049759), ('w_891', 0.003758708066391699)]
#
#
# 17208 Reinforcement_Learning [('Samelink(17208,31489)', 0.9764236919992346), ('w_875', 0.001803213864975038), ('w_70', 0.0016720843772626548), ('w_337', 0.0014737449843075434), ('w_1119', 0.0014184637741156746), ('w_1333', 0.0013790033878659336), ('w_127', 0.0013326223150776494), ('w_1340', 0.0012283959729244961), ('w_1382', 0.0011887780866004143), ('w_465', 0.0011721552344507614), ('w_1210', 0.001156288521579976), ('w_1259', 0.001077941601445243), ('w_916', 0.0010483555406039582), ('w_724', 0.0010144531819845325), ('w_94', 0.000996943000609232), ('w_285', 0.0008242882789270717), ('w_506', 0.0008147308630717382), ('w_649', 0.0007146312440893554), ('w_100', 0.0007072317200460919), ('w_1230', 0.00044828368105356706), ('w_150', 0.0004424640171265494), ('w_1350', 0.0004363127291322366), ('w_59', 0.0004224748017196483), ('w_595', 0.00040969848504309386), ('w_830', 0.0003937483367528947)]
#
#
# 6910 Neural_Networks [('Samelink(6910,31489)', 0.9981349915305948), ('w_1274', 0.0005011842457613757), ('w_1333', 0.00048601238730588606), ('w_1390', 0.00028396421996628655), ('w_1242', 0.0001606058612047449), ('w_821', 0.0001603861530824729), ('w_534', 0.00014050064452500848), ('w_172', 0.00013235495755949277)]
#
#
# 887 Reinforcement_Learning [('Samelink(887,31489)', 0.9964957963954165), ('w_1198', 0.0009330064420925231), ('w_764', 0.0007979561481710653), ('w_1333', 0.0007614130987476461), ('w_1264', 0.0007333625156180402), ('w_957', 0.0002784653999541154)]
#
#
# 45605 Genetic_Algorithms [('Samelink(45605,31489)', 0.997723075554487), ('w_1264', 0.00115005474399438), ('w_20', 0.0004258420464748005), ('w_369', 0.0003625453991995956), ('w_775', 0.0003384822558443658)]
#
#
# ...
#
#
# 78557 Neural_Networks [('Samelink(78557,31489)', 0.9979828959112801), ('w_1210', 0.0005130942998961384), ('w_620', 0.000447591598510932), ('w_699', 0.0003928851556932445), ('w_1390', 0.0003575300846219191), ('w_1061', 0.0003060029499976752)]
#
#
# 5064 Case_Based [('Samelink(5064,31489)', 0.9830948176643877), ('w_1334', 0.00221133123297186), ('w_1153', 0.0013538982490685204), ('w_702', 0.0013104719796554875), ('w_127', 0.0010643022938041041), ('w_964', 0.0010202869033323055), ('w_923', 0.0009692912440350815), ('w_1300', 0.0009554689225982981), ('w_1178', 0.0009449069298893533), ('w_1210', 0.0009234728489033427), ('w_1353', 0.0008705477058125813), ('w_378', 0.0008278215198744531), ('w_1231', 0.0007553617503405602), ('w_1263', 0.0006283908777393263), ('w_5', 0.0005033566184781182), ('w_759', 0.0004955449325780955), ('w_1172', 0.000442748888488773), ('w_1052', 0.0003689505996828028), ('w_429', 0.00036533132816849156), ('w_751', 0.0003313257076930931), ('w_41', 0.0003157196178482821), ('w_327', 0.0002466521846490682)]
#
#
# 31489 Probabilistic_Methods [('w_1229', 0.08375351415345529), ('w_972', 0.07949821972083529), ('w_133', 0.07783691995910769), ('w_443', 0.07491747790103832), ('w_412', 0.07457335940841278), ('w_435', 0.07428313325473838), ('w_1293', 0.0681404387023179), ('w_1382', 0.060409736249618824), ('w_541', 0.058569810168500734), ('w_26', 0.05312370036146525), ('w_379', 0.051725065346674204), ('w_195', 0.0432941133074895), ('w_912', 0.02976753822645692), ('w_366', 0.023321352839542293), ('w_570', 0.023242185009729376), ('w_1118', 0.021628708555794098), ('w_752', 0.0210756349522525), ('w_675', 0.02102958134560523), ('w_446', 0.020262696548659975), ('w_534', 0.020258274884764893), ('w_484', 0.01928853910354073)]
#
#
# 714256 Probabilistic_Methods [('Samelink(714256,31489)', 0.963703386255634), ('w_1258', 0.005121958466645994), ('w_40', 0.00445807719600709), ('w_1176', 0.004092453286716735), ('w_916', 0.003258526999226094), ('w_94', 0.0030987251541620678), ('w_946', 0.002606867159668513), ('w_1180', 0.0021203777216295626), ('w_814', 0.0014694152165177225), ('w_1424', 0.0014008065470085122), ('w_1418', 0.001387008325107051), ('w_59', 0.001313147586460103), ('w_130', 0.0012688908218082711), ('w_288', 0.0012190800664513312), ('w_1195', 0.0011802773849514852), ('w_87', 0.0011707276026141087), ('w_1050', 0.0011302742093913974)]
#
#
# 642894 Probabilistic_Methods [('Samelink(642894,31489)', 0.9479990938527988), ('w_380', 0.004789491133308569), ('w_1305', 0.004741517240109397), ('w_1012', 0.004582780174572193), ('w_933', 0.004501134099049087), ('w_279', 0.0037853256880190683), ('w_1349', 0.0033549974888241914), ('w_508', 0.0033407934971771847), ('w_648', 0.003223738061301141), ('w_1199', 0.002665042948420791), ('w_132', 0.0026389460095779752), ('w_1098', 0.0024717422248739817), ('w_649', 0.0019519685020427903), ('w_759', 0.0016947901378286288), ('w_822', 0.0014327236464886151), ('w_510', 0.0012333110015627909), ('w_984', 0.0012200611870867332), ('w_59', 0.0011539622885008004), ('w_598', 0.0011055773941216632), ('w_449', 0.0011015837048037528), ('w_186', 0.0010114197195317757)]
#
#
# 54131 Genetic_Algorithms [('Samelink(54131,31489)', 0.9897052224853814), ('w_263', 0.0013136794616054098), ('w_1285', 0.0011709254294476968), ('w_1262', 0.0007336055840266961), ('w_64', 0.0006657992890484354), ('w_1094', 0.0005982461593310714), ('w_1178', 0.0005777061826716298), ('w_235', 0.0005733742445132852), ('w_809', 0.0005580513461931212), ('w_1207', 0.0005475002219462896), ('w_1073', 0.0005445261714698589), ('w_515', 0.00047486948861687195), ('w_42', 0.0004195958677365478), ('w_1133', 0.00034655927757596945), ('w_1175', 0.00027481518825525473), ('w_463', 0.0002305576753181252), ('w_1241', 0.00022968705728921004), ('w_304', 0.00022345911931567327), ('w_1158', 0.0002155675746303164), ('w_1017', 0.00020252152414495294), ('w_496', 0.00019914338006929072), ('w_807', 0.0001945872714123973)]
#
#
# 33818 Neural_Networks [('Samelink(33818,31489)', 0.9953573176420575), ('w_1064', 0.0005535872079781975), ('w_508', 0.0004908142878309554), ('w_1210', 0.0004640070563074051), ('w_1080', 0.0003802952713188861), ('w_699', 0.00035529820658113093), ('w_119', 0.00032688395239130713), ('w_1390', 0.000323325521527593), ('w_100', 0.0002838050386398412), ('w_1061', 0.00027672793885752536), ('w_912', 0.00023506888207217562), ('w_408', 0.00017105491793028887), ('w_551', 0.00016978574510975316), ('w_549', 0.00016694833803702823), ('w_424', 0.00016460030101803715), ('w_1053', 0.00015034806300914648), ('w_2', 0.00013013162933363018)]
#
#
# 235679 Rule_Learning [('Samelink(235679,31489)', 0.9832498234061048), ('w_456', 0.0019690846022478803), ('w_674', 0.0016607896747922487), ('w_702', 0.0013890060099224638), ('w_1124', 0.0013735324649632105), ('w_1380', 0.0011859909474540354), ('w_28', 0.0010833380298034638), ('w_1302', 0.0010006433410277768), ('w_379', 0.0008616466455031857), ('w_1199', 0.0008259384970002647), ('w_418', 0.0008075779821972292), ('w_1171', 0.000778408082317045), ('w_331', 0.0007467343006877278), ('w_579', 0.00037314552422062206), ('w_1393', 0.000366096594420205), ('w_1156', 0.0003538873570233887), ('w_944', 0.0003505204510181163), ('w_1247', 0.0003504123335996817), ('w_1057', 0.0003469930110761899), ('w_498', 0.00033329674559176846), ('w_1050', 0.00030782606540839374), ('w_1388', 0.0002853079336201265)]
#
#
# 22229 Genetic_Algorithms [('Samelink(22229,31489)', 0.9869045694201379), ('w_815', 0.001339406928832428), ('w_133', 0.0010337409429380152), ('w_40', 0.00096798154931539), ('w_1264', 0.000896387767349592), ('w_1178', 0.0007984787103564242), ('w_980', 0.0007895518855319522), ('w_1210', 0.0007803661779979316), ('w_7', 0.0006878416953168203), ('w_506', 0.0005498527381760171), ('w_62', 0.0005329937441504679), ('w_1133', 0.00047899817125239753), ('w_84', 0.0003219387399469692), ('w_122', 0.0003063494568243158), ('w_1407', 0.00030477855649012846), ('w_39', 0.0002961735974695537), ('w_538', 0.00029509631731832055), ('w_155', 0.00028773230545784626), ('w_300', 0.0002873910565937444), ('w_1307', 0.0002873055509877038), ('w_651', 0.0002791207799168724), ('w_625', 0.0002731017928647392), ('w_762', 0.0002708448126479152), ('w_511', 0.0002690249083138297), ('w_1055', 0.0002661557801212619), ('w_1195', 0.0002562734294351233), ('w_780', 0.00023854318425573252)]
#
#
# 671269 Neural_Networks [('Samelink(671269,31489)', 0.9868666700210612), ('w_275', 0.001655595736639062), ('w_475', 0.0014154671443557683), ('w_624', 0.0012065500997385252), ('w_1382', 0.0010347545262418354), ('w_1178', 0.0010298350319748433), ('w_648', 0.001027319389862077), ('w_53', 0.0009263811566552238), ('w_378', 0.000902226001759982), ('w_1171', 0.000800404604266144), ('w_1072', 0.0006245850286584072), ('w_1186', 0.0004382337379721546), ('w_1074', 0.0003795581447469021), ('w_59', 0.0003677370219303769), ('w_394', 0.00034996945533464385), ('w_641', 0.0003440120318514386), ('w_590', 0.00032304065685540077), ('w_780', 0.0003076602100959282)]
#
#
# 36802 Probabilistic_Methods [('Samelink(36802,31489)', 0.9837833122691629), ('w_1414', 0.0018291705474573533), ('w_1315', 0.001623247810884374), ('w_1132', 0.0011713574371839991), ('w_1176', 0.0011378355351802235), ('w_1178', 0.0010224441826797673), ('w_1210', 0.0009992512620629192), ('w_541', 0.0009960385760495914), ('w_916', 0.000905976819356243), ('w_1255', 0.000839739210989268), ('w_1306', 0.0007984324223920229), ('w_293', 0.0005846336081351674), ('w_1172', 0.0004790800142362037), ('w_897', 0.0004301277629860611), ('w_20', 0.00042501300073139223), ('w_1076', 0.00040880995122270374), ('w_1256', 0.00040287911014756265), ('w_304', 0.0003954856005772053), ('w_597', 0.000387766674971284), ('w_1230', 0.0003874016092825195), ('w_586', 0.0003721223349003008), ('w_1037', 0.0003626632537878856), ('w_52', 0.00025721100562344016)]
#
#
# 12195 Theory [('Samelink(12195,31489)', 0.969720022440202), ('w_1316', 0.0033751845291646754), ('w_439', 0.002685424152908015), ('w_368', 0.002339100198872456), ('w_730', 0.0019656585018736025), ('w_631', 0.0019461308127350575), ('w_922', 0.0018782415272959882), ('w_719', 0.0018696322236759948), ('w_572', 0.001592620989350391), ('w_281', 0.0014036877542309516), ('w_459', 0.0013596288445296633), ('w_702', 0.001312378300027768), ('w_716', 0.0012974314583322007), ('w_472', 0.0011427834127914552), ('w_1111', 0.0011163151800357078), ('w_1132', 0.0010841020521845336), ('w_1264', 0.001062314026050562), ('w_508', 0.0009782459179821085), ('w_1178', 0.0009462814692601458), ('w_1210', 0.0009248162084962544)]
#
#
# 20924 Probabilistic_Methods [('Samelink(20924,31489)', 0.9807681253334608), ('w_281', 0.0015563020216944477), ('w_475', 0.0014420351210865485), ('w_589', 0.0014181264092915345), ('w_1335', 0.0013038609273739387), ('w_1026', 0.0012513694944629482), ('w_1176', 0.0011675717825448825), ('w_508', 0.0010846045320841383), ('w_1302', 0.0010482324405003453), ('w_235', 0.0010412976096984149), ('w_786', 0.0010031222829245971), ('w_1259', 0.0009558897877582229), ('w_1255', 0.0008616849950043763), ('w_1139', 0.0008255602187900967), ('w_1263', 0.0006977254167053034), ('w_5', 0.0005588952972113429), ('w_759', 0.0005502216961250692), ('w_912', 0.0005194567093271843), ('w_1076', 0.0004194938097056144), ('w_1284', 0.00039146231712914995), ('w_441', 0.0003835711231617555), ('w_1393', 0.0003835076004541202), ('w_751', 0.00036788307350515097)]
#
#
# 36140 Neural_Networks [('Samelink(36140,31489)', 0.8991168867393912), ('w_407', 0.007866957784344781), ('w_730', 0.006366751343551823), ('w_970', 0.005796912216241288), ('w_1414', 0.0054833345843382925), ('w_1157', 0.005454745663728947), ('w_815', 0.0051413758719569685), ('w_27', 0.004738778530077374), ('w_726', 0.004624654140126171), ('w_212', 0.004168548425648702), ('w_1309', 0.004132483724595369), ('w_133', 0.003968062750361129), ('w_1262', 0.003892115933415173), ('w_435', 0.0037868936001462313), ('w_1204', 0.0037688928993606405), ('w_1252', 0.0037417239441908216), ('w_360', 0.0037045980353013473), ('w_1329', 0.0036373859352685747), ('w_1333', 0.003572435289936747), ('w_1264', 0.0034408261893836708), ('w_1148', 0.0033233419345920297), ('w_1382', 0.003079639126229383), ('w_761', 0.0028825634796408226), ('w_418', 0.0024714350710709826), ('w_1133', 0.0018386567871015518)]
#
#
# 6923 Rule_Learning [('Samelink(6923,31489)', 0.9450198743421913), ('w_480', 0.00716197894606152), ('w_306', 0.005092765024168725), ('w_1020', 0.005063406675675993), ('w_815', 0.0042662057907696576), ('w_726', 0.003837440942710806), ('w_48', 0.0036367711690073975), ('w_1058', 0.002872448983927905), ('w_1264', 0.0028551253555000483), ('w_1349', 0.002640358374312608), ('w_1094', 0.002633695153209267), ('w_1022', 0.002615621359021506), ('w_697', 0.0018433720603434117), ('w_676', 0.001822353446649333), ('w_1133', 0.0015256788119995723), ('w_1076', 0.001016891111598761), ('w_988', 0.0009568546265787622), ('w_1006', 0.0008994472925422454), ('w_1059', 0.0008928536224905657), ('w_654', 0.0008889521377588325), ('w_909', 0.000842372895636155), ('w_614', 0.0008329378151826687), ('w_784', 0.0007825940626630689)]
#
#
# 6925 Theory [('Samelink(6925,31489)', 0.9719467211896525), ('w_970', 0.0026856303929351693), ('w_537', 0.0024709101470251), ('w_726', 0.002142539209191181), ('w_716', 0.0019469005271080095), ('w_476', 0.0018323950433519044), ('w_1119', 0.001702420365359133), ('w_1206', 0.0016740134056182025), ('w_616', 0.0016395032791767681), ('w_1132', 0.0016267825504632746), ('w_188', 0.001527028073146432), ('w_1178', 0.0014199716520388271), ('w_916', 0.0012582216444504827), ('w_1385', 0.0011968763462312671), ('w_129', 0.0010182828186788937), ('w_1387', 0.0009465911467592523), ('w_1263', 0.0009443228793910168), ('w_1074', 0.000523347710174047), ('w_471', 0.0005232454571259588), ('w_723', 0.0005138652540345605), ('w_1384', 0.0004604309080882153)]
#
#
# 2696 Neural_Networks [('Samelink(2696,31489)', 0.969532458667854), ('w_537', 0.00418772033715629), ('w_133', 0.0031156507470812716), ('w_1264', 0.0027016741825855416), ('w_1349', 0.0024984500378984445), ('w_1178', 0.0024065804952833865), ('w_1207', 0.0022807499639452464), ('w_913', 0.001946236367491229), ('w_699', 0.001800959389860175), ('w_1121', 0.0009285690676493853), ('w_858', 0.000922662691942471), ('w_76', 0.0009180152797541686), ('w_878', 0.0008948614826823539), ('w_137', 0.0008818185952173705), ('w_1118', 0.0008657524219312068), ('w_59', 0.0008593500093642787), ('w_965', 0.0008421786810284145), ('w_108', 0.0008113435267878917), ('w_1296', 0.0008078014089602424), ('w_983', 0.0007971666455264533)]
#
#
# 2698 Neural_Networks [('Samelink(2698,31489)', 0.9629119508478102), ('w_1361', 0.005613888118729833), ('w_1297', 0.004751467355005765), ('w_1427', 0.004208594520804181), ('w_616', 0.0036915072946712125), ('w_913', 0.002585629574843629), ('w_20', 0.0013290267497978758), ('w_1076', 0.001278359390944644), ('w_542', 0.001214648399893543), ('w_1369', 0.0012021943763075985), ('w_565', 0.0012019561035225743), ('w_178', 0.0012018023630631298), ('w_1307', 0.0011504077307420283), ('w_1428', 0.001139290844265547), ('w_1188', 0.001136878087383062), ('w_1224', 0.0010965692195444884), ('w_423', 0.0010921690377316247), ('w_883', 0.0010777126057028232), ('w_68', 0.001059565145323001), ('w_775', 0.0010563822339128995)]
#
#
# 644577 Probabilistic_Methods [('Samelink(644577,31489)', 0.9416599744053185), ('w_531', 0.005414834673807909), ('w_1329', 0.0045351123832405105), ('w_279', 0.00447620692387712), ('w_1148', 0.004143560631049158), ('w_58', 0.003948018771610192), ('w_1178', 0.003821455665453114), ('w_1276', 0.00376881033833533), ('w_1199', 0.003151455034875442), ('w_204', 0.0031075434435442538), ('w_285', 0.0026624216279380318), ('w_152', 0.002580742067951205), ('w_649', 0.002308233331596479), ('w_703', 0.002011325570015782), ('w_822', 0.0016942181558414183), ('w_858', 0.001465113915090791), ('w_510', 0.0014584095793823753), ('w_1415', 0.0014368809777716633), ('w_1428', 0.0013617341127923916), ('w_549', 0.001343759159634337), ('w_174', 0.001292522435392626), ('w_373', 0.0012281225523867567), ('w_1413', 0.0011295442430947055)]
#
#
# 27535 Neural_Networks [('Samelink(27535,31489)', 0.9593184805189956), ('w_860', 0.004086589172704596), ('w_1132', 0.0033450962606414816), ('w_1077', 0.003315954336164765), ('w_1264', 0.003277867308717036), ('w_1176', 0.0032493663105145625), ('w_1382', 0.0029337862068299857), ('w_1178', 0.0029198382181437224), ('w_894', 0.0027655455590240878), ('w_1353', 0.0026900622503070854), ('w_399', 0.0026199707809210445), ('w_370', 0.002390536982724029), ('w_1076', 0.0011674563166949711), ('w_1236', 0.0010817783495754066), ('w_1398', 0.0010614684292685047), ('w_394', 0.0009922503693717782), ('w_1235', 0.0009356993648547678), ('w_87', 0.0009295458162152194), ('w_906', 0.0009187074483313702)]
#
#
# 195792 Genetic_Algorithms [('Samelink(195792,31489)', 0.9870285036801013), ('w_214', 0.0018092777982249585), ('w_704', 0.00166877523014013), ('w_702', 0.0012726558258912386), ('w_508', 0.0009486368119984241), ('w_1178', 0.0009176398487854947), ('w_465', 0.0009091306061906357), ('w_7', 0.0007904918955160807), ('w_987', 0.0007266369376760157), ('w_100', 0.0005485331494202857), ('w_1323', 0.0004251550047463301), ('w_20', 0.0003814475864108624), ('w_1321', 0.0003437398811554222), ('w_1416', 0.00034195146601445495), ('w_262', 0.0003311739268679883), ('w_141', 0.0003310989544004652), ('w_496', 0.0003163232567952062), ('w_775', 0.0003031951414933324), ('w_667', 0.00030315943384596783), ('w_1357', 0.00030247356432536453)]

# %%
#Cora MLN
def cora_mln():
                                pid=[]
                                cl=[]
                                words={}
                                label={}
                                ln1=[]
                                ln2=[]
                                f1=open("content.txt")
                                for j in f1:
                                    wrds=[]
                                    p=j.strip("\n").split()
                                    for j in range(1,len(p)-1):
                                        if int(p[j])==1:
                                            ss="w_"+str(j)
                                            wrds.append(ss)
                                    words[p[0]]=wrds
                                    label[p[0]]=p[-1]
                                   # print(len(wrds))
                                f1.close()
                                f1=open("link.txt")
                                for z in f1:
                                    p=z.strip("\n").split()
                                    ln1.append(p[0])
                                    ln2.append(p[1])
                                f1.close()
                                linked={}
                                for t in words:
                                    zzv=[]
                                    for hh in range(0,len(ln1)):
                                        if int(t)==int(ln1[hh]):
                                            if ln2[hh] not in zzv:
                                                        zzv.append(ln2[hh])
                                    if len(zzv)>0:
                                          linked[t]=zzv
                                for x in linked:
                                    pass#print(x,linked[x]) Neural_Networks Neural_Networks
                                WORDS={}
                                samelink={}
                                c1=0
                                c2=0
                                c3=0
                                c4=0
                                c5=0
                                c6=0
                                c7=0
                                #c2=0
                                lb=300
                                for x in words:
                                    if x in linked:
                                                if label[x]=='Neural_Networks':
                                                     if c1<lb:
                                                        if len(linked[x])>=5:
                                                            WORDS[x]=words[x]
                                                            samelink[x]=linked[x]
                                                            c1=c1+1
                                                elif label[x]=='Probabilistic_Methods':
                                                      if c2<lb:
                                                            if len(linked[x])>=5:
                                                                WORDS[x]=words[x]
                                                                samelink[x]=linked[x]
                                                                c2=c2+1
                                                elif label[x]=='Genetic_Algorithms':
                                                      if c3<lb:
                                                            if len(linked[x])>=5:
                                                                WORDS[x]=words[x]
                                                                samelink[x]=linked[x]
                                                                c3=c3+1
                                                elif label[x]=='Theory':
                                                      if c4<lb:
                                                            if len(linked[x])>=5:
                                                                WORDS[x]=words[x]
                                                                samelink[x]=linked[x]
                                                                c4=c4+1
                                                elif label[x]=='Case_Based':
                                                      if c5<80:
                                                            if len(linked[x])>=5:
                                                                WORDS[x]=words[x]
                                                                samelink[x]=linked[x]
                                                                c5=c5+1
                                                elif label[x]=='Reinforcement_Learning':
                                                      if c6<80:
                                                            if len(linked[x])>=5:
                                                                WORDS[x]=words[x]
                                                                samelink[x]=linked[x]
                                                                c6=c6+1
                                                elif label[x]=='Rule_Learning':
                                                      if c7<80:
                                                            if len(linked[x])>=5:
                                                                WORDS[x]=words[x]
                                                                samelink[x]=linked[x]
                                                                c7=c7+1
                                # Data Type

                                d_tt={}
                                #margs2={}
                                d_tt[0]="Neural_Networks"
                                d_tt[1]="Probabilistic_Methods"
                                d_tt[2]="Genetic_Algorithms"
                                d_tt[3]="Theory"
                                d_tt[4]="Case_Based"
                                d_tt[5]="Reinforcement_Learning"
                                d_tt[6]="Rule_Learning"
                                #d_tt[7]="Probabilistic_Methods"
                                #train and target data
                                w11=[]
                                trg=[]
                                w12=[]
                                trg1=[]
                                for tt in WORDS:
                                    s=' '
                                    #if qrat[tt]!=1:
                                    for kk in WORDS[tt]:
                                        #if qrat[tt]!=1:
                                            w11.append(kk)
                                            s=str(kk)+s+"\t"
                                            #print(kk)
                                            trg.append(label[tt])
                                        #w12.append(s)
                                        #trg1.append(qrat[tt])
                                #SVM Learner
                                from sklearn.feature_extraction.text import TfidfVectorizer
                                from sklearn import svm
                                #from sklearn import cross_validation
                                from sklearn.model_selection import cross_validate
                                from sklearn.preprocessing import MinMaxScaler
                                from sklearn.metrics import (precision_score,recall_score,f1_score)
                                from sklearn.feature_extraction.text import TfidfVectorizer
                                from collections import defaultdict
                                from sklearn import svm
                                #from sklearn import cross_validation
                                from sklearn.model_selection import cross_validate
                                from sklearn.preprocessing import MinMaxScaler
                                from sklearn.metrics import (precision_score,recall_score,f1_score)
                                from sklearn.multiclass import OneVsRestClassifier
                                from sklearn.svm import SVC
                                from sklearn.svm import LinearSVC
                                from sklearn.multiclass import OneVsOneClassifier
                                from sklearn.multiclass import OutputCodeClassifier

                                #OutputCodeClassifier(LinearSVC(random_state=0),code_size=2, random_state=0)

                                #Learn SVM Model
                                #ifile = open("processed_revs_1.txt",encoding="ISO-8859-1")
                                Y = trg
                                words =w11
                                unique_words = []

                                ss=set(words)
                                for w1 in ss:
                                        if w1 not in unique_words:
                                            unique_words.append(w1)

                                #######
                                #tf_transformer = TfidfVectorizer()
                                #f = tf_transformer.fit_transform(words)
                                #features = [((i, j), f[i,j]) for i, j in zip(*f.nonzero())]
                                #unique_word_ids = []
                                #for w in unique_words:
                                   # i = tf_transformer.vocabulary_.get(w)
                                    #unique_word_ids.append(i)

                                #clf =OneVsRestClassifier(SVC(kernel='linear'))#svm.LinearSVC(C=1)
                                #clf.fit(f,Y)
                                #p = clf.predict(f)
                                #print(f1_score(Y,p,average='weighted'))




                                #########
                                tf_transformer = TfidfVectorizer()
                                f = tf_transformer.fit_transform(words)
                                features = [((i, j), f[i,j]) for i, j in zip(*f.nonzero())]
                                unique_word_ids = []
                                for w in unique_words:
                                    i = tf_transformer.vocabulary_.get(w)
                                    unique_word_ids.append(i)

                                clf =svm.LinearSVC(C=100)#svm.SVC(C=1.0, kernel='linear', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=- 1, decision_function_shape='ovr', random_state=None)

                                #OneVsRestClassifier(LinearSVC(random_state=0)) #svm.LinearSVC(C=1)
                                clf.fit(f,Y)
                                #clf.fit(f,Y)
                                p = clf.predict(f)
                                print(f1_score(Y,p,average='micro'))
                                from sklearn.metrics import accuracy_score
                                print(accuracy_score(Y,p))

                                #Store learned weights

                                #Tunable parameter, normalization range of weights
                                rangelower=0
                                rangehigher=1

                                C = clf.coef_
                                scaler = MinMaxScaler(feature_range=(rangelower,rangehigher))
                                vals = []
                                for i, j in zip(*C.nonzero()):
                                    vals.append([C[i,j]])
                                scaler.fit(vals)
                                V1 = scaler.transform(vals)
                                rows,cols = C.nonzero()
                                r_wts =  defaultdict(list)
                                ix= 0
                                for w in unique_words:
                                    r_wts[w] = [0,0,0,0,0,0,0]  
                                for i, j in zip(*C.nonzero()):
                                    #print(i,j)
                                    for k in tf_transformer.vocabulary_.keys():
                                        if tf_transformer.vocabulary_[k]==j:
                                            if k not in r_wts:
                                                break
                                            else:
                                                #if float(V1[ix][0])>0:
                                                r_wts[k][i] = V1[ix][0]
                                                break
                                    ix = ix + 1


                                #print(r_wts)
                                #Sample 2 origin

                                import random
                                from collections import defaultdict

                                #Sampler
                                margs =defaultdict(list)
                                Relational_formula_filter={}
                                iter1=defaultdict(list)
                                users_s= defaultdict(list)
                                expns = defaultdict(dict)
                                Relational_formula_filter={}
                                same_user={}
                                Sample={}
                                Sample_r={}

                                for h in samelink:
                                    for i,r in enumerate(samelink[h]):
                                        if r in WORDS:
                                                Sample[r] = random.randint(0,6)
                                                #Sample_r[r] = random.randint(0,1)
                                                margs[r] = [0]*7
                                                #margs_r[r] = 0
                                                iter1[r] =0

                                #Tunable parameter (default value of prob)
                                C1 = 0.98
                                VR=0.98
                                iters =1000000

                                for t in range(0,iters,1):
                                    h1 = random.choice(list(samelink.keys()))
                                    if len(samelink[h1])==0:
                                        continue
                                    ix1 = random.randint(0,len(samelink[h1])-1)
                                    r33 = samelink[h1][ix1]
                                    if r33 in WORDS:
                                        if random.random()<0.5:
                                            #sample Topic
                                            W0=0
                                            W1=0
                                            W2=0
                                            W3=0
                                            W4=0
                                            W5=0
                                            W6=0


                                            try:
                                                        for w in WORDS[r33]:
                                                            if len(r_wts[w])!=7:
                                                                continue

                                                            W0=W0+r_wts[w][0]
                                                            W1=W1+r_wts[w][1]
                                                            W2=W2+r_wts[w][2]
                                                            W3=W3+r_wts[w][3]
                                                            W4=W4+r_wts[w][4]
                                                            W5=W5+r_wts[w][5]
                                                            W6=W6+r_wts[w][6]
                                                           # W2=W2+(r_wts[w][2])


                                                            if r33 not in expns or w not in expns[r]:
                                                                                     expns[r33][w] = r_wts[w][0]
                                                                                     expns[r33][w] = r_wts[w][1]
                                                                                     expns[r33][w] = r_wts[w][2]
                                                                                     expns[r33][w] = r_wts[w][3]
                                                                                     expns[r33][w] = r_wts[w][4]
                                                                                     expns[r33][w] = r_wts[w][5]
                                                                                     expns[r33][w] = r_wts[w][6]
                                                                                #expns[r][w] = (r_wts[w][2])


                                                            else:
                                                                                 expns[r33][w] =expns[r33][w]+ r_wts[w][0]
                                                                                 expns[r33][w] = expns[r33][w]+r_wts[w][1]
                                                                                 expns[r33][w] = expns[r33][w]+r_wts[w][2]
                                                                                 expns[r33][w] =expns[r33][w]+ r_wts[w][3]
                                                                                 expns[r33][w] =expns[r33][w]+ r_wts[w][4]
                                                                                 expns[r33][w] =expns[r33][w]+ r_wts[w][5]
                                                                                 expns[r33][w] =expns[r33][w]+ r_wts[w][6]
                                            except:
                                                continue



                                            if (W0+W1+W2+W3+W4+W5+W6)!= 0:
                                                W0 = W0/(W0+W1+W2+W3+W4+W5+W6)
                                                W1 = W1/(W0+W1+W2+W3+W4+W5+W6)
                                                W2 = W2/(W0+W1+W2+W3+W4+W5+W6)
                                                W3 = W3/(W0+W1+W2+W3+W4+W5+W6)
                                                W4 = W4/(W0+W1+W2+W3+W4+W5+W6)
                                                W5 = W5/(W0+W1+W2+W3+W4+W5+W6)
                                                W6 = W6/(W0+W1+W2+W3+W4+W5+W6)

                                               # W2=W2/(W0+W1+W2)


                                                sval = random.random()
                                                iter1[r33]=iter1[r33]+1
                                                #print(sval,W14,W15,W16,W17,W18,W19)
                                                if sval<W0:
                                                    print(sval)
                                                    Sample[r33]=0
                                                    #Sample_r[r33]=0
                                                    margs[r33][0]=margs[r33][0]+1
                                                elif sval<(W0+W1):
                                                    #print(sval)
                                                    Sample[r33]=1
                                                    #Sample_r[r33]=1
                                                    margs[r33][1]=margs[r33][1]+1
                                                elif sval<(W0+W1+W2):
                                                    #print(sval)
                                                    Sample[r33]=2
                                                    #Sample_r[r33]=1
                                                    margs[r33][2]=margs[r33][1]+1
                                                elif sval<(W0+W1+W2+W3):
                                                    #print(sval)
                                                    Sample[r33]=3
                                                    #Sample_r[r33]=1
                                                    margs[r33][3]=margs[r33][1]+1
                                                elif sval<(W0+W1+W2+W3+W4):
                                                    #print(sval)
                                                    Sample[r33]=4
                                                    #Sample_r[r33]=1
                                                    margs[r33][4]=margs[r33][1]+1
                                                elif sval<(W0+W1+W2+W3+W4+W5):
                                                    #print(sval)
                                                    Sample[r33]=5
                                                    #Sample_r[r33]=1
                                                    margs[r33][5]=margs[r33][1]+1
                                                elif sval<(W0+W1+W2+W3+W4+W5+W6):
                                                    #print(sval)
                                                    Sample[r33]=6
                                                    #Sample_r[r33]=1
                                                    margs[r33][6]=margs[r33][1]+1



                                                for r1 in samelink[h]:
                                                    if r1==r33:
                                                        continue
                                                    if r33 in WORDS and r1 in WORDS:
                                                            if Sample[r33]!=Sample[r1]:
                                                                if Sample[r1]==0:
                                                                    #W0=W0+r_wts1[w][0]
                                                                    #margs[r][0]=margs[r][0]+1
                                                                    hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                    if r33 not in expns or hhlll not in expns[r33]:
                                                                        expns[r33][hhlll] =C1
                                                                        if r33 not in Relational_formula_filter:
                                                                            Relational_formula_filter[r33]=WORDS[r33]    
                                                                    else:
                                                                        expns[r33][hhlll] = expns[r33][hhlll] + C1
                                                                elif Sample[r1]==1:
                                                                    #W1=W1+r_wts1[w][1]
                                                                   # margs[r][1]=margs[r][1]+1
                                                                    hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                    if r33 not in expns or hhlll not in expns[r33]:
                                                                        expns[r33][hhlll] =C1
                                                                        if r33 not in Relational_formula_filter:
                                                                            Relational_formula_filter[r33]=WORDS[r33]    
                                                                    else:
                                                                        expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                                elif Sample[r1]==2:
                                                                    #W1=W1+r_wts1[w][1]
                                                                   # margs[r][1]=margs[r][1]+1
                                                                    hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                    if r33 not in expns or hhlll not in expns[r33]:
                                                                        expns[r33][hhlll] =C1
                                                                        if r33 not in Relational_formula_filter:
                                                                            Relational_formula_filter[r33]=WORDS[r33]    
                                                                    else:
                                                                        expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                                elif Sample[r1]==3:
                                                                    #W1=W1+r_wts1[w][1]
                                                                   # margs[r][1]=margs[r][1]+1
                                                                    hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                    if r33 not in expns or hhlll not in expns[r33]:
                                                                        expns[r33][hhlll] =C1
                                                                        if r33 not in Relational_formula_filter:
                                                                            Relational_formula_filter[r33]=WORDS[r33]    
                                                                    else:
                                                                        expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                                elif Sample[r1]==4:
                                                                    #W1=W1+r_wts1[w][1]
                                                                   # margs[r][1]=margs[r][1]+1
                                                                    hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                    if r33 not in expns or hhlll not in expns[r33]:
                                                                        expns[r33][hhlll] =C1
                                                                        if r33 not in Relational_formula_filter:
                                                                            Relational_formula_filter[r33]=WORDS[r33]    
                                                                    else:
                                                                        expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                                elif Sample[r1]==5:
                                                                    #W1=W1+r_wts1[w][1]
                                                                   # margs[r][1]=margs[r][1]+1
                                                                    hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                    if r33 not in expns or hhlll not in expns[r33]:
                                                                        expns[r33][hhlll] =C1
                                                                        if r33 not in Relational_formula_filter:
                                                                            Relational_formula_filter[r33]=WORDS[r33]    
                                                                    else:
                                                                        expns[r33][hhlll] = expns[r33][hhlll] +C1 
                                                                elif Sample[r1]==6:
                                                                    #W1=W1+r_wts1[w][1]
                                                                   # margs[r][1]=margs[r][1]+1
                                                                    hhlll="Samelink("+str(r33)+","+str(r1)+")"
                                                                    if r33 not in expns or hhlll not in expns[r33]:
                                                                        expns[r33][hhlll] =C1
                                                                        if r33 not in Relational_formula_filter:
                                                                            Relational_formula_filter[r33]=WORDS[r33]    
                                                                    else:
                                                                        expns[r33][hhlll] = expns[r33][hhlll] +C1 




                                #Computing Marginal Probability of original
                                margs1={}
                                for t in margs:
                                    pass# print(t,margs[t])
                                    gh=[]
                                    if iter1[t]>0:
                                        for kk in margs[t]:
                                            vv=float(kk)/float(iter1[t])
                                            if float(vv)>=1.0:
                                                gh.append(float(1.0))
                                            elif float(vv)<1.0:
                                                gh.append(abs(float(vv)))
                                        margs1[t]=gh
                                #d_tt={}
                                margs2={}
                                #d_tt[0]="Neural_Networks"
                                #d_tt[1]="Probabilistic_Methods"
                                for dd in margs1:
                                    v=max(margs1[dd])
                                    print(v)
                                    if v>0:
                                        margs2[dd]=v
                                #check the marginal
                                for t in margs:
                                     print(t,margs[t])
                                for t in margs1:
                                    s=0
                                    for dd in margs1[t]:
                                        s=s+dd
                                    pass#print(t,s)

                                #predicting review original
                                sampled_doc=[]
                                pred_t=[]
                                for a in margs1:
                                    for ss in range(0,len(margs1[a])):
                                            if margs1[a][ss]==margs2[a]:
                                                #print(a,d_tt[ss])
                                                sampled_doc.append(a)
                                                pred_t.append(d_tt[ss])
                                ss=set(sampled_doc)
                                sampled_doc_up=[]
                                sampled_doc_up_map1={}
                                for kk in ss:
                                    sampled_doc_up.append(kk)
                                for tt in sampled_doc_up:
                                    ggf=[]
                                    gvv=[]
                                    c=0
                                    for gg in range(0,len(sampled_doc)):
                                        if tt==sampled_doc[gg]:
                                            ggf.append(pred_t[gg])
                                    for ggh in ggf:
                                        if c<1:
                                            gvv.append(ggh)
                                            c=c+1

                                    sampled_doc_up_map1[tt]=gvv

                                cx=0   
                                for s in sampled_doc_up_map1:
                                    if len(sampled_doc_up_map1[s])>1:
                                            cx=cx+1
                                           #print(s,sampled_doc_up_map[s])


                                #print(doc_per_pred_topic)
                                print(cx)

                                ffd=open("Original_Prediction1.txt","w")

                                for s in sampled_doc_up_map1:
                                    ccvb=str(s)+":"+str(sampled_doc_up_map1[s])
                                    ffd.write(str(ccvb)+"\n")
                                ffd.close()

                                #Computing Prediction Probability
                                from sklearn import svm
                                #from sklearn import cross_validation
                                from sklearn.model_selection import cross_validate
                                from sklearn.preprocessing import MinMaxScaler
                                from sklearn.metrics import (precision_score,recall_score,f1_score)
                                from sklearn.feature_extraction.text import CountVectorizer
                                pred=[]
                                true=[]
                                #topicindex doc_per_pred_topic sampled_doc_up_map
                                f4=[]
                                f5=[]
                                f6=[]
                                #for d in range(0,2):
                                for t in margs2:
                                   # if t in qrat and t in sampled_doc_up_map1:
                                                    for tt in sampled_doc_up_map1[t]:
                                                                    #print(tt,d_tt[0])
                                                                    if str(tt)==str(d_tt[1]):
                                                                        pred.append(1)
                                                                    else:
                                                                        pred.append(0)
                                                                    if str(label[t])=='Probabilistic_Methods':
                                                                        true.append(1)
                                                                    else:
                                                                        true.append(0)
                                print(precision_score(true,pred))
                                print(recall_score(true,pred))
                                print(f1_score(true,pred))
                                f4.append(float(precision_score(true,pred)))
                                f5.append(float(recall_score(true,pred)))
                                f6.append(float(f1_score(true,pred)))
                                #Explanation Generation
                                import operator
                                correct_predictions_r = {}

                                for m in margs1.keys():
                                            if m in WORDS and m in sampled_doc_up_map1:
                                                          correct_predictions_r[m] = 1
                                            #if len(WORDS[m])==0:#or ratings[m]==3:
                                               # continue
                                            #else:
                                               # correct_predictions[m] = 1
                                            #if margs[m] > 0.5 and spamindex[m] ==-1:
                                                #correct_predictions[m] = 1
                                fft_r=open("expn_n1_r1_or.txt","w")  
                                explanation_r={}
                                for e in expns: 
                                    if e in correct_predictions_r:
                                        sorted_expns_r = sorted(expns[e].items(), key=operator.itemgetter(1),reverse=True)
                                        z = 0
                                        for s in sorted_expns_r[:]:
                                            z = z + s[1]
                                        rex_r = {}
                                        keys_r = []
                                        for s in sorted_expns_r[:]:
                                            #if 'same' in s[0]:
                                            rex_r[s[0]] = s[1]/z
                                            keys_r.append(s[0])
                                        #if "Sameuser" not in keys or "Samehotel" not in keys:
                                            #continue
                                        sorted1 = sorted(rex_r.items(), key=operator.itemgetter(1),reverse=True)
                                        #if sorted1[0][0]=="JNTM":
                                        #print(str(e) +" "+str(sorted1))
                                        gg=str(e) +":"+str(sorted1)
                                        explanation_r[e]=sorted1
                                        fft_r.write(str(gg)+"\n")
                                hhh="Explanation_Topic1"+"_original"+" before user feedback"+".txt"
                                f11_r=open(hhh,"w")
                                Store_Explanation_r={}
                                for t in explanation_r:
                                    #for k in WORDS1:
                                           #if str(t)==str(k):
                                                ggg=str(t)+":"+str(explanation_r[t])
                                                f11_r.write(str(ggg)+"\n")
                                                print(t,explanation_r[t])
                                                print("\n")
                                                Store_Explanation_r[t]=explanation_r[t]
                                return WORDS,Store_Explanation_r


WORDS,Store_Explanation_r=cora_mln()
